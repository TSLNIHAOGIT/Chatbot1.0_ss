# %%
import pandas as pd
import numpy as np
import re
import datetime as dt
import pytz
import sys,os
ENV_PATH = '../../ENV/'
sys.path.append(ENV_PATH)
from env import ENV

sys.path.append('../../Lib')
from LOG import Logger

__file__ = '../TIME_PATTERN/'

# %%
class CHN2NUM:
    def __init__(self):
        self.CN_NUM = {
    '〇' : 0, '一' : 1, '二' : 2, '三' : 3, '四' : 4, '五' : 5, '六' : 6, '七' : 7, '八' : 8, '九' : 9, '零' : 0,
    '壹' : 1, '贰' : 2, '叁' : 3, '肆' : 4, '伍' : 5, '陆' : 6, '柒' : 7, '捌' : 8, '玖' : 9, '貮' : 2, '两' : 2
}

        for i in range(10):
            self.CN_NUM[str(i)] = i
        self.CN_UNIT = {
                            '十' : 10,
                            '拾' : 10,
                            '百' : 100,
                            '佰' : 100,
                            '千' : 1000,
                            '仟' : 1000,
                            '万' : 10000,
                            '萬' : 10000,
                            '亿' : 100000000,
                            '億' : 100000000,
                            '兆' : 1000000000000,
                        }

    def transform(self,cn:str):
        unit = 0   # current
        ldig = []  # digest
        for cndig in reversed(cn):
            if cndig in self.CN_UNIT:
                unit = self.CN_UNIT.get(cndig)
                if unit == 10000 or unit == 100000000:
                    ldig.append(unit)
                    unit = 1
            else:
                dig = self.CN_NUM.get(cndig)
                if unit:
                    dig *= unit
                    unit = 0
                ldig.append(dig)
        if unit == 10:
            ldig.append(10)
        val, tmp = 0, 0
        for x in reversed(ldig):
            if x == 10000 or x == 100000000:
                val += tmp * x
                tmp = 0
            else:
                tmp += x
        val += tmp
        return val


class TimePattern:
    def __init__(self,logAppendName=''):
        self.CHN2NUM = CHN2NUM()
        self._init_reExpression()
        self.log = None
        self.evlEngine = None
        self.logAppendName = logAppendName
        self._load_mapping(os.path.join(os.path.dirname(__file__), 'mapping.csv'))
        
    def _init_post(self):
        """
        once below two are initialized, it will be locked by thread and thus cannot be pickled.
        Need to initialize later.
        """
        logName = self.__class__.__name__ + self.logAppendName
        self.log = Logger(logName,level=ENV.MODEL_LOG_LEVEL.value).logger
        self.evlEngine = EvlTimeExpEngine(logAppendName=self.logAppendName)
        
    def _load_mapping(self, pattern_path):
        df = pd.read_csv(pattern_path)
        # create length
        df['length'] = df.key_word.apply(lambda x: len(x))
        df = df.sort_values(['length','key_word'], ascending=False)
        df_series = pd.Series(index=df.key_word.values, data=df.expression.values)
        df_dict = df_series.to_dict()
        self.serires = df_series
        self.re_ext = r'|'.join(self.serires.index.values)
        self.dict_ext = df_dict
        
    def _init_reExpression(self):
        self.num_cn = r'[一二三四五六七八九十零〇两百千0-9]'
        
        self.year_rela_exp = r'(?:今|明|后|后后|再后|下一|再下一|下|再下|半|(?:{}))年(?:半)?'.format(self.num_cn)
        self.year_fix_exp = r'(?:{}+)年'.format(self.num_cn)
        self.year_exp = r'(?:{}|{})'.format(self.year_rela_exp,self.year_fix_exp)
        
        self.month_rela_exp = r'(?:下下下|下下|再下|下|(?:{}+)|半)(?:个)?(?:半)?月'.format(self.num_cn)
        self.month_fix_exp = r'(?:{}+)月'.format(self.num_cn)
        self.month_exp = r'(?:{}|{})'.format(self.month_rela_exp,self.month_fix_exp)


        self.date_rela_exp = '(?:今|明|后|大后|大大后|再后|(?:{})+)天'.format(self.num_cn)
        self.date_descrip_exp = r'(?:上旬|中旬|下旬|月初|月中|月末|月底|初|底|末)'
        self.date_fix_exp = r'(?:(?:{}+)(?:日|号))|{}'.format(self.num_cn,self.date_descrip_exp)
        self.date_exp = r'(?:{}|{})'.format(self.date_rela_exp,self.date_fix_exp)

        
        
        
        
        self.hour_rela_exp= r'(?:{}+(?:个)?(?:半)?)(?:小时|钟头)'.format(self.num_cn)
        self.hour_descrip_exp = r'早晨|凌晨|早上|半夜|上午|中午|下午|傍晚|晚上|清晨|午后'
        self.minute_fix_exp = r'(?:(?:过)?一刻|(?:过)?{}+(?:分)?|半(?:过)?|过)+'.format(self.num_cn)
        self.hour_fix_exp= r'(?:(?:{})|(?:(?:{}+)点(?:{})?))+'.format(self.hour_descrip_exp,
                                                                   self.num_cn,
                                                                     self.minute_fix_exp)
        self.hour_exp = r'(?:{}|{})'.format(self.hour_rela_exp,self.hour_fix_exp)
        
        
        self.minute_rela_exp = r'(?:过)?(?:{}+|几)分钟|(?:过)?一刻钟'.format(self.num_cn)
        self.minute_exp = r'(?:{})'.format(self.minute_rela_exp)


        self.week_rela_exp = r'(?:(?:这|下|再下|下下|再后)(?:{}+)?(?:个)?)|(?:{}+)'.format(self.num_cn,self.num_cn)
        self.weekDay_exp = r'[1-7天一二三四五六七]'
        self.week_unit = r'周|星期|礼拜'
        self.exp_week =  r'(?:(?:{rw})?(?:{wu})+(?:{wd})?(?:{h})?(?:{mm})?)+'.format(rw=self.week_rela_exp,
                                                                           wu=self.week_unit,
                                                                           wd=self.weekDay_exp,
                                                                           h=self.hour_exp,
                                                                            mm=self.minute_exp)

        self.exp_ymd = r'(?:(?:{y})|(?:{m})|(?:{d})|(?:{h})|(?:{mm}))+'.format(y=self.year_exp,
                                                                      m=self.month_exp,
                                                                      d=self.date_exp,
                                                                      h=self.hour_exp,
                                                                        mm=self.minute_exp)
        
    def remove_time(self,sentence):
        finds,remain = self.extract_pattern(sentence,replace='TIMEPATTERN')
        return remain
        
    def YearExtractor(self,sentence):
        """
        this function will return a list of year it can extract
        """
        #########
        #######define
        
        def Year2Exp(text):
            """
            text has format of "<x>年"
            output: extracted expression
            """
            year_map = {'今':'?','明':'^1','后':'^2','后后':'^3',
                        '再后':'^3','下一':'^1','下':'^1','再下一':'^2','再下':'^2','半':'+0.5'}
            def CHN2Year(x):
                ##TODO: more case needs to be handled
                # case 1. digits
                if x.isdigit():
                    # case 1.1 length is 4. eg 2017
                    if len(x) == 4:
                        return x
                    # case 1.2 length is not 4. which may mean calcuate delta
                    else:
                        return '+'+x
                # needs to handle more cases
                else:
                    return '?'
            index = text.find('年')
            y = None
            if index == -1:
                y = '?'
            else:
                context = text[:index]
                # step 1. get mapping from year_map
                if year_map.get(context) is not None:
                    y = year_map.get(context)
                # step 2. CHN to canlender year    
                else:
                    y = CHN2Year(context)
                    if text.find('半') != -1:
                        y = y+'.5'
            return y
        ########################## end define ############################
        extracted_list = re.findall(self.year_exp,sentence)
        finds_list = []
        if len(extracted_list) > 0:
            for each in extracted_list:
                try:
                    y = Year2Exp(each)
                except Exception as e:
                    self.log.error(e)
                    y = '?'
                finally:
                    finds_list.append((each,y))
        else:
            y = '?'
            finds_list.append((None,y))
        return finds_list 
    
    def MonthExtractor(self,sentence):
        """
        extract month info and convert to expression
        """
        def Month2Exp(text):
            month_map = {'下下下':'^3','下下':'^2','再下':'^2','下':'^1','半':'+0.5'}
            def CHN2Month(x,rela=True):
                """
                CHN2Month("二",rela=True)   --> +2
                CHN2Month("二",rela=False)   --> 2
                CHN2Month("二十",rela=False) --> +20
                """
                if x.isdigit():
                    if int(x) > 12 or rela:
                        return '+'+x
                    else:
                        return x
                # if not digit, then transform        
                else:
                    try:
                        x = str(self.CHN2NUM.transform(x))
                        if int(x) > 12 or rela:
                            x = '+'+x                
                    except Exception as e:
                        self.log.error(e)
                        x = '?'
                    finally:
                        return x
            index = text.find('月')
            m = None
            if index == -1:
                m = '?'
            else:
                # step 1. get mapping from month_map
                index_rala = text.find('个月')
                if index_rala != -1:
                    index = index_rala
                content = text[:index]
                if month_map.get(content) is not None:
                    m = month_map.get(content)

                # step 2. CHN to canlender month
                else:
                    shift = ''
                    if index_rala == -1:
                        index_rala = text.find('个半月')
                        if index_rala != -1:
                            shift = '.5'
                            content = text[:index_rala]
                        
                    if index_rala != -1:
                        ## process relative month logic
                        m = CHN2Month(content,rela=True)
                        m += shift
                    else:
                        ## process nonrelative month logic
                        m = CHN2Month(content,rela=False)
            return m
        ################## end define ############
        extracted_list = re.findall(self.month_exp,sentence)
        finds_list = []
        if len(extracted_list) > 0:
            for each in extracted_list:
                try:
                    m = Month2Exp(each)
                except Exception as e:
                    self.log.error(e)
                    m = '?'
                finally:
                    finds_list.append((each,m))
        else:
            m = '?'
            finds_list.append((None,m))
        return finds_list
    
    def DateExtractor(self,sentence,month_flag = True):
        """
        extract month info and convert to expression
        """
        def Date2Exp(text):
            date_map = {'今':'?','明':'^1','后':'^2','大后':'^3','大大后':'^4','再后':'^3',
                        '上旬':'10','中旬':'15','下旬':'28','月初':'10','月中':'15','月末':'28','月底':'28',
                        '初':'10','中':'15','底':'28','末':'28'}
            def CHN2Date(x,rela=True):
                """
                CHN2Date("二",rela=True)   --> +2
                CHN2Date("二",rela=False)   --> 2
                CHN2Date("二十",rela=False) --> +20
                """
                if x.isdigit():
                    if int(x) > 31 or rela:
                        return '+'+x
                    else:
                        return x
                # if not digit, then transform        
                else:
                    try:
                        x = str(self.CHN2NUM.transform(x))
                        if int(x) > 31 or rela:
                            x = '+'+x                
                    except Exception as e:
                        self.log.error(e)
                        x = '?'
                    finally:
                        return x
            # case 1. 号
            if text.find('号') != -1:
                index_date = text.find('号')
                d = CHN2Date(text[:index_date],rela=False)
            # case 2. 天
            elif text.find('天') != -1:
                index_date = text.find('天')
                descrip = text[:index_date]
                d = date_map.get(descrip)
                if d is None:
                    d = CHN2Date(descrip,rela=True)
            # case 3. 天
            elif text.find('日') != -1:
                index_date = text.find('日')
                descrip = text[:index_date]
                if month_flag:
                    d = CHN2Date(text[:index_date],rela=False)
                else:
                    d = CHN2Date(text[:index_date],rela=True)
            elif date_map.get(text) is not None:
                d = date_map.get(text)
            else:
                d = '?'
            return d
        ################## end define ############
        extracted_list = re.findall(self.date_exp,sentence)
        finds_list = []
        if len(extracted_list) > 0:
            for each in extracted_list:
                try:
                    d = Date2Exp(each)
                except Exception as e:
                    self.log.error(e)
                    d = '?'
                finally:
                    finds_list.append((each,d))
        else:
            d = '?'
            finds_list.append((None,d))
        return finds_list
    
    

    def HourExtractor(self,sentence,date_flag=None):
        """
        extract hour info and convert to expression
        date_flag will just be used as a placeholder
        3点15，
        3点过一刻
        can be extracted
        """
        def Minute2Exp(text):
            minute_map = {'过':'30','一刻':'15','半':'30','半过':'45'}
            reg_period = r'过|分|钟'
            def CHN2Minute(x,rela=True):
                """
                CHN2Minute("二",rela=True)   --> +2
                CHN2Minute("二",rela=False)   --> 2
                CHN2Minute("二十",rela=False) --> +20
                """
                if x.isdigit():
                    if int(x) > 59 or rela:
                        return '+'+x
                    else:
                        return x
                # if not digit, then transform        
                else:
                    try:
                        x = str(self.CHN2NUM.transform(x))
                        if int(x) > 59 or rela:
                            x = '+'+x                
                    except Exception as e:
                        self.log.error(e)
                        x = '00'
                    finally:
                        if x == '0':
                            x = '00'
                        return x
            # case 1. can get value from defined mapping
            if minute_map.get(text) is not None:
                mm = minute_map.get(text)
            # case 2. need to remove some words
            else:
                text_sub = re.sub(reg_period,'',text)
                if minute_map.get(text_sub) is not None:
                    mm = minute_map.get(text_sub)
                # cannot get value from defined mapping
                else:
                    try:
                        mm = CHN2Minute(text_sub, rela=False)
                    except Exception as e:
                        self.log.error(e)
                        mm = '00'
            return mm

        def Hour2Exp(text):
                hour_map = {'早晨':11,'凌晨':6,'早上':11,'半夜':6,'清晨':11,'上午':11,
                            '中午':14,'下午':18,'傍晚':21,'晚上':23,'午后':15,}
                reg_period = r'(?:个)?(?:小时|钟头)'
                def CHN2Hour(x,rela=True):
                    """
                    CHN2Date("二",rela=True)   --> +2
                    CHN2Date("二",rela=False)   --> 2
                    CHN2Date("二十",rela=False) --> +20
                    """
                    if x.isdigit():
                        if int(x) > 24 or rela:
                            return '+'+x
                        else:
                            return x
                    # if not digit, then transform        
                    else:
                        try:
                            x = str(self.CHN2NUM.transform(x))
                            if int(x) > 24 or rela:
                                x = '+'+x                
                        except Exception as e:
                            self.log.error(e)
                            x = '?'
                        finally:
                            return x
                def ShiftTime(x,am_pm):
                    am_pm = am_pm//12
                    if x.isdigit():
                        x = int(x) 
                        if x < 12 and am_pm == 1:
                            x += 12
                        return str(x)
                    else:
                        return x

                #1. Judge in the morning or afternoon. Then remove the description words
                des_t = re.findall(self.hour_descrip_exp,text)
                if len(des_t) > 0:
                    des_t = des_t[0]
                    hours = hour_map.get(des_t)
                    if hours is None:
                        hours = 17
                    text = re.sub(self.hour_descrip_exp,'',text)
                else:
                    hours = 17
                mm = '00'
                # case 1.  几点

                if len(re.findall(r'点',text)) > 0:
                    index_hour = text.find('点')
                    h = CHN2Hour(text[:index_hour],rela=False)
                    h = ShiftTime(h,hours)
                    mm = Minute2Exp(text[index_hour+1:])
                    try:
                        if int(h) >= 24:
                            h='23'
                            mm='59'
                    except Exception as e:
                        pass
                    
                # case 2. 几个小时
                elif len(re.findall(reg_period,text)) > 0:
                    replace = '!H!'
                    if text.find('半') != -1:
                        mm = '+30'
                        text = re.sub(r'半','',text)
                    finds = re.sub(reg_period,replace,text)
                    index_hour = finds.find(replace)
                    h = CHN2Hour(finds[:index_hour],rela=True)
                else:
                    h = str(hours)
                return h,mm
        ################## end define ############
        extracted_list = re.findall(self.hour_exp,sentence)
        finds_list = []
        if len(extracted_list) > 0:
            for each in extracted_list:
                try:
                    h,mm = Hour2Exp(each)
                except Exception as e:
                    self.log.error(e)
                   
                    h = '?'
                    mm = '?'
                finally:
                    finds_list.append((each,h,mm))
        else:
            h = '?'
            mm = '?'
            finds_list.append((None,h,mm))
        return finds_list
    
    
    def MinuteExtractor(self,sentence,hour_flag=None):
        """
        just extract relative time. fix time will be handled by hour
        """
        def Minute2Exp(text):
            minute_map = {'一刻钟':'+15'}
            def CHN2Minute(x,rela=True):
                """
                CHN2Minute("二",rela=True)   --> +2
                CHN2Minute("二",rela=False)   --> 2
                CHN2Minute("二十",rela=False) --> +20
                """
                if x.isdigit():
                    if int(x) > 59 or rela:
                        return '+'+x
                    else:
                        return x
                # if not digit, then transform        
                else:
                    try:
                        x = str(self.CHN2NUM.transform(x))
                        if int(x) > 59 or rela:
                            x = '+'+x                
                    except Exception as e:
                        self.log.error(e)
                        x = '00'
                    finally:
                        return x
            # case 1. can get value from defined mapping
            if minute_map.get(text) is not None:
                mm = minute_map.get(text)
            # case 2. need to remove some words
            else:
                text = re.sub('过','',text)
                index_minute = text.find('分钟')
                if index_minute != -1:
                    mm = CHN2Minute(text[:index_minute],rela=True)
                else:
                    mm = '?'
            return mm
        ################## end define ############
        extracted_list = re.findall(self.minute_exp,sentence)
        finds_list = []
        if len(extracted_list) > 0:
            for each in extracted_list:
                try:
                    mm = Minute2Exp(each)
                except Exception as e:
                    self.log.error(e)
                    mm = '00'
                finally:
                    finds_list.append((each,mm))
        else:
            mm = '?'
            finds_list.append((None,mm))
        return finds_list
    
    def WeekExtractor(self,sentence):
        def Week2Exp(text):
            replace_wu = '!wu!'
            reg_wu = r'(?:{})+'.format(replace_wu)
            rela_week_map = {'这':'?','下':'^1','再下':'^2','下下':'^2','再后':'^2'}
            def CHN2Week(x,rela=True):
                """
                CHN2Minute("二",rela=True)   --> +2
                CHN2Minute("二",rela=False)   --> 2
                CHN2Minute("二十",rela=False) --> +20
                """
                if x.isdigit():
                    if rela:
                        return '+'+x
                    else:
                        return x
                # if not digit, then transform        
                else:
                    try:
                        x = str(self.CHN2NUM.transform(x))
                        if rela:
                            x = '+'+x                
                    except Exception as e:
                        self.log.error(e)
                        x = '?'
                    finally:
                        return x
            # replace key word

            text = re.sub(self.week_unit,replace_wu,text)
            text = re.sub(reg_wu,replace_wu,text)
            # no such pattern
            index_wu = text.find(replace_wu)
            if index_wu == -1:
                W = '?'
                w = '?'
            else:
                Week_info = text[:index_wu]
                Week_info = re.sub(r'个','',Week_info)
                WeekDay_info = text[index_wu+len(replace_wu):]
                if len(Week_info) > 0:
                    if rela_week_map.get(Week_info) is not None:
                        W = rela_week_map.get(Week_info)
                    else:
                        W = CHN2Week(Week_info,rela=True)
                else:
                    W = '?'
                if len(WeekDay_info) > 0:
                    w = CHN2Week(WeekDay_info,rela=False)
                else:
                    w = '?'
            return W,w
        ################## end define ############
        extracted_list = re.findall(self.exp_week,sentence)      
        finds_list = []
        if len(extracted_list) > 0:
            for each in extracted_list:
                each = re.sub(self.hour_exp,'',each)
                try:
                    W,w = Week2Exp(each)
                except Exception as e:
                    self.log.error(e)
                    W = '?'
                    w = '?'
                finally:
                    finds_list.append((each,W,w))
        else:
            W = '?'
            w = '?'
            finds_list.append((None,W,w))
        return finds_list
        
    def evl_week(self,sentence):
        exp = '?y-{}W-{}w-{}H:{}M:00S'
        finds = re.findall(self.exp_week,sentence)
        return_list = []

        for each in finds:
            #1. process week and weekday
            extract_w = self.WeekExtractor(each)
            p,W,w = extract_w[0]
            if p is None:
                continue
            #2. process hour and minute
            extract_h = self.HourExtractor(each)
            p,h,mm = extract_h[0]
            if p is None:
                h = '18'
                mm = '00'
            return_list.append((each,exp.format(W,w,h,mm)))
            
        return return_list
    
    
    def evl_ymd(self,sentence):
        exp = '{}y-{}m-{}d-{}H:{}M:00S'
        finds = re.findall(self.exp_ymd,sentence)
        return_list = []

        for each in finds:
            #1. process year
            extract_y = self.YearExtractor(each)
            p,y = extract_y[0]
            if p is None:
                p=''
            each_remain = re.sub(p,'',each)
            #2. process month
            extract_m = self.MonthExtractor(each_remain)
            p,m = extract_m[0]
            if p is None:
                p=''
                month_flag = False
            else:
                month_flag = True
            each_remain = re.sub(p,'',each_remain)
            #3. process date
            extract_d = self.DateExtractor(each_remain,month_flag)
            p,d = extract_d[0]
            if p is None:
                p=''
            each_remain = re.sub(p,'',each_remain)
            #4. process hours
            extract_h = self.HourExtractor(each_remain)
            p,h,mm = extract_h[0]
            if p is None:
                p=''
            each_remain = re.sub(p,'',each_remain)
            #5. process minutes
            extract_m = self.MinuteExtractor(each_remain)
            p,mm_rela = extract_m[0]
            if mm_rela[0] == '+':
                mm = mm_rela
            return_list.append((each,exp.format(y,m,d,h,mm)))
            
        return return_list
    
    def evl_selfDefine(self,sentence):
        finds = re.findall(self.re_ext,sentence)
        return_list = []
        for each in finds:
            return_list.append((each,self.dict_ext[each]))
        return return_list
        
    
    
    def extract_pattern(self,sentence,replace='TIMEPATTERN'):
        #1 process by self define
        selfDefine_finds = self.evl_selfDefine(sentence)
        remain = re.sub(self.re_ext,replace,sentence)
        #2 process by week exp
        week_finds = self.evl_week(remain)
        remain = re.sub(self.exp_week,replace,remain)
        #3 process by ymd exp
        ymd_finds = self.evl_ymd(remain)
        remain = re.sub(self.exp_ymd,replace,remain)
        
        finds = selfDefine_finds + week_finds + ymd_finds
        return finds,remain
        
        
    def process(self,sentence):
        if self.log is None:
            self._init_post()
        finds,_ = self.extract_pattern(sentence)
        result = []
        for p,exp in finds:
            try:
                timestamp,gapS,gapH,gapD = self.evlEngine.evl(exp)
                result.append({'pattern':p,'time':timestamp,'gapS':gapS,'gapH':gapH,'gapD':gapD,'exp':exp})
            except Exception as e:
                self.log.error('evaluating expression: {}. Got error!!!'.format(exp))
                self.log.error(e)
            
        return result
            
                
                
                    
    
class EvlTimeExpEngine:
    def __init__(self,tz=None,logAppendName=''):
        self.logAppendName = logAppendName
        logName = self.__class__.__name__+logAppendName
        self.log = Logger(logName,level=ENV.MODEL_LOG_LEVEL.value).logger
        self._set_timeZone(tz)
        
    def _set_timeZone(self,tz=None):
        if tz is None:
            tz = ENV.TIMEZONE.value
            self.log.info('Time Zone is set from ENV: {}. Classifier: {}'.format(tz,self.logAppendName))
        tz = ENV.TIMEZONE.value
        self.tz = pytz.timezone(tz)
        self.delta = self.tz.utcoffset(dt.datetime.utcnow())
        
        
    def _get_LocalNow(self):
        now = dt.datetime.utcnow()
        return self.tz.localize(now) + self.delta
        
    
    def evl(self,exp):
        """
        '?y-{}W-{}w-{}H:{}M:00S'
        '{}y-{}m-{}d-{}H:{}M:00S'
        """
        current = self._get_LocalNow()
        if exp.find('W') != -1:
            timestamp =  self.createFromWD(exp,current)
        else:
            timestamp = self.createFromYMD(exp,current)
        gapS = (timestamp - current).total_seconds()
        gapH = gapS / 3600
        gapD = gapH / 24
        return timestamp,gapS,gapH,gapD
        
    
    def createFromWD(self,exp,current):
        """
        create timestamp from weekDay expression
        https://docs.python.org/3/library/datetime.html#strftime-strptime-behavior
        y,W has '^'
        """
        posi_info = self.WD_exp_keyExtractor(exp)
        y_cur = current.year
        W_cur = int(current.strftime("%W"))
        w_cur = int(current.strftime("%w"))
        shift = 0
        ###### process year
        if posi_info['y'][0] == '^':
            y = current.year + int(posi_info['y'][1:])
        elif posi_info['y'] == '?':
            y = current.year
        elif posi_info['y'][0] == '+':
            y = current.year
            shift += float(posi_info['y'][1:]) * 365 * 24 * 60
        else:
            y = int(posi_info['y'])
            
        ###### process week
        if posi_info['W'][0] == '^':
            W = W_cur + int(posi_info['W'][1:])
        elif posi_info['W'] == '?':
            W = W_cur
        elif posi_info['W'][0] == '+':
            W = W_cur
            shift += float(posi_info['W'][1:]) * 7 * 24 * 60
        else:
            W = int(posi_info['W'])
        
        ###### process week day
        if posi_info['w'] == '?':
            w = w_cur
        elif posi_info['w'][0] == '+':
            w = w_cur
            shift += float(posi_info['w'][1:]) * 1 * 24 * 60
        else:
            w = int(posi_info['w'])
            
        ###### process hour
        if posi_info['H'] == '?':
            H = current.hour
        elif posi_info['H'][0] == '+':
            H = current.hour
            shift += float(posi_info['H'][1:]) * 60
        else:
            H = int(posi_info['H'])
        
        ###### process Minute
        if posi_info['M'] == '?':
            M = current.minute
        elif posi_info['M'][0] == '+':
            M = current.minute
            shift += float(posi_info['M'][1:])
        else:
            M = int(posi_info['M'])
        
        ###### process Second
        if posi_info['S'] == '?':
            S = current.second
        elif posi_info['S'][0] == '+':
            S = current.second
            shift += int(float(posi_info['S'][1:]) / 60)
        else:
            S = int(posi_info['S'])
            
        y = y + ((W-1)//53)
        W = W % 53
        if W==0:
            W=53
        if w >= 7:
            shift+= (w-7)*24*60
            w=0
            
        
        reconstruct = True
        while reconstruct:
            try:    
                time = '{}y-{}W-{}w-{}H:{}M:00S'.format(y,W,w,H,M,S)
                timestamp = dt.datetime.strptime(time, "%Yy-%WW-%ww-%HH:%MM:%SS")
                reconstruct = False
            except ValueError as e:
                self.log.error(e)
                self.log.error('year:{},Week:{},weekday:{}'.format(y,W,w))
                self.log.info('will change to next year')
                W -= 1
                shift += 24 * 60 * 7
            
        delta = dt.timedelta(minutes=shift)
        timestamp += delta
        timestamp = self.tz.localize(timestamp)
        
        return timestamp
            
    
    def createFromYMD(self,exp,current):
        """
        shift is converted to minute level
        y,m,d has '^'
        
        """
        posi_info = self.YMD_exp_keyExtractor(exp)
        shift = 0
        ###### process year
        if posi_info['y'][0] == '^':
            y = current.year + int(posi_info['y'][1:])
        elif posi_info['y'] == '?':
            y = current.year
        elif posi_info['y'][0] == '+':
            y = current.year
            shift += float(posi_info['y'][1:]) * 365 * 24 * 60
        else:
            y = int(posi_info['y'])
        ###### process month
        if posi_info['m'][0] == '^':
            m = current.month + int(posi_info['m'][1:])
        elif posi_info['m'] == '?':
            m = current.month
        elif posi_info['m'][0] == '+':
            m = current.month
            shift += float(posi_info['m'][1:]) * 30 * 24 * 60
        else:
            m = int(posi_info['m'])
            
        y = y + ((m-1)//12)
        m = m % 12
        if m == 0:
            m = 12
        
        ###### process day
        if posi_info['d'][0] == '^':
            d = current.day + int(posi_info['d'][1:])
        elif posi_info['d'] == '?':
            d = current.day
        elif posi_info['d'][0] == '+':
            d = current.day
            shift += float(posi_info['d'][1:]) * 24 * 60
        else:
            d = int(posi_info['d'])
        
        ###### process hour
        if posi_info['H'] == '?':
            H = current.hour
        elif posi_info['H'][0] == '+':
            H = current.hour
            shift += float(posi_info['H'][1:]) * 60
        else:
            H = int(posi_info['H'])
        
        ###### process Minute
        if posi_info['M'] == '?':
            M = current.minute
        elif posi_info['M'][0] == '+':
            M = current.minute
            shift += float(posi_info['M'][1:])
        else:
            M = int(posi_info['M'])
        
        ###### process Second
        if posi_info['S'] == '?':
            S = current.second
        elif posi_info['S'][0] == '+':
            S = current.second
            shift += float(int(posi_info['S'][1:]) / 60)
        else:
            S = int(posi_info['S'])
            
        reconstruct = True
        while reconstruct:
            try:    
                timestamp = dt.datetime(year=y,month=m,day=d,hour=H,minute=M,second=S)
                reconstruct = False
            except ValueError as e:
                self.log.error(e)
                self.log.error('year:{},month:{},day:{}'.format(y,m,d))
                self.log.info('will change to next month')
                d -= 1
                shift += 24 * 60
            
        delta = dt.timedelta(minutes=shift)
        timestamp += delta
        timestamp = self.tz.localize(timestamp)
        
        return timestamp
    
    def YMD_exp_keyExtractor(self, exp):
        y_index = exp.find('y')
        m_index = exp.find('m')
        d_index = exp.find('d')
        H_index = exp.find('H')
        M_index = exp.find('M')
        S_index = exp.find('S')
        y = exp[:y_index]
        m = exp[y_index+2:m_index]
        d = exp[m_index+2:d_index]
        H = exp[d_index+2:H_index]
        M = exp[H_index+2:M_index]
        S = exp[M_index+2:S_index]
        return {'y':y, 'm':m, 'd':d, 'H':H, 'M':M, 'S':S}
    
    def WD_exp_keyExtractor(self, exp):
        y_index = exp.find('y')
        W_index = exp.find('W')
        w_index = exp.find('w')
        H_index = exp.find('H')
        M_index = exp.find('M')
        S_index = exp.find('S')
        y = exp[:y_index]
        W = exp[y_index+2:W_index]
        w = exp[W_index+2:w_index]
        H = exp[w_index+2:H_index]
        M = exp[H_index+2:M_index]
        S = exp[M_index+2:S_index]
        return {'y':y, 'W':W, 'w':w, 'H':H, 'M':M, 'S':S}

# %%
r = TimePattern()

# %%
r.process('今天二十五点之前还')
# Out:
# [{'pattern': '今天二十五点',
#   'time': datetime.datetime(2018, 9, 11, 23, 59, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>),
#   'gapS': 6913.302884,
#   'gapH': 1.9203619122222222,
#   'gapD': 0.08001507967592593,
#   'exp': '?y-?m-?d-23H:59M:00S'}]

# %% [markdown]
# # Test self-define

# %%
df_mapping = pd.read_csv('../../classifier/models/time_pattern/mapping.csv')

# %% [markdown]
# # Load from py

# %%
import re
import sys,os
import pandas as pd
sys.path.append('../../classifier/models/time_extractor/')
from time_pattern import TimePattern
df_mapping = pd.read_csv('../../classifier/models/time_pattern/mapping.csv')

# %%
import time
r = TimePattern()
error_list = []
not_match = []
for pt in df_mapping.key_word.values:
    result = r.process(pt)
    print(pt)
    print(result)
    try:
        pt_extract = result[0]['pattern']
        if pt_extract != pt:
            not_match.append((pt,pt_extract))
    except Exception as e:  
        error_list.append((pt,str(e)))
# Out:
# 2018-09-11 14:06:25,227 - INFO - CLASS:EvlTimeExpEngine- METHOD:_set_timeZone -LINE:755 - MSG:Time Zone is set from ENV: Asia/Shanghai. Classifier:
# 明天
# [{'pattern': '明天', 'time': datetime.datetime(2018, 9, 12, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 86374.73772, 'gapH': 23.992982700000002, 'gapD': 0.9997076125000001, 'exp': '?y-?m-^1d-?H:?M:00S'}]
# 明天早上
# [{'pattern': '明天早上', 'time': datetime.datetime(2018, 9, 12, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 46414.736165, 'gapH': 12.892982268055556, 'gapD': 0.5372075945023148, 'exp': '?y-?m-^1d-11H:00M:00S'}]
# 明天下午
# [{'pattern': '明天下午', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 71614.735483, 'gapH': 19.89298207861111, 'gapD': 0.8288742532754628, 'exp': '?y-?m-^1d-18H:00M:00S'}]
# 后天下午
# [{'pattern': '后天下午', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 158014.734847, 'gapH': 43.892981901944445, 'gapD': 1.8288742459143519, 'exp': '?y-?m-^2d-18H:00M:00S'}]
# 后天
# [{'pattern': '后天', 'time': datetime.datetime(2018, 9, 13, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 172774.734297, 'gapH': 47.99298174916667, 'gapD': 1.9997075728819445, 'exp': '?y-?m-^2d-?H:?M:00S'}]
# 后天早上
# [{'pattern': '后天早上', 'time': datetime.datetime(2018, 9, 13, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 132814.733747, 'gapH': 36.892981596388886, 'gapD': 1.5372075665162035, 'exp': '?y-?m-^2d-11H:00M:00S'}]
# 今天
# [{'pattern': '今天', 'time': datetime.datetime(2018, 9, 11, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -25.266844, 'gapH': -0.007018567777777778, 'gapD': -0.0002924403240740741, 'exp': '?y-?m-?d-?H:?M:00S'}]
# 今天下午
# [{'pattern': '今天下午', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14785.267413, 'gapH': -4.107018725833333, 'gapD': -0.17112578024305555, 'exp': '?y-?m-?d-18H:00M:00S'}]
# 大后天
# [{'pattern': '大后天', 'time': datetime.datetime(2018, 9, 14, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 259174.731985, 'gapH': 71.99298110694444, 'gapD': 2.999707546122685, 'exp': '?y-?m-^3d-?H:?M:00S'}]
# 大后天早上
# [{'pattern': '大后天早上', 'time': datetime.datetime(2018, 9, 14, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 219214.731421, 'gapH': 60.89298095027778, 'gapD': 2.5372075395949074, 'exp': '?y-?m-^3d-11H:00M:00S'}]
# 大后天下午
# [{'pattern': '大后天下午', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 244414.730865, 'gapH': 67.89298079583332, 'gapD': 2.8288741998263887, 'exp': '?y-?m-^3d-18H:00M:00S'}]
# 半个月内
# [{'pattern': '半个月', 'time': datetime.datetime(2018, 9, 26, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1295974.730077, 'gapH': 359.9929805769445, 'gapD': 14.999707524039353, 'exp': '?y-+0.5m-?d-?H:?M:00S'}]
# 下个月
# [{'pattern': '下个月', 'time': datetime.datetime(2018, 10, 11, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 2591974.72946, 'gapH': 719.9929804055556, 'gapD': 29.99970751689815, 'exp': '?y-^1m-?d-?H:?M:00S'}]
# 下个月月底
# [{'pattern': '下个月月底', 'time': datetime.datetime(2018, 10, 28, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 4060774.728852, 'gapH': 1127.9929802366667, 'gapD': 46.99970750986111, 'exp': '?y-^1m-28d-?H:?M:00S'}]
# 下个月初
# [{'pattern': '下个月初', 'time': datetime.datetime(2018, 10, 10, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 2505574.728243, 'gapH': 695.9929800675, 'gapD': 28.999707502812498, 'exp': '?y-^1m-10d-?H:?M:00S'}]
# 下下个月
# [{'pattern': '下下个月', 'time': datetime.datetime(2018, 11, 11, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 5270374.727409, 'gapH': 1463.9929798358332, 'gapD': 60.99970749315972, 'exp': '?y-^2m-?d-?H:?M:00S'}]
# 再下个月
# [{'pattern': '再下个月', 'time': datetime.datetime(2018, 11, 11, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 5270374.726702, 'gapH': 1463.9929796394445, 'gapD': 60.99970748497685, 'exp': '?y-^2m-?d-?H:?M:00S'}]
# 下下个月初
# [{'pattern': '下下个月初', 'time': datetime.datetime(2018, 11, 10, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 5183974.726119, 'gapH': 1439.9929794775, 'gapD': 59.99970747822917, 'exp': '?y-^2m-10d-?H:?M:00S'}]
# 下个月中
# [{'pattern': '下个月', 'time': datetime.datetime(2018, 10, 11, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 2591974.725576, 'gapH': 719.9929793266666, 'gapD': 29.999707471944443, 'exp': '?y-^1m-?d-?H:?M:00S'}]
# 下下个月中
# [{'pattern': '下下个月', 'time': datetime.datetime(2018, 11, 11, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 5270374.725037, 'gapH': 1463.9929791769446, 'gapD': 60.999707465706024, 'exp': '?y-^2m-?d-?H:?M:00S'}]
# 下个月末
# [{'pattern': '下个月末', 'time': datetime.datetime(2018, 10, 28, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 4060774.724424, 'gapH': 1127.9929790066667, 'gapD': 46.99970745861111, 'exp': '?y-^1m-28d-?H:?M:00S'}]
# 下个月底
# [{'pattern': '下个月底', 'time': datetime.datetime(2018, 10, 28, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 4060774.723668, 'gapH': 1127.9929787966666, 'gapD': 46.99970744986111, 'exp': '?y-^1m-28d-?H:?M:00S'}]
# 下下个月末
# [{'pattern': '下下个月末', 'time': datetime.datetime(2018, 11, 28, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 6739174.722852, 'gapH': 1871.99297857, 'gapD': 77.99970744041667, 'exp': '?y-^2m-28d-?H:?M:00S'}]
# 下下个月底
# [{'pattern': '下下个月底', 'time': datetime.datetime(2018, 11, 28, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 6739174.722271, 'gapH': 1871.9929784086112, 'gapD': 77.99970743369214, 'exp': '?y-^2m-28d-?H:?M:00S'}]
# 下下下个月
# [{'pattern': '下下下个月', 'time': datetime.datetime(2018, 12, 11, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 7862374.72163, 'gapH': 2183.9929782305553, 'gapD': 90.99970742627313, 'exp': '?y-^3m-?d-?H:?M:00S'}]
# 一个月
# [{'pattern': '一个月', 'time': datetime.datetime(2018, 10, 11, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 2591974.720991, 'gapH': 719.9929780530556, 'gapD': 29.999707418877318, 'exp': '?y-+1m-?d-?H:?M:00S'}]
# 1个月
# [{'pattern': '1个月', 'time': datetime.datetime(2018, 10, 11, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 2591974.720237, 'gapH': 719.9929778436111, 'gapD': 29.999707410150464, 'exp': '?y-+1m-?d-?H:?M:00S'}]
# 半个月
# [{'pattern': '半个月', 'time': datetime.datetime(2018, 9, 26, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1295974.719604, 'gapH': 359.9929776677778, 'gapD': 14.999707402824074, 'exp': '?y-+0.5m-?d-?H:?M:00S'}]
# 两个月
# [{'pattern': '两个月', 'time': datetime.datetime(2018, 11, 10, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 5183974.718986, 'gapH': 1439.992977496111, 'gapD': 59.999707395671294, 'exp': '?y-+2m-?d-?H:?M:00S'}]
# 2个月
# [{'pattern': '2个月', 'time': datetime.datetime(2018, 11, 10, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 5183974.718377, 'gapH': 1439.9929773269444, 'gapD': 59.99970738862268, 'exp': '?y-+2m-?d-?H:?M:00S'}]
# 一个半月
# [{'pattern': '一个半月', 'time': datetime.datetime(2018, 10, 26, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 3887974.717767, 'gapH': 1079.9929771575, 'gapD': 44.9997073815625, 'exp': '?y-+1.5m-?d-?H:?M:00S'}]
# 1个半月
# [{'pattern': '1个半月', 'time': datetime.datetime(2018, 10, 26, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 3887974.717049, 'gapH': 1079.9929769580556, 'gapD': 44.99970737325231, 'exp': '?y-+1.5m-?d-?H:?M:00S'}]
# 两个半月
# [{'pattern': '两个半月', 'time': datetime.datetime(2018, 11, 25, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 6479974.716432, 'gapH': 1799.9929767866665, 'gapD': 74.99970736611111, 'exp': '?y-+2.5m-?d-?H:?M:00S'}]
# 2个半月
# [{'pattern': '2个半月', 'time': datetime.datetime(2018, 11, 25, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 6479974.715829, 'gapH': 1799.9929766191667, 'gapD': 74.99970735913195, 'exp': '?y-+2.5m-?d-?H:?M:00S'}]
# 三个月
# [{'pattern': '三个月', 'time': datetime.datetime(2018, 12, 10, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 7775974.715224, 'gapH': 2159.992976451111, 'gapD': 89.99970735212963, 'exp': '?y-+3m-?d-?H:?M:00S'}]
# 3个月
# [{'pattern': '3个月', 'time': datetime.datetime(2018, 12, 10, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 7775974.714629, 'gapH': 2159.9929762858333, 'gapD': 89.99970734524305, 'exp': '?y-+3m-?d-?H:?M:00S'}]
# 三个半月
# [{'pattern': '三个半月', 'time': datetime.datetime(2018, 12, 25, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 9071974.714023, 'gapH': 2519.9929761175, 'gapD': 104.99970733822916, 'exp': '?y-+3.5m-?d-?H:?M:00S'}]
# 3个半月
# [{'pattern': '3个半月', 'time': datetime.datetime(2018, 12, 25, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 9071974.713425, 'gapH': 2519.992975951389, 'gapD': 104.99970733130787, 'exp': '?y-+3.5m-?d-?H:?M:00S'}]
# 四个月
# [{'pattern': '四个月', 'time': datetime.datetime(2019, 1, 9, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 10367974.712822, 'gapH': 2879.9929757838886, 'gapD': 119.9997073243287, 'exp': '?y-+4m-?d-?H:?M:00S'}]
# 4个月
# [{'pattern': '4个月', 'time': datetime.datetime(2019, 1, 9, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 10367974.712228, 'gapH': 2879.992975618889, 'gapD': 119.99970731745371, 'exp': '?y-+4m-?d-?H:?M:00S'}]
# 四个半月
# [{'pattern': '四个半月', 'time': datetime.datetime(2019, 1, 24, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 11663974.711609, 'gapH': 3239.9929754469445, 'gapD': 134.99970731028935, 'exp': '?y-+4.5m-?d-?H:?M:00S'}]
# 4个半月
# [{'pattern': '4个半月', 'time': datetime.datetime(2019, 1, 24, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 11663974.71101, 'gapH': 3239.9929752805556, 'gapD': 134.99970730335647, 'exp': '?y-+4.5m-?d-?H:?M:00S'}]
# 五个月
# [{'pattern': '五个月', 'time': datetime.datetime(2019, 2, 8, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 12959974.71027, 'gapH': 3599.9929750750002, 'gapD': 149.99970729479168, 'exp': '?y-+5m-?d-?H:?M:00S'}]
# 5个月
# [{'pattern': '5个月', 'time': datetime.datetime(2019, 2, 8, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 12959974.709686, 'gapH': 3599.9929749127778, 'gapD': 149.9997072880324, 'exp': '?y-+5m-?d-?H:?M:00S'}]
# 五个半月
# [{'pattern': '五个半月', 'time': datetime.datetime(2019, 2, 23, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 14255974.7091, 'gapH': 3959.99297475, 'gapD': 164.99970728125, 'exp': '?y-+5.5m-?d-?H:?M:00S'}]
# 5个半月
# [{'pattern': '5个半月', 'time': datetime.datetime(2019, 2, 23, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 14255974.708522, 'gapH': 3959.992974589444, 'gapD': 164.99970727456017, 'exp': '?y-+5.5m-?d-?H:?M:00S'}]
# 六个月
# [{'pattern': '六个月', 'time': datetime.datetime(2019, 3, 10, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 15551974.707942, 'gapH': 4319.992974428334, 'gapD': 179.99970726784724, 'exp': '?y-+6m-?d-?H:?M:00S'}]
# 6个月
# [{'pattern': '6个月', 'time': datetime.datetime(2019, 3, 10, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 15551974.707131, 'gapH': 4319.992974203055, 'gapD': 179.99970725846063, 'exp': '?y-+6m-?d-?H:?M:00S'}]
# 六个半月
# [{'pattern': '六个半月', 'time': datetime.datetime(2019, 3, 25, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 16847974.706455, 'gapH': 4679.9929740152775, 'gapD': 194.99970725063656, 'exp': '?y-+6.5m-?d-?H:?M:00S'}]
# 6个半月
# [{'pattern': '6个半月', 'time': datetime.datetime(2019, 3, 25, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 16847974.705866, 'gapH': 4679.992973851667, 'gapD': 194.99970724381944, 'exp': '?y-+6.5m-?d-?H:?M:00S'}]
# 七个月
# [{'pattern': '七个月', 'time': datetime.datetime(2019, 4, 9, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 18143974.705195, 'gapH': 5039.9929736652775, 'gapD': 209.99970723605324, 'exp': '?y-+7m-?d-?H:?M:00S'}]
# 7个月
# [{'pattern': '7个月', 'time': datetime.datetime(2019, 4, 9, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 18143974.704285, 'gapH': 5039.9929734125, 'gapD': 209.99970722552084, 'exp': '?y-+7m-?d-?H:?M:00S'}]
# 七个半月
# [{'pattern': '七个半月', 'time': datetime.datetime(2019, 4, 24, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 19439974.703331, 'gapH': 5399.9929731475, 'gapD': 224.99970721447917, 'exp': '?y-+7.5m-?d-?H:?M:00S'}]
# 7个半月
# [{'pattern': '7个半月', 'time': datetime.datetime(2019, 4, 24, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 19439974.702704, 'gapH': 5399.992972973334, 'gapD': 224.99970720722226, 'exp': '?y-+7.5m-?d-?H:?M:00S'}]
# 八个月
# [{'pattern': '八个月', 'time': datetime.datetime(2019, 5, 9, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 20735974.702116, 'gapH': 5759.9929728100005, 'gapD': 239.99970720041668, 'exp': '?y-+8m-?d-?H:?M:00S'}]
# 8个月
# [{'pattern': '8个月', 'time': datetime.datetime(2019, 5, 9, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 20735974.701546, 'gapH': 5759.992972651667, 'gapD': 239.99970719381943, 'exp': '?y-+8m-?d-?H:?M:00S'}]
# 八个半月
# [{'pattern': '八个半月', 'time': datetime.datetime(2019, 5, 24, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 22031974.70096, 'gapH': 6119.992972488889, 'gapD': 254.99970718703705, 'exp': '?y-+8.5m-?d-?H:?M:00S'}]
# 8个半月
# [{'pattern': '8个半月', 'time': datetime.datetime(2019, 5, 24, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 22031974.700281, 'gapH': 6119.992972300278, 'gapD': 254.99970717917824, 'exp': '?y-+8.5m-?d-?H:?M:00S'}]
# 上半年
# [{'pattern': '上半年', 'time': datetime.datetime(2018, 5, 31, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -8935585.300233, 'gapH': -2482.1070278425004, 'gapD': -103.42112616010418, 'exp': '?y-5m-31d-12H:00M:00S'}]
# 前半年
# [{'pattern': '半年', 'time': datetime.datetime(2019, 3, 13, 10, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 15767974.699197, 'gapH': 4379.992971999167, 'gapD': 182.49970716663196, 'exp': '+0.5y-?m-?d-?H:?M:00S'}]
# 下半年
# [{'pattern': '下半年', 'time': datetime.datetime(2018, 12, 31, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 9554014.698687, 'gapH': 2653.8929718575, 'gapD': 110.57887382739584, 'exp': '?y-12m-31d-12H:00M:00S'}]
# 后半年
# [{'pattern': '半年', 'time': datetime.datetime(2019, 3, 13, 10, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 15767974.698183, 'gapH': 4379.9929717175, 'gapD': 182.49970715489584, 'exp': '+0.5y-?m-?d-?H:?M:00S'}]
# 年初
# [{'pattern': '年初', 'time': datetime.datetime(2018, 3, 31, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14205985.30231, 'gapH': -3946.1070284194443, 'gapD': -164.4211261841435, 'exp': '?y-3m-31d-12H:00M:00S'}]
# 年末
# [{'pattern': '末', 'time': datetime.datetime(2018, 9, 28, 22, 6, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1468774.697171, 'gapH': 407.9929714363889, 'gapD': 16.99970714318287, 'exp': '?y-?m-28d-?H:?M:00S'}]
# 年尾
# [{'pattern': '年尾', 'time': datetime.datetime(2018, 12, 31, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 9554014.696678, 'gapH': 2653.8929712994445, 'gapD': 110.57887380414353, 'exp': '?y-12m-31d-12H:00M:00S'}]
# 春天
# [{'pattern': '春天', 'time': datetime.datetime(2018, 5, 30, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -9021985.303811, 'gapH': -2506.107028836389, 'gapD': -104.4211262015162, 'exp': '?y-5m-30d-12H:00M:00S'}]
# 春季
# [{'pattern': '春季', 'time': datetime.datetime(2018, 5, 30, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -9021985.304299, 'gapH': -2506.1070289719446, 'gapD': -104.42112620716436, 'exp': '?y-5m-30d-12H:00M:00S'}]
# 夏天
# [{'pattern': '夏天', 'time': datetime.datetime(2018, 8, 30, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -1073185.304798, 'gapH': -298.1070291105556, 'gapD': -12.421126212939816, 'exp': '?y-8m-30d-12H:00M:00S'}]
# 夏季
# [{'pattern': '夏季', 'time': datetime.datetime(2018, 8, 30, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -1073185.305289, 'gapH': -298.1070292469445, 'gapD': -12.421126218622687, 'exp': '?y-8m-30d-12H:00M:00S'}]
# 秋天
# [{'pattern': '秋天', 'time': datetime.datetime(2018, 11, 30, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 6875614.694226, 'gapH': 1909.8929706183335, 'gapD': 79.5788737757639, 'exp': '?y-11m-30d-12H:00M:00S'}]
# 秋季
# [{'pattern': '秋季', 'time': datetime.datetime(2018, 11, 30, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 6875614.693746, 'gapH': 1909.892970485, 'gapD': 79.57887377020833, 'exp': '?y-11m-30d-12H:00M:00S'}]
# 冬天
# [{'pattern': '冬天', 'time': datetime.datetime(2018, 2, 28, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -16884385.306733, 'gapH': -4690.107029648056, 'gapD': -195.42112623533566, 'exp': '?y-2m-28d-12H:00M:00S'}]
# 冬季
# [{'pattern': '冬季', 'time': datetime.datetime(2018, 2, 28, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -16884385.307248, 'gapH': -4690.107029791111, 'gapD': -195.4211262412963, 'exp': '?y-2m-28d-12H:00M:00S'}]
# 一个季度
# [{'pattern': '一个季度', 'time': datetime.datetime(2018, 12, 10, 22, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 7775614.692015, 'gapH': 2159.8929700041667, 'gapD': 89.99554041684029, 'exp': '?y-+3m-?d-?H:00M:00S'}]
# 1个季度
# [{'pattern': '1个季度', 'time': datetime.datetime(2018, 12, 10, 22, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 7775614.69151, 'gapH': 2159.892969863889, 'gapD': 89.99554041099537, 'exp': '?y-+3m-?d-?H:00M:00S'}]
# 两个季度
# [{'pattern': '两个季度', 'time': datetime.datetime(2019, 3, 10, 22, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 15551614.690991, 'gapH': 4319.892969719722, 'gapD': 179.99554040498842, 'exp': '?y-+6m-?d-?H:00M:00S'}]
# 2个季度
# [{'pattern': '2个季度', 'time': datetime.datetime(2019, 3, 10, 22, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 15551614.69043, 'gapH': 4319.892969563889, 'gapD': 179.99554039849536, 'exp': '?y-+6m-?d-?H:00M:00S'}]
# 三个季度
# [{'pattern': '三个季度', 'time': datetime.datetime(2019, 6, 8, 22, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 23327614.689753, 'gapH': 6479.892969375834, 'gapD': 269.99554039065976, 'exp': '?y-+9m-?d-?H:00M:00S'}]
# 3个季度
# [{'pattern': '3个季度', 'time': datetime.datetime(2019, 6, 8, 22, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 23327614.689257, 'gapH': 6479.892969238055, 'gapD': 269.99554038491897, 'exp': '?y-+9m-?d-?H:00M:00S'}]
# 劳动节
# [{'pattern': '劳动节', 'time': datetime.datetime(2018, 5, 7, 22, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -10973185.31123, 'gapH': -3048.107030897222, 'gapD': -127.00445962071758, 'exp': '?y-5m-7d-?H:00M:00S'}]
# 国庆节
# [{'pattern': '国庆节', 'time': datetime.datetime(2018, 10, 7, 22, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 2246014.688281, 'gapH': 623.8929689669445, 'gapD': 25.99554037362269, 'exp': '?y-10m-7d-?H:00M:00S'}]
# 下辈子
# [{'pattern': '下辈子', 'time': datetime.datetime(2118, 8, 18, 22, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 3153599614.687792, 'gapH': 875999.8929688311, 'gapD': 36499.99554036796, 'exp': '+100y-?m-?d-?H:00M:00S'}]
# 一周后
# [{'pattern': '一周', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590014.686749, 'gapH': 163.89296854138888, 'gapD': 6.828873689224537, 'exp': '?y-+1W-?w-18H:00M:00S'}]
# 一周内
# [{'pattern': '一周', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590014.684597, 'gapH': 163.89296794361113, 'gapD': 6.82887366431713, 'exp': '?y-+1W-?w-18H:00M:00S'}]
# 1周后
# [{'pattern': '1周', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590014.683952, 'gapH': 163.89296776444445, 'gapD': 6.828873656851852, 'exp': '?y-+1W-?w-18H:00M:00S'}]
# 2周后
# [{'pattern': '2周', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1194814.683351, 'gapH': 331.89296759750005, 'gapD': 13.828873649895835, 'exp': '?y-+2W-?w-18H:00M:00S'}]
# 两周后
# [{'pattern': '两周', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1194814.682745, 'gapH': 331.8929674291667, 'gapD': 13.828873642881945, 'exp': '?y-+2W-?w-18H:00M:00S'}]
# 下周
# [{'pattern': '下周', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590014.682148, 'gapH': 163.89296726333333, 'gapD': 6.828873635972222, 'exp': '?y-^1W-?w-18H:00M:00S'}]
# 周三
# [{'pattern': '周三', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 71614.681557, 'gapH': 19.89296709916667, 'gapD': 0.8288736291319445, 'exp': '?y-?W-3w-18H:00M:00S'}]
# 下周一
# [{'pattern': '下周一', 'time': datetime.datetime(2018, 9, 17, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 503614.680964, 'gapH': 139.89296693444444, 'gapD': 5.828873622268518, 'exp': '?y-^1W-1w-18H:00M:00S'}]
# 下周1
# [{'pattern': '下周1', 'time': datetime.datetime(2018, 9, 17, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 503614.680366, 'gapH': 139.89296676833334, 'gapD': 5.828873615347223, 'exp': '?y-^1W-1w-18H:00M:00S'}]
# 下周一早上
# [{'pattern': '下周一早上', 'time': datetime.datetime(2018, 9, 17, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 478414.679656, 'gapH': 132.89296657111112, 'gapD': 5.537206940462963, 'exp': '?y-^1W-1w-11H:00M:00S'}]
# 下周1早上
# [{'pattern': '下周1早上', 'time': datetime.datetime(2018, 9, 17, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 478414.679029, 'gapH': 132.89296639694444, 'gapD': 5.5372069332060185, 'exp': '?y-^1W-1w-11H:00M:00S'}]
# 下周一下午
# [{'pattern': '下周一下午', 'time': datetime.datetime(2018, 9, 17, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 503614.67839, 'gapH': 139.89296621944445, 'gapD': 5.828873592476852, 'exp': '?y-^1W-1w-18H:00M:00S'}]
# 下周1下午
# [{'pattern': '下周1下午', 'time': datetime.datetime(2018, 9, 17, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 503614.677744, 'gapH': 139.89296604, 'gapD': 5.828873585, 'exp': '?y-^1W-1w-18H:00M:00S'}]
# 下下周一
# [{'pattern': '下下周一', 'time': datetime.datetime(2018, 9, 24, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1108414.677106, 'gapH': 307.89296586277777, 'gapD': 12.82887357761574, 'exp': '?y-^2W-1w-18H:00M:00S'}]
# 下下周1
# [{'pattern': '下下周1', 'time': datetime.datetime(2018, 9, 24, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1108414.675665, 'gapH': 307.8929654625, 'gapD': 12.8288735609375, 'exp': '?y-^2W-1w-18H:00M:00S'}]
# 下周二
# [{'pattern': '下周二', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590014.673863, 'gapH': 163.89296496194444, 'gapD': 6.828873540081019, 'exp': '?y-^1W-2w-18H:00M:00S'}]
# 下周2
# [{'pattern': '下周2', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590014.671177, 'gapH': 163.89296421583333, 'gapD': 6.8288735089930555, 'exp': '?y-^1W-2w-18H:00M:00S'}]
# 下周二下午
# [{'pattern': '下周二下午', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590014.669465, 'gapH': 163.8929637402778, 'gapD': 6.828873489178242, 'exp': '?y-^1W-2w-18H:00M:00S'}]
# 下周2下午
# [{'pattern': '下周2下午', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590014.667684, 'gapH': 163.89296324555556, 'gapD': 6.828873468564815, 'exp': '?y-^1W-2w-18H:00M:00S'}]
# 下周二早上
# [{'pattern': '下周二早上', 'time': datetime.datetime(2018, 9, 18, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 564814.664935, 'gapH': 156.89296248194444, 'gapD': 6.537206770081018, 'exp': '?y-^1W-2w-11H:00M:00S'}]
# 下周2早上
# [{'pattern': '下周2早上', 'time': datetime.datetime(2018, 9, 18, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 564814.662899, 'gapH': 156.89296191638888, 'gapD': 6.537206746516204, 'exp': '?y-^1W-2w-11H:00M:00S'}]
# 下下周二
# [{'pattern': '下下周二', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1194814.661697, 'gapH': 331.8929615825, 'gapD': 13.828873399270833, 'exp': '?y-^2W-2w-18H:00M:00S'}]
# 下下周2
# [{'pattern': '下下周2', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1194814.660709, 'gapH': 331.89296130805553, 'gapD': 13.828873387835648, 'exp': '?y-^2W-2w-18H:00M:00S'}]
# 下周三
# [{'pattern': '下周三', 'time': datetime.datetime(2018, 9, 19, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 676414.659754, 'gapH': 187.89296104277778, 'gapD': 7.828873376782408, 'exp': '?y-^1W-3w-18H:00M:00S'}]
# 下周3
# [{'pattern': '下周3', 'time': datetime.datetime(2018, 9, 19, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 676414.658482, 'gapH': 187.89296068944444, 'gapD': 7.828873362060185, 'exp': '?y-^1W-3w-18H:00M:00S'}]
# 下周三早上
# [{'pattern': '下周三早上', 'time': datetime.datetime(2018, 9, 19, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 651214.657309, 'gapH': 180.8929603636111, 'gapD': 7.537206681817129, 'exp': '?y-^1W-3w-11H:00M:00S'}]
# 下周3早上
# [{'pattern': '下周3早上', 'time': datetime.datetime(2018, 9, 19, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 651214.655221, 'gapH': 180.8929597836111, 'gapD': 7.537206657650462, 'exp': '?y-^1W-3w-11H:00M:00S'}]
# 下周三下午
# [{'pattern': '下周三下午', 'time': datetime.datetime(2018, 9, 19, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 676414.65389, 'gapH': 187.8929594138889, 'gapD': 7.828873308912037, 'exp': '?y-^1W-3w-18H:00M:00S'}]
# 下周3下午
# [{'pattern': '下周3下午', 'time': datetime.datetime(2018, 9, 19, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 676414.652535, 'gapH': 187.8929590375, 'gapD': 7.828873293229166, 'exp': '?y-^1W-3w-18H:00M:00S'}]
# 下下周三
# [{'pattern': '下下周三', 'time': datetime.datetime(2018, 9, 26, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1281214.651731, 'gapH': 355.89295881416666, 'gapD': 14.828873283923611, 'exp': '?y-^2W-3w-18H:00M:00S'}]
# 下下周3
# [{'pattern': '下下周3', 'time': datetime.datetime(2018, 9, 26, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1281214.651087, 'gapH': 355.8929586352778, 'gapD': 14.828873276469908, 'exp': '?y-^2W-3w-18H:00M:00S'}]
# 下周四
# [{'pattern': '下周四', 'time': datetime.datetime(2018, 9, 20, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 762814.650456, 'gapH': 211.89295846, 'gapD': 8.828873269166666, 'exp': '?y-^1W-4w-18H:00M:00S'}]
# 下周4
# [{'pattern': '下周4', 'time': datetime.datetime(2018, 9, 20, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 762814.649824, 'gapH': 211.89295828444443, 'gapD': 8.828873261851852, 'exp': '?y-^1W-4w-18H:00M:00S'}]
# 下周四早上
# [{'pattern': '下周四早上', 'time': datetime.datetime(2018, 9, 20, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 737614.649182, 'gapH': 204.8929581061111, 'gapD': 8.53720658775463, 'exp': '?y-^1W-4w-11H:00M:00S'}]
# 下周4早上
# [{'pattern': '下周4早上', 'time': datetime.datetime(2018, 9, 20, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 737614.648542, 'gapH': 204.89295792833332, 'gapD': 8.537206580347222, 'exp': '?y-^1W-4w-11H:00M:00S'}]
# 下周四下午
# [{'pattern': '下周四下午', 'time': datetime.datetime(2018, 9, 20, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 762814.647897, 'gapH': 211.89295774916667, 'gapD': 8.828873239548612, 'exp': '?y-^1W-4w-18H:00M:00S'}]
# 下周4下午
# [{'pattern': '下周4下午', 'time': datetime.datetime(2018, 9, 20, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 762814.647272, 'gapH': 211.89295757555556, 'gapD': 8.828873232314814, 'exp': '?y-^1W-4w-18H:00M:00S'}]
# 下下周四
# [{'pattern': '下下周四', 'time': datetime.datetime(2018, 9, 27, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1367614.646658, 'gapH': 379.892957405, 'gapD': 15.828873225208334, 'exp': '?y-^2W-4w-18H:00M:00S'}]
# 下下周4
# [{'pattern': '下下周4', 'time': datetime.datetime(2018, 9, 27, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1367614.646031, 'gapH': 379.8929572308333, 'gapD': 15.828873217951388, 'exp': '?y-^2W-4w-18H:00M:00S'}]
# 下周五
# [{'pattern': '下周五', 'time': datetime.datetime(2018, 9, 21, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 849214.645418, 'gapH': 235.89295706055555, 'gapD': 9.82887321085648, 'exp': '?y-^1W-5w-18H:00M:00S'}]
# 下周5
# [{'pattern': '下周5', 'time': datetime.datetime(2018, 9, 21, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 849214.644811, 'gapH': 235.89295689194444, 'gapD': 9.828873203831018, 'exp': '?y-^1W-5w-18H:00M:00S'}]
# 下周五早上
# [{'pattern': '下周五早上', 'time': datetime.datetime(2018, 9, 21, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 824014.644187, 'gapH': 228.89295671861112, 'gapD': 9.53720652994213, 'exp': '?y-^1W-5w-11H:00M:00S'}]
# 下周5早上
# [{'pattern': '下周5早上', 'time': datetime.datetime(2018, 9, 21, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 824014.643562, 'gapH': 228.892956545, 'gapD': 9.537206522708333, 'exp': '?y-^1W-5w-11H:00M:00S'}]
# 下周五下午
# [{'pattern': '下周五下午', 'time': datetime.datetime(2018, 9, 21, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 849214.642936, 'gapH': 235.89295637111113, 'gapD': 9.82887318212963, 'exp': '?y-^1W-5w-18H:00M:00S'}]
# 下周5下午
# [{'pattern': '下周5下午', 'time': datetime.datetime(2018, 9, 21, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 849214.642031, 'gapH': 235.89295611972221, 'gapD': 9.828873171655092, 'exp': '?y-^1W-5w-18H:00M:00S'}]
# 下下周五
# [{'pattern': '下下周五', 'time': datetime.datetime(2018, 9, 28, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1454014.64103, 'gapH': 403.89295584166666, 'gapD': 16.828873160069445, 'exp': '?y-^2W-5w-18H:00M:00S'}]
# 下下周5
# [{'pattern': '下下周5', 'time': datetime.datetime(2018, 9, 28, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1454014.63936, 'gapH': 403.89295537777775, 'gapD': 16.82887314074074, 'exp': '?y-^2W-5w-18H:00M:00S'}]
# 这周内
# [{'pattern': '这周', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14785.361241, 'gapH': -4.107044789166666, 'gapD': -0.17112686621527776, 'exp': '?y-?W-?w-18H:00M:00S'}]
# 这星期内
# [{'pattern': '这星期', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14785.363181, 'gapH': -4.1070453280555554, 'gapD': -0.17112688866898149, 'exp': '?y-?W-?w-18H:00M:00S'}]
# 这礼拜内内
# [{'pattern': '这礼拜', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14785.363829, 'gapH': -4.107045508055555, 'gapD': -0.17112689616898147, 'exp': '?y-?W-?w-18H:00M:00S'}]
# 下周内
# [{'pattern': '下周', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590014.635773, 'gapH': 163.89295438138888, 'gapD': 6.828873099224537, 'exp': '?y-^1W-?w-18H:00M:00S'}]
# 下星期内
# [{'pattern': '下星期', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590014.635467, 'gapH': 163.89295429638887, 'gapD': 6.828873095682869, 'exp': '?y-^1W-?w-18H:00M:00S'}]
# 下礼拜内
# [{'pattern': '下礼拜', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590014.635186, 'gapH': 163.89295421833333, 'gapD': 6.828873092430555, 'exp': '?y-^1W-?w-18H:00M:00S'}]
# 下下周
# [{'pattern': '下下周', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1194814.634814, 'gapH': 331.892954115, 'gapD': 13.828873088125, 'exp': '?y-^2W-?w-18H:00M:00S'}]
# 下下星期
# [{'pattern': '下下星期', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1194814.634489, 'gapH': 331.89295402472226, 'gapD': 13.828873084363428, 'exp': '?y-^2W-?w-18H:00M:00S'}]
# 下下礼拜
# [{'pattern': '下下礼拜', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1194814.634192, 'gapH': 331.8929539422222, 'gapD': 13.828873080925925, 'exp': '?y-^2W-?w-18H:00M:00S'}]
# 下下下周
# [{'pattern': '下下周', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1194814.633897, 'gapH': 331.89295386027777, 'gapD': 13.828873077511574, 'exp': '?y-^2W-?w-18H:00M:00S'}]
# 下下下星期
# [{'pattern': '下下星期', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1194814.633517, 'gapH': 331.8929537547222, 'gapD': 13.828873073113426, 'exp': '?y-^2W-?w-18H:00M:00S'}]
# 下下下礼拜
# [{'pattern': '下下礼拜', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1194814.63314, 'gapH': 331.89295365000004, 'gapD': 13.828873068750001, 'exp': '?y-^2W-?w-18H:00M:00S'}]
# 两周内
# [{'pattern': '两周', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1194814.632704, 'gapH': 331.8929535288889, 'gapD': 13.828873063703703, 'exp': '?y-+2W-?w-18H:00M:00S'}]
# 这周二
# [{'pattern': '这周二', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14785.3678, 'gapH': -4.1070466111111115, 'gapD': -0.17112694212962964, 'exp': '?y-?W-2w-18H:00M:00S'}]
# 这周2
# [{'pattern': '这周2', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14785.368228, 'gapH': -4.1070467299999995, 'gapD': -0.17112694708333331, 'exp': '?y-?W-2w-18H:00M:00S'}]
# 这周二早上
# [{'pattern': '这周二早上', 'time': datetime.datetime(2018, 9, 11, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -39985.368554, 'gapH': -11.107046820555556, 'gapD': -0.4627936175231482, 'exp': '?y-?W-2w-11H:00M:00S'}]
# 这周2早上
# [{'pattern': '这周2早上', 'time': datetime.datetime(2018, 9, 11, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -39985.368971, 'gapH': -11.10704693638889, 'gapD': -0.4627936223495371, 'exp': '?y-?W-2w-11H:00M:00S'}]
# 这周二下午
# [{'pattern': '这周二下午', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14785.369579, 'gapH': -4.107047105277778, 'gapD': -0.17112696271990743, 'exp': '?y-?W-2w-18H:00M:00S'}]
# 这周2下午
# [{'pattern': '这周2下午', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14785.370007, 'gapH': -4.107047224166666, 'gapD': -0.1711269676736111, 'exp': '?y-?W-2w-18H:00M:00S'}]
# 这周三
# [{'pattern': '这周三', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 71614.629629, 'gapH': 19.892952674722224, 'gapD': 0.828873028113426, 'exp': '?y-?W-3w-18H:00M:00S'}]
# 这周3
# [{'pattern': '这周3', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 71614.629213, 'gapH': 19.892952559166666, 'gapD': 0.8288730232986111, 'exp': '?y-?W-3w-18H:00M:00S'}]
# 这周三早上
# [{'pattern': '这周三早上', 'time': datetime.datetime(2018, 9, 12, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 46414.628519, 'gapH': 12.892952366388888, 'gapD': 0.537206348599537, 'exp': '?y-?W-3w-11H:00M:00S'}]
# 这周3早上
# [{'pattern': '这周3早上', 'time': datetime.datetime(2018, 9, 12, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 46414.627723, 'gapH': 12.892952145277777, 'gapD': 0.537206339386574, 'exp': '?y-?W-3w-11H:00M:00S'}]
# 这周三下午
# [{'pattern': '这周三下午', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 71614.627336, 'gapH': 19.89295203777778, 'gapD': 0.8288730015740741, 'exp': '?y-?W-3w-18H:00M:00S'}]
# 这周四
# [{'pattern': '这周四', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 158014.626951, 'gapH': 43.892951930833334, 'gapD': 1.8288729971180555, 'exp': '?y-?W-4w-18H:00M:00S'}]
# 这周4
# [{'pattern': '这周4', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 158014.626018, 'gapH': 43.89295167166667, 'gapD': 1.8288729863194446, 'exp': '?y-?W-4w-18H:00M:00S'}]
# 这周四早上
# [{'pattern': '这周四早上', 'time': datetime.datetime(2018, 9, 13, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 132814.625447, 'gapH': 36.89295151305556, 'gapD': 1.5372063130439815, 'exp': '?y-?W-4w-11H:00M:00S'}]
# 这周4早上
# [{'pattern': '这周4早上', 'time': datetime.datetime(2018, 9, 13, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 132814.625075, 'gapH': 36.89295140972222, 'gapD': 1.537206308738426, 'exp': '?y-?W-4w-11H:00M:00S'}]
# 这周四下午
# [{'pattern': '这周四下午', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 158014.624594, 'gapH': 43.89295127611111, 'gapD': 1.828872969837963, 'exp': '?y-?W-4w-18H:00M:00S'}]
# 这周4下午
# [{'pattern': '这周4下午', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 158014.624009, 'gapH': 43.89295111361111, 'gapD': 1.8288729630671297, 'exp': '?y-?W-4w-18H:00M:00S'}]
# 这周五
# [{'pattern': '这周五', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 244414.623659, 'gapH': 67.89295101638889, 'gapD': 2.828872959016204, 'exp': '?y-?W-5w-18H:00M:00S'}]
# 这周5
# [{'pattern': '这周5', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 244414.623382, 'gapH': 67.89295093944445, 'gapD': 2.8288729558101853, 'exp': '?y-?W-5w-18H:00M:00S'}]
# 这周五早上
# [{'pattern': '这周五早上', 'time': datetime.datetime(2018, 9, 14, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 219214.623099, 'gapH': 60.89295086083333, 'gapD': 2.5372062858680553, 'exp': '?y-?W-5w-11H:00M:00S'}]
# 这周5早上
# [{'pattern': '这周5早上', 'time': datetime.datetime(2018, 9, 14, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 219214.622825, 'gapH': 60.892950784722224, 'gapD': 2.537206282696759, 'exp': '?y-?W-5w-11H:00M:00S'}]
# 这周五下午
# [{'pattern': '这周五下午', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 244414.622523, 'gapH': 67.89295070083334, 'gapD': 2.828872945868056, 'exp': '?y-?W-5w-18H:00M:00S'}]
# 这周5下午
# [{'pattern': '这周5下午', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 244414.62225, 'gapH': 67.892950625, 'gapD': 2.8288729427083332, 'exp': '?y-?W-5w-18H:00M:00S'}]
# 星期二
# [{'pattern': '星期二', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14785.378011, 'gapH': -4.107049447500001, 'gapD': -0.17112706031250002, 'exp': '?y-?W-2w-18H:00M:00S'}]
# 星期2
# [{'pattern': '星期2', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14785.378267, 'gapH': -4.107049518611111, 'gapD': -0.17112706327546298, 'exp': '?y-?W-2w-18H:00M:00S'}]
# 礼拜二
# [{'pattern': '礼拜二', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14785.378617, 'gapH': -4.107049615833334, 'gapD': -0.1711270673263889, 'exp': '?y-?W-2w-18H:00M:00S'}]
# 礼拜2
# [{'pattern': '礼拜2', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14785.379009, 'gapH': -4.107049724722223, 'gapD': -0.17112707186342593, 'exp': '?y-?W-2w-18H:00M:00S'}]
# 星期三
# [{'pattern': '星期三', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 71614.620586, 'gapH': 19.89295016277778, 'gapD': 0.8288729234490742, 'exp': '?y-?W-3w-18H:00M:00S'}]
# 星期3
# [{'pattern': '星期3', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 71614.620081, 'gapH': 19.8929500225, 'gapD': 0.8288729176041666, 'exp': '?y-?W-3w-18H:00M:00S'}]
# 礼拜三
# [{'pattern': '礼拜三', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 71614.619523, 'gapH': 19.8929498675, 'gapD': 0.8288729111458334, 'exp': '?y-?W-3w-18H:00M:00S'}]
# 礼拜3
# [{'pattern': '礼拜3', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 71614.619088, 'gapH': 19.89294974666667, 'gapD': 0.8288729061111112, 'exp': '?y-?W-3w-18H:00M:00S'}]
# 星期四
# [{'pattern': '星期四', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 158014.618807, 'gapH': 43.89294966861111, 'gapD': 1.8288729028587962, 'exp': '?y-?W-4w-18H:00M:00S'}]
# 星期4
# [{'pattern': '星期4', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 158014.61854, 'gapH': 43.892949594444445, 'gapD': 1.8288728997685186, 'exp': '?y-?W-4w-18H:00M:00S'}]
# 礼拜4
# [{'pattern': '礼拜4', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 158014.618278, 'gapH': 43.89294952166667, 'gapD': 1.8288728967361114, 'exp': '?y-?W-4w-18H:00M:00S'}]
# 礼拜四
# [{'pattern': '礼拜四', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 158014.618008, 'gapH': 43.89294944666666, 'gapD': 1.828872893611111, 'exp': '?y-?W-4w-18H:00M:00S'}]
# 星期五
# [{'pattern': '星期五', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 244414.617736, 'gapH': 67.8929493711111, 'gapD': 2.8288728904629625, 'exp': '?y-?W-5w-18H:00M:00S'}]
# 星期5
# [{'pattern': '星期5', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 244414.61726, 'gapH': 67.89294923888889, 'gapD': 2.8288728849537037, 'exp': '?y-?W-5w-18H:00M:00S'}]
# 礼拜五
# [{'pattern': '礼拜五', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 244414.616913, 'gapH': 67.8929491425, 'gapD': 2.8288728809375, 'exp': '?y-?W-5w-18H:00M:00S'}]
# 礼拜5
# [{'pattern': '礼拜5', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 244414.616642, 'gapH': 67.89294906722222, 'gapD': 2.828872877800926, 'exp': '?y-?W-5w-18H:00M:00S'}]
# 下个星期一
# [{'pattern': '下个星期一', 'time': datetime.datetime(2018, 9, 17, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 503614.616368, 'gapH': 139.8929489911111, 'gapD': 5.828872874629629, 'exp': '?y-^1W-1w-18H:00M:00S'}]
# 下个礼拜一
# [{'pattern': '下个礼拜一', 'time': datetime.datetime(2018, 9, 17, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 503614.616089, 'gapH': 139.89294891361112, 'gapD': 5.828872871400463, 'exp': '?y-^1W-1w-18H:00M:00S'}]
# 下个星期1
# [{'pattern': '下个星期1', 'time': datetime.datetime(2018, 9, 17, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 503614.615821, 'gapH': 139.89294883916668, 'gapD': 5.828872868298611, 'exp': '?y-^1W-1w-18H:00M:00S'}]
# 下个礼拜1
# [{'pattern': '下个礼拜1', 'time': datetime.datetime(2018, 9, 17, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 503614.615558, 'gapH': 139.89294876611112, 'gapD': 5.82887286525463, 'exp': '?y-^1W-1w-18H:00M:00S'}]
# 下个星期一早上
# [{'pattern': '下个星期一早上', 'time': datetime.datetime(2018, 9, 17, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 478414.615214, 'gapH': 132.89294867055554, 'gapD': 5.537206194606481, 'exp': '?y-^1W-1w-11H:00M:00S'}]
# 下个礼拜一早上
# [{'pattern': '下个礼拜一早上', 'time': datetime.datetime(2018, 9, 17, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 478414.614872, 'gapH': 132.89294857555555, 'gapD': 5.537206190648148, 'exp': '?y-^1W-1w-11H:00M:00S'}]
# 下个星期1早上
# [{'pattern': '下个星期1早上', 'time': datetime.datetime(2018, 9, 17, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 478414.614509, 'gapH': 132.8929484747222, 'gapD': 5.537206186446759, 'exp': '?y-^1W-1w-11H:00M:00S'}]
# 下个礼拜1早上
# [{'pattern': '下个礼拜1早上', 'time': datetime.datetime(2018, 9, 17, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 478414.614161, 'gapH': 132.89294837805556, 'gapD': 5.5372061824189815, 'exp': '?y-^1W-1w-11H:00M:00S'}]
# 下下个星期一
# [{'pattern': '下下个星期一', 'time': datetime.datetime(2018, 9, 24, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1108414.613818, 'gapH': 307.8929482827778, 'gapD': 12.828872845115741, 'exp': '?y-^2W-1w-18H:00M:00S'}]
# 下下个礼拜一
# [{'pattern': '下下个礼拜一', 'time': datetime.datetime(2018, 9, 24, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1108414.612839, 'gapH': 307.8929480108334, 'gapD': 12.828872833784724, 'exp': '?y-^2W-1w-18H:00M:00S'}]
# 下下个星期1
# [{'pattern': '下下个星期1', 'time': datetime.datetime(2018, 9, 24, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1108414.612384, 'gapH': 307.8929478844445, 'gapD': 12.82887282851852, 'exp': '?y-^2W-1w-18H:00M:00S'}]
# 下下个礼拜1
# [{'pattern': '下下个礼拜1', 'time': datetime.datetime(2018, 9, 24, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1108414.611995, 'gapH': 307.8929477763889, 'gapD': 12.828872824016203, 'exp': '?y-^2W-1w-18H:00M:00S'}]
# 下个星期二
# [{'pattern': '下个星期二', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590014.611591, 'gapH': 163.89294766416666, 'gapD': 6.828872819340277, 'exp': '?y-^1W-2w-18H:00M:00S'}]
# 下个礼拜二
# [{'pattern': '下个礼拜二', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590014.611272, 'gapH': 163.89294757555555, 'gapD': 6.828872815648148, 'exp': '?y-^1W-2w-18H:00M:00S'}]
# 下个星期2
# [{'pattern': '下个星期2', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590014.610896, 'gapH': 163.8929474711111, 'gapD': 6.828872811296296, 'exp': '?y-^1W-2w-18H:00M:00S'}]
# 下个礼拜2
# [{'pattern': '下个礼拜2', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590014.609649, 'gapH': 163.8929471247222, 'gapD': 6.8288727968634255, 'exp': '?y-^1W-2w-18H:00M:00S'}]
# 下个星期二早上
# [{'pattern': '下个星期二早上', 'time': datetime.datetime(2018, 9, 18, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 564814.609213, 'gapH': 156.8929470036111, 'gapD': 6.537206125150463, 'exp': '?y-^1W-2w-11H:00M:00S'}]
# 下个礼拜二早上
# [{'pattern': '下个礼拜二早上', 'time': datetime.datetime(2018, 9, 18, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 564814.608888, 'gapH': 156.89294691333333, 'gapD': 6.537206121388889, 'exp': '?y-^1W-2w-11H:00M:00S'}]
# 下个星期2早上
# [{'pattern': '下个星期2早上', 'time': datetime.datetime(2018, 9, 18, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 564814.608607, 'gapH': 156.89294683527777, 'gapD': 6.537206118136574, 'exp': '?y-^1W-2w-11H:00M:00S'}]
# 下个礼拜2早上
# [{'pattern': '下个礼拜2早上', 'time': datetime.datetime(2018, 9, 18, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 564814.608317, 'gapH': 156.8929467547222, 'gapD': 6.5372061147800915, 'exp': '?y-^1W-2w-11H:00M:00S'}]
# 下下个星期二
# [{'pattern': '下下个星期二', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1194814.608053, 'gapH': 331.8929466813889, 'gapD': 13.828872778391203, 'exp': '?y-^2W-2w-18H:00M:00S'}]
# 下下个礼拜二
# [{'pattern': '下下个礼拜二', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1194814.607795, 'gapH': 331.89294660972223, 'gapD': 13.828872775405094, 'exp': '?y-^2W-2w-18H:00M:00S'}]
# 下下个星期2
# ...
# 早上4点
# [{'pattern': '早上4点', 'time': datetime.datetime(2018, 9, 11, 4, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -65185.5564, 'gapH': -18.107099, 'gapD': -0.7544624583333334, 'exp': '?y-?m-?d-4H:00M:00S'}]
# 早上5点
# [{'pattern': '早上5点', 'time': datetime.datetime(2018, 9, 11, 5, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -61585.556707, 'gapH': -17.107099085277778, 'gapD': -0.7127957952199074, 'exp': '?y-?m-?d-5H:00M:00S'}]
# 早上6点
# [{'pattern': '早上6点', 'time': datetime.datetime(2018, 9, 11, 6, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -57985.556914, 'gapH': -16.107099142777777, 'gapD': -0.671129130949074, 'exp': '?y-?m-?d-6H:00M:00S'}]
# 早上7点
# [{'pattern': '早上7点', 'time': datetime.datetime(2018, 9, 11, 7, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -54385.557142, 'gapH': -15.10709920611111, 'gapD': -0.6294624669212963, 'exp': '?y-?m-?d-7H:00M:00S'}]
# 早上8点
# [{'pattern': '早上8点', 'time': datetime.datetime(2018, 9, 11, 8, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -50785.557356, 'gapH': -14.107099265555554, 'gapD': -0.5877958027314815, 'exp': '?y-?m-?d-8H:00M:00S'}]
# 早上9点
# [{'pattern': '早上9点', 'time': datetime.datetime(2018, 9, 11, 9, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -47185.557609, 'gapH': -13.107099335833334, 'gapD': -0.5461291389930556, 'exp': '?y-?m-?d-9H:00M:00S'}]
# 早上10点
# [{'pattern': '早上10点', 'time': datetime.datetime(2018, 9, 11, 10, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -43585.557838, 'gapH': -12.107099399444445, 'gapD': -0.5044624749768519, 'exp': '?y-?m-?d-10H:00M:00S'}]
# 早上11点
# [{'pattern': '早上11点', 'time': datetime.datetime(2018, 9, 11, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -39985.558006, 'gapH': -11.10709944611111, 'gapD': -0.4627958102546296, 'exp': '?y-?m-?d-11H:00M:00S'}]
# 早上一点
# [{'pattern': '早上一点', 'time': datetime.datetime(2018, 9, 11, 1, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -75985.558172, 'gapH': -21.107099492222222, 'gapD': -0.8794624788425925, 'exp': '?y-?m-?d-1H:00M:00S'}]
# 早上二点
# [{'pattern': '早上二点', 'time': datetime.datetime(2018, 9, 11, 2, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -72385.558334, 'gapH': -20.107099537222222, 'gapD': -0.837795814050926, 'exp': '?y-?m-?d-2H:00M:00S'}]
# 早上三点
# [{'pattern': '早上三点', 'time': datetime.datetime(2018, 9, 11, 3, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -68785.558495, 'gapH': -19.107099581944446, 'gapD': -0.7961291492476853, 'exp': '?y-?m-?d-3H:00M:00S'}]
# 早上四点
# [{'pattern': '早上四点', 'time': datetime.datetime(2018, 9, 11, 4, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -65185.559106, 'gapH': -18.107099751666667, 'gapD': -0.7544624896527777, 'exp': '?y-?m-?d-4H:00M:00S'}]
# 早上五点
# [{'pattern': '早上五点', 'time': datetime.datetime(2018, 9, 11, 5, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -61585.55938, 'gapH': -17.107099827777777, 'gapD': -0.7127958261574073, 'exp': '?y-?m-?d-5H:00M:00S'}]
# 早上六点
# [{'pattern': '早上六点', 'time': datetime.datetime(2018, 9, 11, 6, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -57985.559647, 'gapH': -16.107099901944444, 'gapD': -0.6711291625810185, 'exp': '?y-?m-?d-6H:00M:00S'}]
# 早上七点
# [{'pattern': '早上七点', 'time': datetime.datetime(2018, 9, 11, 7, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -54385.559908, 'gapH': -15.107099974444445, 'gapD': -0.6294624989351852, 'exp': '?y-?m-?d-7H:00M:00S'}]
# 早上八点
# [{'pattern': '早上八点', 'time': datetime.datetime(2018, 9, 11, 8, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -50785.560169, 'gapH': -14.107100046944444, 'gapD': -0.5877958352893519, 'exp': '?y-?m-?d-8H:00M:00S'}]
# 早上九点
# [{'pattern': '早上九点', 'time': datetime.datetime(2018, 9, 11, 9, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -47185.560447, 'gapH': -13.107100124166667, 'gapD': -0.5461291718402778, 'exp': '?y-?m-?d-9H:00M:00S'}]
# 早上十点
# [{'pattern': '早上十点', 'time': datetime.datetime(2018, 9, 11, 10, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -43585.560698, 'gapH': -12.10710019388889, 'gapD': -0.5044625080787037, 'exp': '?y-?m-?d-10H:00M:00S'}]
# 早上十一点
# [{'pattern': '早上十一点', 'time': datetime.datetime(2018, 9, 11, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -39985.560971, 'gapH': -11.107100269722222, 'gapD': -0.46279584457175926, 'exp': '?y-?m-?d-11H:00M:00S'}]
# 早晨1点
# [{'pattern': '早晨1点', 'time': datetime.datetime(2018, 9, 11, 1, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -75985.561238, 'gapH': -21.107100343888888, 'gapD': -0.8794625143287037, 'exp': '?y-?m-?d-1H:00M:00S'}]
# 早晨2点
# [{'pattern': '早晨2点', 'time': datetime.datetime(2018, 9, 11, 2, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -72385.561694, 'gapH': -20.107100470555558, 'gapD': -0.837795852939815, 'exp': '?y-?m-?d-2H:00M:00S'}]
# 早晨3点
# [{'pattern': '早晨3点', 'time': datetime.datetime(2018, 9, 11, 3, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -68785.561969, 'gapH': -19.107100546944444, 'gapD': -0.7961291894560185, 'exp': '?y-?m-?d-3H:00M:00S'}]
# 早晨4点
# [{'pattern': '早晨4点', 'time': datetime.datetime(2018, 9, 11, 4, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -65185.562221, 'gapH': -18.107100616944443, 'gapD': -0.7544625257060185, 'exp': '?y-?m-?d-4H:00M:00S'}]
# 早晨5点
# [{'pattern': '早晨5点', 'time': datetime.datetime(2018, 9, 11, 5, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -61585.562486, 'gapH': -17.107100690555555, 'gapD': -0.7127958621064815, 'exp': '?y-?m-?d-5H:00M:00S'}]
# 早晨6点
# [{'pattern': '早晨6点', 'time': datetime.datetime(2018, 9, 11, 6, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -57985.562731, 'gapH': -16.10710075861111, 'gapD': -0.6711291982754629, 'exp': '?y-?m-?d-6H:00M:00S'}]
# 早晨7点
# [{'pattern': '早晨7点', 'time': datetime.datetime(2018, 9, 11, 7, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -54385.563258, 'gapH': -15.107100905000001, 'gapD': -0.6294625377083334, 'exp': '?y-?m-?d-7H:00M:00S'}]
# 早晨8点
# [{'pattern': '早晨8点', 'time': datetime.datetime(2018, 9, 11, 8, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -50785.563484, 'gapH': -14.107100967777777, 'gapD': -0.5877958736574074, 'exp': '?y-?m-?d-8H:00M:00S'}]
# 早晨9点
# [{'pattern': '早晨9点', 'time': datetime.datetime(2018, 9, 11, 9, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -47185.56373, 'gapH': -13.107101036111112, 'gapD': -0.546129209837963, 'exp': '?y-?m-?d-9H:00M:00S'}]
# 早晨10点
# [{'pattern': '早晨10点', 'time': datetime.datetime(2018, 9, 11, 10, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -43585.563946, 'gapH': -12.107101096111112, 'gapD': -0.5044625456712963, 'exp': '?y-?m-?d-10H:00M:00S'}]
# 早晨11点
# [{'pattern': '早晨11点', 'time': datetime.datetime(2018, 9, 11, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -39985.564421, 'gapH': -11.107101228055557, 'gapD': -0.46279588450231485, 'exp': '?y-?m-?d-11H:00M:00S'}]
# 早晨一点
# [{'pattern': '早晨一点', 'time': datetime.datetime(2018, 9, 11, 1, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -75985.564725, 'gapH': -21.1071013125, 'gapD': -0.8794625546875, 'exp': '?y-?m-?d-1H:00M:00S'}]
# 早晨二点
# [{'pattern': '早晨二点', 'time': datetime.datetime(2018, 9, 11, 2, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -72385.565088, 'gapH': -20.107101413333336, 'gapD': -0.8377958922222223, 'exp': '?y-?m-?d-2H:00M:00S'}]
# 早晨三点
# [{'pattern': '早晨三点', 'time': datetime.datetime(2018, 9, 11, 3, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -68785.565392, 'gapH': -19.10710149777778, 'gapD': -0.7961292290740741, 'exp': '?y-?m-?d-3H:00M:00S'}]
# 早晨四点
# [{'pattern': '早晨四点', 'time': datetime.datetime(2018, 9, 11, 4, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -65185.565816, 'gapH': -18.107101615555557, 'gapD': -0.7544625673148149, 'exp': '?y-?m-?d-4H:00M:00S'}]
# 早晨五点
# [{'pattern': '早晨五点', 'time': datetime.datetime(2018, 9, 11, 5, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -61585.566057, 'gapH': -17.107101682499998, 'gapD': -0.7127959034374999, 'exp': '?y-?m-?d-5H:00M:00S'}]
# 早晨六点
# [{'pattern': '早晨六点', 'time': datetime.datetime(2018, 9, 11, 6, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -57985.566312, 'gapH': -16.107101753333335, 'gapD': -0.6711292397222223, 'exp': '?y-?m-?d-6H:00M:00S'}]
# 早晨七点
# [{'pattern': '早晨七点', 'time': datetime.datetime(2018, 9, 11, 7, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -54385.566563, 'gapH': -15.107101823055556, 'gapD': -0.6294625759606481, 'exp': '?y-?m-?d-7H:00M:00S'}]
# 早晨八点
# [{'pattern': '早晨八点', 'time': datetime.datetime(2018, 9, 11, 8, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -50785.566813, 'gapH': -14.1071018925, 'gapD': -0.5877959121874999, 'exp': '?y-?m-?d-8H:00M:00S'}]
# 早晨九点
# [{'pattern': '早晨九点', 'time': datetime.datetime(2018, 9, 11, 9, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -47185.56706, 'gapH': -13.10710196111111, 'gapD': -0.5461292483796296, 'exp': '?y-?m-?d-9H:00M:00S'}]
# 早晨十点
# [{'pattern': '早晨十点', 'time': datetime.datetime(2018, 9, 11, 10, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -43585.567579, 'gapH': -12.107102105277779, 'gapD': -0.5044625877199075, 'exp': '?y-?m-?d-10H:00M:00S'}]
# 早晨十一点
# [{'pattern': '早晨十一点', 'time': datetime.datetime(2018, 9, 11, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -39985.567814, 'gapH': -11.107102170555557, 'gapD': -0.4627959237731482, 'exp': '?y-?m-?d-11H:00M:00S'}]
# 下午1点
# [{'pattern': '下午1点', 'time': datetime.datetime(2018, 9, 11, 13, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -32785.568072, 'gapH': -9.107102242222222, 'gapD': -0.3794625934259259, 'exp': '?y-?m-?d-13H:00M:00S'}]
# 下午2点
# [{'pattern': '下午2点', 'time': datetime.datetime(2018, 9, 11, 14, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -29185.568324, 'gapH': -8.107102312222223, 'gapD': -0.3377959296759259, 'exp': '?y-?m-?d-14H:00M:00S'}]
# 下午3点
# [{'pattern': '下午3点', 'time': datetime.datetime(2018, 9, 11, 15, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -25585.568587, 'gapH': -7.107102385277778, 'gapD': -0.29612926605324075, 'exp': '?y-?m-?d-15H:00M:00S'}]
# 下午4点
# [{'pattern': '下午4点', 'time': datetime.datetime(2018, 9, 11, 16, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -21985.56882, 'gapH': -6.10710245, 'gapD': -0.2544626020833333, 'exp': '?y-?m-?d-16H:00M:00S'}]
# 下午5点
# [{'pattern': '下午5点', 'time': datetime.datetime(2018, 9, 11, 17, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -18385.569107, 'gapH': -5.107102529722222, 'gapD': -0.21279593873842592, 'exp': '?y-?m-?d-17H:00M:00S'}]
# 下午6点
# [{'pattern': '下午6点', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14785.569367, 'gapH': -4.107102601944445, 'gapD': -0.17112927508101852, 'exp': '?y-?m-?d-18H:00M:00S'}]
# 下午一点
# [{'pattern': '下午一点', 'time': datetime.datetime(2018, 9, 11, 13, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -32785.569626, 'gapH': -9.107102673888887, 'gapD': -0.37946261141203697, 'exp': '?y-?m-?d-13H:00M:00S'}]
# 下午二点
# [{'pattern': '下午二点', 'time': datetime.datetime(2018, 9, 11, 14, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -29185.569909, 'gapH': -8.107102752500001, 'gapD': -0.3377959480208334, 'exp': '?y-?m-?d-14H:00M:00S'}]
# 下午三点
# [{'pattern': '下午三点', 'time': datetime.datetime(2018, 9, 11, 15, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -25585.570164, 'gapH': -7.107102823333333, 'gapD': -0.2961292843055556, 'exp': '?y-?m-?d-15H:00M:00S'}]
# 下午四点
# [{'pattern': '下午四点', 'time': datetime.datetime(2018, 9, 11, 16, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -21985.570416, 'gapH': -6.107102893333333, 'gapD': -0.2544626205555555, 'exp': '?y-?m-?d-16H:00M:00S'}]
# 下午五点
# [{'pattern': '下午五点', 'time': datetime.datetime(2018, 9, 11, 17, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -18385.570682, 'gapH': -5.107102967222223, 'gapD': -0.2127959569675926, 'exp': '?y-?m-?d-17H:00M:00S'}]
# 下午六点
# [{'pattern': '下午六点', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14785.570952, 'gapH': -4.1071030422222226, 'gapD': -0.17112929342592595, 'exp': '?y-?m-?d-18H:00M:00S'}]
# 晚上6点
# [{'pattern': '晚上6点', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14785.5712, 'gapH': -4.107103111111111, 'gapD': -0.17112929629629628, 'exp': '?y-?m-?d-18H:00M:00S'}]
# 晚上7点
# [{'pattern': '晚上7点', 'time': datetime.datetime(2018, 9, 11, 19, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -11185.571463, 'gapH': -3.1071031841666668, 'gapD': -0.1294626326736111, 'exp': '?y-?m-?d-19H:00M:00S'}]
# 晚上8点
# [{'pattern': '晚上8点', 'time': datetime.datetime(2018, 9, 11, 20, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -7585.571717, 'gapH': -2.1071032547222224, 'gapD': -0.08779596894675927, 'exp': '?y-?m-?d-20H:00M:00S'}]
# 晚上9点
# [{'pattern': '晚上9点', 'time': datetime.datetime(2018, 9, 11, 21, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -3985.571934, 'gapH': -1.107103315, 'gapD': -0.046129304791666666, 'exp': '?y-?m-?d-21H:00M:00S'}]
# 晚上10点
# [{'pattern': '晚上10点', 'time': datetime.datetime(2018, 9, 11, 22, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -385.572444, 'gapH': -0.10710345666666667, 'gapD': -0.0044626440277777775, 'exp': '?y-?m-?d-22H:00M:00S'}]
# 晚上11点
# [{'pattern': '晚上11点', 'time': datetime.datetime(2018, 9, 11, 23, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 3214.427324, 'gapH': 0.8928964788888889, 'gapD': 0.037204019953703704, 'exp': '?y-?m-?d-23H:00M:00S'}]
# 晚上12点
# [{'pattern': '晚上12点', 'time': datetime.datetime(2018, 9, 11, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -36385.572929, 'gapH': -10.10710359138889, 'gapD': -0.4211293163078704, 'exp': '?y-?m-?d-12H:00M:00S'}]
# 晚上六点
# [{'pattern': '晚上六点', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14785.573179, 'gapH': -4.107103660833333, 'gapD': -0.17112931920138888, 'exp': '?y-?m-?d-18H:00M:00S'}]
# 晚上七点
# [{'pattern': '晚上七点', 'time': datetime.datetime(2018, 9, 11, 19, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -11185.573426, 'gapH': -3.107103729444445, 'gapD': -0.12946265539351853, 'exp': '?y-?m-?d-19H:00M:00S'}]
# 晚上八点
# [{'pattern': '晚上八点', 'time': datetime.datetime(2018, 9, 11, 20, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -7585.573672, 'gapH': -2.107103797777778, 'gapD': -0.08779599157407408, 'exp': '?y-?m-?d-20H:00M:00S'}]
# 晚上九点
# [{'pattern': '晚上九点', 'time': datetime.datetime(2018, 9, 11, 21, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -3985.573918, 'gapH': -1.1071038661111112, 'gapD': -0.046129327754629634, 'exp': '?y-?m-?d-21H:00M:00S'}]
# 晚上十点
# [{'pattern': '晚上十点', 'time': datetime.datetime(2018, 9, 11, 22, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -385.574163, 'gapH': -0.10710393416666666, 'gapD': -0.004462663923611111, 'exp': '?y-?m-?d-22H:00M:00S'}]
# 晚上十一点
# [{'pattern': '晚上十一点', 'time': datetime.datetime(2018, 9, 11, 23, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 3214.425587, 'gapH': 0.892895996388889, 'gapD': 0.03720399984953704, 'exp': '?y-?m-?d-23H:00M:00S'}]
# 晚上十二点
# [{'pattern': '晚上十二点', 'time': datetime.datetime(2018, 9, 11, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -36385.575071, 'gapH': -10.107104186388888, 'gapD': -0.421129341099537, 'exp': '?y-?m-?d-12H:00M:00S'}]

# %%
r.process('今天24点之前')
# Out:
# [{'pattern': '今天24点',
#   'time': datetime.datetime(2018, 9, 11, 23, 59, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>),
#   'gapS': 6732.172302,
#   'gapH': 1.8700478616666667,
#   'gapD': 0.07791866090277778,
#   'exp': '?y-?m-?d-23H:59M:00S'}]
