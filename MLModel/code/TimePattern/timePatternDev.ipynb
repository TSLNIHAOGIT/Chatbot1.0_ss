# %%
import pandas as pd
import numpy as np

# %%
pattern = pd.read_csv('../../data/TimePattern/time_pattern.csv', encoding='utf-8')

# %%
pattern
# Out:
#      time
# 0      今天
# 1      明天
# 2      后天
# 3     大后天
# 4      周一
# 5      周二
# 6      周三
# 7      周四
# 8      周五
# 9      周六
# 10     周日
# 11     周末
# 12    这周一
# 13    这周二
# 14    这周三
# 15    这周四
# 16    这周五
# 17    这周六
# 18    这周日
# 19    这周末
# 20    下周一
# 21    下周二
# 22    下周三
# 23    下周四
# 24    下周五
# 25    下周六
# 26    下周日
# 27    下周末
# 28     1号
# 29     2号
# ..    ...
# 168     秒
# 169   一刻钟
# 170  第一季度
# 171  第二季度
# 172  第三季度
# 173  第四季度
# 174    月初
# 175    月末
# 176    正月
# 177    初月
# 178    一月
# 179    二月
# 180    三月
# 181    四月
# 182    五月
# 183    六月
# 184    七月
# 185    八月
# 186    九月
# 187    十月
# 188   十一月
# 189    腊月
# 190   十二月
# 191    元旦
# 192    春节
# 193   清明节
# 194   劳动节
# 195   端午节
# 196   中秋节
# 197   国庆节
#
# [198 rows x 1 columns]
