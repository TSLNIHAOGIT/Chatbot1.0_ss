# %%
from textblob import TextBlob
from textblob.translate import NotTranslated
import pandas as pd
import numpy as np
from multiprocessing import Pool
from itertools import repeat

# %%
def translate(comment, from_lang, to_lang):
        if hasattr(comment, "decode"):
            comment = comment.decode("utf-8")

        text = TextBlob(comment)
        try:
            text = text.translate(to=to_lang)
            text = text.translate(to=from_lang)
        except NotTranslated:
            pass

        return str(text)

def translate_csv(df,col,from_lang,to_lang,num_pol=10):
    """
        https://developers.google.com/translate/v2/using_rest#language-params
    """
    

    if num_pol >= 1000:
        num_pol=1000
    comment_pool = df[col].values
    p = Pool(num_pol)
    new_col_name = col + '_' + to_lang
    df[new_col_name] = p.starmap(translate, zip(comment_pool, repeat(from_lang),repeat(to_lang)))
    return df

# %%
col = 'split_text'
df = pd.read_csv('../MLModel/data/IDClassifier/cleaned_mock_up_data.csv',encoding='utf8')
dff = translate_csv(df,col,from_lang='zh',to_lang='el',num_pol=50)

# %%
len(dff)
# Out:
# 315

# %%
dff
# Out:
#                       split_text  label      split_text_el
# 0                              啊      0                  啊
# 1    你 有病 吧 我 跟你 说过 很多次 了 我 不是 他      1  你病了，我多次告诉过你。我不是他。
# 2                         不是 什么事      1             这不是什么。
# 3                            啊 对      0               哦，是的
# 4                              对      0                 究竟
# 5                              对      0                 究竟
# 6                         我 不是 啊      1                我不是
# 7                              噢      0                  噢
# 8                              啊      0                  啊
# 9                              啊      0                  啊
# 10                           啊 对      0               哦，是的
# 11                          嗯 你说      0              那么，你说
# 12                           是的呀      0                 是的
# 13                            对啊      0                 究竟
# 14                           啊 对      0               哦，是的
# 15                           啊 对      0               哦，是的
# 16                           噢 对      0                噢 噢
# 17                            嗯那      0                  嗯
# 18                             啊      0                  啊
# 19                             哇      0               噢，我的
# 20                             嗯      0                  嗡
# 21                             嗯      0                  嗡
# 22                            对对      0                 究竟
# 23                             啊      0                  啊
# 24                            嗯唉      0                 蜂鸟
# 25                            唉呀      0                 好的
# 26                            嗯嗯      0                  Q
# 27                             嗯      0                  嗡
# 28                          嗯 是的      0              是的，是的
# 29                           啊 对      0               哦，是的
# ..                           ...    ...                ...
# 285                 声音 太 小了 听 不清      2           声音太小，听不到
# 286                       喂 说话 呀      2             你好，说吧。
# 287                       是 你 大爷      1             他是你的祖父
# 288                         是 你爸      1             这是你的爸爸
# 289                         是 你妹      1             她是你的妹妹
# 290                     你 是不是 有病      1              你病了吗？
# 291                        啊 什么事      0              它是什么？
# 292                      我 是 他 爸      1             我是他的父亲
# 293                     我 是 他 妈妈      1             我是他的母亲
# 294                     我 是 他 邻居      1             我是他的邻居
# 295                     他 换 电话 了      1              他换了电话
# 296                       你 爸 才是      1              你的父亲是
# 297                     我 是 你 大爷      1             我是你的祖父
# 298                        是 个 屁      1             这是一个放屁
# 299                         打错 了      1                 错误
# 300                       请问 什么事      0             什么是问题？
# 301                            啊      0                  啊
# 302                       是 你 哪位      0               你是谁？
# 303                      不是 你 哪位      1              你不是吗？
# 304                     不是 你 打错了      1              不，你错了
# 305                     你 找他 什么事      1             你在找什么？
# 306                         怎么 了      0             发生了什么？
# 307                            滚      1                 滚动
# 308                     不好意思 打错了      1        对不起，我犯了一个错误
# 309                        说了 不是      1                说不是
# 310                我 不方便 等下 打给 你      0       我不舒服，等等，我打电话
# 311                      你 大爷 才是      1              你的叔叔是
# 312                         是 你妈      1            她是你的母亲。
# 313                          你 猜      2                 猜测
# 314                        你 说 呢      2              你说什么？
#
# [315 rows x 3 columns]
