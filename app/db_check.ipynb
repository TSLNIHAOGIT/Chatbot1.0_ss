# %%
from pymongo import MongoClient
client = MongoClient('mongodb://chatbotdb:27017/')

# %%
db = client.flask_database

# %%
import datetime
post = {"author": "Mike1",
         "text": "My first blog post!",
         "tags": ["mongodb", "python", "pymongo"],
         "date": datetime.datetime.utcnow()}

# %%
posts = db.posts
post_id = posts.insert_one(post).inserted_id
post_id
# Out:
# ObjectId('5b19a9b4406d9c002877ac83')

# %%
import pprint
posts = db.posts
pprint.pprint(posts.find_one())
# Out:
# {'_id': ObjectId('5b19a9b4406d9c002877ac83'),
#  'author': 'Mike',
#  'date': datetime.datetime(2018, 6, 7, 21, 54, 54, 733000),
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'text': 'My first blog post!'}

# %% [markdown]
# # show database name

# %%
client.database_names()
# Out:
# ['admin', 'config', 'local', 'sample_database']

# %% [markdown]
# ## drop database

# %%
client.drop_database('flask_database')

# %% [markdown]
# # view data

# %%
db = client.flask_database
l_query = db.query
for i in l_query.find():
    print(i)
# Out:
# {'_id': '7eca689f0d3389d9dea66ae112e5cfd7', 'query': '你好', 'time': datetime.datetime(2018, 6, 7, 22, 23, 27, 19000), 'prediction': ['你好']}

# %%
db_sample = client.sample_database
for i in db_sample.query.find():
    print(i)
# Out:
# {'_id': ObjectId('5b19b240406d9c0039f056b5'), 'author': 'Mike1', 'text': 'My first blog post!', 'tags': ['mongodb', 'python', 'pymongo'], 'date': datetime.datetime(2018, 6, 7, 22, 31, 28, 693000)}
# {'_id': ObjectId('5b19b24c406d9c0039f056b6'), 'author': 'Mike1', 'text': 'My first blog post!', 'tags': ['mongodb', 'python', 'pymongo'], 'date': datetime.datetime(2018, 6, 7, 22, 31, 40, 514000)}
# {'_id': ObjectId('5b19b2ef406d9c0039f056b8'), 'author': 'Mike1', 'text': 'My first blog post!', 'tags': ['mongodb', 'python', 'pymongo'], 'date': datetime.datetime(2018, 6, 7, 22, 34, 23, 764000)}
# {'_id': ObjectId('5b19b30d406d9c0039f056b9'), 'author': 'Mike1', 'text': 'My first blog post!', 'tags': ['mongodb', 'python', 'pymongo'], 'date': datetime.datetime(2018, 6, 7, 22, 34, 53, 93000)}

# %% [markdown]
# # Insert Data

# %% [markdown]
# ### posts inserts

# %%
import pprint
import datetime
post = {"author": "Mike1",
         "text": "My first blog post!",
         "tags": ["mongodb", "python", "pymongo"],
         "date": datetime.datetime.utcnow()}
db_posts = client.sample_database.posts
db_posts.insert_one(post)
pprint.pprint(posts.find_one())
# Out:
# {'_id': ObjectId('5b19b270406d9c0039f056b7'),
#  'author': 'Mike1',
#  'date': datetime.datetime(2018, 6, 7, 22, 32, 16, 88000),
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'text': 'My first blog post!'}

# %% [markdown]
# ### query insert

# %%
import datetime
post = {"author": "Mike4",
         "text": "My first blog post!",
         "tags": ["mongodb", "python", "pymongo"],
         "date": datetime.datetime.utcnow()}
db_sample = client.sample_database
db_sample.query.insert_one(post)
for i in db_sample.query.find():
    print(i)
# Out:
# {'_id': ObjectId('5b19b240406d9c0039f056b5'), 'author': 'Mike1', 'text': 'My first blog post!', 'tags': ['mongodb', 'python', 'pymongo'], 'date': datetime.datetime(2018, 6, 7, 22, 31, 28, 693000)}
# {'_id': ObjectId('5b19b24c406d9c0039f056b6'), 'author': 'Mike1', 'text': 'My first blog post!', 'tags': ['mongodb', 'python', 'pymongo'], 'date': datetime.datetime(2018, 6, 7, 22, 31, 40, 514000)}
# {'_id': ObjectId('5b19b2ef406d9c0039f056b8'), 'author': 'Mike1', 'text': 'My first blog post!', 'tags': ['mongodb', 'python', 'pymongo'], 'date': datetime.datetime(2018, 6, 7, 22, 34, 23, 764000)}
# {'_id': ObjectId('5b19b30d406d9c0039f056b9'), 'author': 'Mike1', 'text': 'My first blog post!', 'tags': ['mongodb', 'python', 'pymongo'], 'date': datetime.datetime(2018, 6, 7, 22, 34, 53, 93000)}
# {'_id': ObjectId('5b19b4c2406d9c0039f056ba'), 'tags': ['1', '2']}
# {'_id': ObjectId('5b19b698406d9c0039f056bb'), 'tags': ['1', '2', '3']}
# {'_id': ObjectId('5b19b783406d9c0039f056bc'), 'author': 'Mike4', 'text': 'My first blog post!', 'tags': ['mongodb', 'python', 'pymongo'], 'date': datetime.datetime(2018, 6, 7, 22, 53, 55, 251000)}

# %% [markdown]
# # Update Data

# %%
import pprint
import datetime

post={'$push':{'tags':['1','2']}}
post={'$inc':{'tags':['1','2']}}


db_sample = client.sample_database
db_sample.query.update_one({"author": "Mike4"},post)
for i in db_sample.query.find():
    print(i)
# Out:
# ---------------------------------------------------------------------------
# WriteError                                Traceback (most recent call last)
# <ipython-input-56-b95582224246> in <module>()
#       7
#       8 db_sample = client.sample_database
# ----> 9 db_sample.query.update_one({"author": "Mike4"},post)
#      10 for i in db_sample.query.find():
#      11     print(i)
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in update_one(self, filter, update, upsert, bypass_document_validation, collation, array_filters, session)
#     974                 bypass_doc_val=bypass_document_validation,
#     975                 collation=collation, array_filters=array_filters,
# --> 976                 session=session),
#     977             self.write_concern.acknowledged)
#     978
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in _update_retryable(self, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, session)
#     834         return self.__database.client._retryable_write(
#     835             (write_concern or self.write_concern).acknowledged and not multi,
# --> 836             _update, session)
#     837
#     838     def replace_one(self, filter, replacement, upsert=False,
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1100         """Internal retryable write helper."""
#    1101         with self._tmp_session(session) as s:
# -> 1102             return self._retry_with_session(retryable, func, s, None)
#    1103
#    1104     def __reset_server(self, address):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1077                         # Reset the transaction id and retry the operation.
#    1078                         session._retry_transaction_id()
# -> 1079                     return func(session, sock_info, retryable)
#    1080             except ServerSelectionTimeoutError:
#    1081                 if is_retrying():
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in _update(session, sock_info, retryable_write)
#     830                 bypass_doc_val=bypass_doc_val, collation=collation,
#     831                 array_filters=array_filters, session=session,
# --> 832                 retryable_write=retryable_write)
#     833
#     834         return self.__database.client._retryable_write(
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in _update(self, sock_info, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, session, retryable_write)
#     796                 client=self.__database.client,
#     797                 retryable_write=retryable_write).copy()
# --> 798             _check_write_command_response(result)
#     799             # Add the updatedExisting field for compatibility.
#     800             if result.get('n') and 'upserted' not in result:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/helpers.py in _check_write_command_response(result)
#     205     write_errors = result.get("writeErrors")
#     206     if write_errors:
# --> 207         _raise_last_write_error(write_errors)
#     208
#     209     error = result.get("writeConcernError")
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/helpers.py in _raise_last_write_error(write_errors)
#     187     if error.get("code") == 11000:
#     188         raise DuplicateKeyError(error.get("errmsg"), 11000, error)
# --> 189     raise WriteError(error.get("errmsg"), error.get("code"), error)
#     190
#     191
#
# WriteError: Cannot increment with non-numeric argument: {tags: [ "1", "2" ]}

# %% [markdown]
# # Replace

# %%
import pprint
import datetime

post={'tags':['1','2','3']}


db_sample = client.sample_database
db_sample.query.replace_one({"author": "Mike3"},post)
for i in db_sample.query.find():
    print(i)
# Out:
# {'_id': ObjectId('5b19b240406d9c0039f056b5'), 'author': 'Mike1', 'text': 'My first blog post!', 'tags': ['mongodb', 'python', 'pymongo'], 'date': datetime.datetime(2018, 6, 7, 22, 31, 28, 693000)}
# {'_id': ObjectId('5b19b24c406d9c0039f056b6'), 'author': 'Mike1', 'text': 'My first blog post!', 'tags': ['mongodb', 'python', 'pymongo'], 'date': datetime.datetime(2018, 6, 7, 22, 31, 40, 514000)}
# {'_id': ObjectId('5b19b2ef406d9c0039f056b8'), 'author': 'Mike1', 'text': 'My first blog post!', 'tags': ['mongodb', 'python', 'pymongo'], 'date': datetime.datetime(2018, 6, 7, 22, 34, 23, 764000)}
# {'_id': ObjectId('5b19b30d406d9c0039f056b9'), 'author': 'Mike1', 'text': 'My first blog post!', 'tags': ['mongodb', 'python', 'pymongo'], 'date': datetime.datetime(2018, 6, 7, 22, 34, 53, 93000)}
# {'_id': ObjectId('5b19b4c2406d9c0039f056ba'), 'tags': ['1', '2']}
# {'_id': ObjectId('5b19b698406d9c0039f056bb'), 'tags': ['1', '2', '3']}
