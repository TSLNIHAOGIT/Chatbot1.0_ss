# %%
import pandas as pd
import numpy as np
import re
import datetime as dt
import pytz
import sys,os
ENV_PATH = '../../ENV/'
sys.path.append(ENV_PATH)
from env import ENV

sys.path.append('../../Lib')
from LOG import Logger

__file__ = '../TIME_PATTERN/'

# %%
class CHN2NUM:
    def __init__(self):
        self.CN_NUM = {
    '〇' : 0, '一' : 1, '二' : 2, '三' : 3, '四' : 4, '五' : 5, '六' : 6, '七' : 7, '八' : 8, '九' : 9, '零' : 0,
    '壹' : 1, '贰' : 2, '叁' : 3, '肆' : 4, '伍' : 5, '陆' : 6, '柒' : 7, '捌' : 8, '玖' : 9, '貮' : 2, '两' : 2
}

        for i in range(10):
            self.CN_NUM[str(i)] = i
        self.CN_UNIT = {
                            '十' : 10,
                            '拾' : 10,
                            '百' : 100,
                            '佰' : 100,
                            '千' : 1000,
                            '仟' : 1000,
                            '万' : 10000,
                            '萬' : 10000,
                            '亿' : 100000000,
                            '億' : 100000000,
                            '兆' : 1000000000000,
                        }

    def transform(self,cn:str):
        unit = 0   # current
        ldig = []  # digest
        for cndig in reversed(cn):
            if cndig in self.CN_UNIT:
                unit = self.CN_UNIT.get(cndig)
                if unit == 10000 or unit == 100000000:
                    ldig.append(unit)
                    unit = 1
            else:
                dig = self.CN_NUM.get(cndig)
                if unit:
                    dig *= unit
                    unit = 0
                ldig.append(dig)
        if unit == 10:
            ldig.append(10)
        val, tmp = 0, 0
        for x in reversed(ldig):
            if x == 10000 or x == 100000000:
                val += tmp * x
                tmp = 0
            else:
                tmp += x
        val += tmp
        return val


class TimePattern:
    def __init__(self):
        self.CHN2NUM = CHN2NUM()
        self._init_reExpression()
        self.log = None
        self.evlEngine = None
        self._load_mapping(os.path.join(os.path.dirname(__file__), 'mapping.csv'))
        
    def _init_post(self):
        """
        once below two are initialized, it will be locked by thread and thus cannot be pickled.
        Need to initialize later.
        """
        self.log = Logger(self.__class__.__name__,level=ENV.MODEL_LOG_LEVEL.value).logger
        self.evlEngine = EvlTimeExpEngine()
        
    def _load_mapping(self, pattern_path):
        df = pd.read_csv(pattern_path)
        # create length
        df['length'] = df.key_word.apply(lambda x: len(x))
        df = df.sort_values(['length','key_word'], ascending=False)
        df_series = pd.Series(index=df.key_word.values, data=df.expression.values)
        df_dict = df_series.to_dict()
        self.serires = df_series
        self.re_ext = r'|'.join(self.serires.index.values)
        self.dict_ext = df_dict
        
    def _init_reExpression(self):
        self.num_cn = r'[一二三四五六七八九十零〇两百千0-9]'
        
        self.year_rela_exp = r'(?:今|明|后|后后|再后|下一|再下一|下|再下|半|(?:{}))年(?:半)?'.format(self.num_cn)
        self.year_fix_exp = r'(?:{}+)年'.format(self.num_cn)
        self.year_exp = r'(?:{}|{})'.format(self.year_rela_exp,self.year_fix_exp)
        
        self.month_rela_exp = r'(?:下下下|下下|再下|下|(?:{}+)|半)(?:个)?(?:半)?月'.format(self.num_cn)
        self.month_fix_exp = r'(?:{}+)月'.format(self.num_cn)
        self.month_exp = r'(?:{}|{})'.format(self.month_rela_exp,self.month_fix_exp)


        self.date_rela_exp = '(?:今|明|后|大后|大大后|再后|(?:{})+)天'.format(self.num_cn)
        self.date_descrip_exp = r'(?:上旬|中旬|下旬|月初|月中|月末|月底|初|底|末)'
        self.date_fix_exp = r'(?:(?:{}+)(?:日|号))|{}'.format(self.num_cn,self.date_descrip_exp)
        self.date_exp = r'(?:{}|{})'.format(self.date_rela_exp,self.date_fix_exp)

        
        
        
        
        self.hour_rela_exp= r'(?:{}+(?:个)?(?:半)?)(?:小时|钟头)'.format(self.num_cn)
        self.hour_descrip_exp = r'早晨|凌晨|早上|半夜|上午|中午|下午|傍晚|晚上|清晨|午后'
        self.minute_fix_exp = r'(?:(?:过)?一刻|(?:过)?{}+(?:分)?|半(?:过)?|过)+'.format(self.num_cn)
        self.hour_fix_exp= r'(?:(?:{})|(?:(?:{}+)点(?:{})?))+'.format(self.hour_descrip_exp,
                                                                   self.num_cn,
                                                                     self.minute_fix_exp)
        self.hour_exp = r'(?:{}|{})'.format(self.hour_rela_exp,self.hour_fix_exp)
        
        
        self.minute_rela_exp = r'(?:过)?(?:{}+|几)分钟|(?:过)?一刻钟'.format(self.num_cn)
        self.minute_exp = r'(?:{})'.format(self.minute_rela_exp)


        self.week_rela_exp = r'(?:(?:这|下|再下|下下|再后)(?:{}+)?(?:个)?)|(?:{}+)'.format(self.num_cn,self.num_cn)
        self.weekDay_exp = r'[1-7天一二三四五六七]'
        self.week_unit = r'周|星期|礼拜'
        self.exp_week =  r'(?:(?:{rw})?(?:{wu})+(?:{wd})?(?:{h})?(?:{mm})?)+'.format(rw=self.week_rela_exp,
                                                                           wu=self.week_unit,
                                                                           wd=self.weekDay_exp,
                                                                           h=self.hour_exp,
                                                                            mm=self.minute_exp)

        self.exp_ymd = r'(?:(?:{y})|(?:{m})|(?:{d})|(?:{h})|(?:{mm}))+'.format(y=self.year_exp,
                                                                      m=self.month_exp,
                                                                      d=self.date_exp,
                                                                      h=self.hour_exp,
                                                                        mm=self.minute_exp)
        
    def remove_time(self,sentence):
        finds,remain = self.extract_pattern(sentence,replace='TIMEPATTERN')
        return remain
        
    def YearExtractor(self,sentence):
        """
        this function will return a list of year it can extract
        """
        #########
        #######define
        
        def Year2Exp(text):
            """
            text has format of "<x>年"
            output: extracted expression
            """
            year_map = {'今':'?','明':'^1','后':'^2','后后':'^3',
                        '再后':'^3','下一':'^1','下':'^1','再下一':'^2','再下':'^2','半':'+0.5'}
            def CHN2Year(x):
                ##TODO: more case needs to be handled
                # case 1. digits
                if x.isdigit():
                    # case 1.1 length is 4. eg 2017
                    if len(x) == 4:
                        return x
                    # case 1.2 length is not 4. which may mean calcuate delta
                    else:
                        return '+'+x
                # needs to handle more cases
                else:
                    return '?'
            index = text.find('年')
            y = None
            if index == -1:
                y = '?'
            else:
                context = text[:index]
                # step 1. get mapping from year_map
                if year_map.get(context) is not None:
                    y = year_map.get(context)
                # step 2. CHN to canlender year    
                else:
                    y = CHN2Year(context)
                    if text.find('半') != -1:
                        y = y+'.5'
            return y
        ########################## end define ############################
        extracted_list = re.findall(self.year_exp,sentence)
        finds_list = []
        if len(extracted_list) > 0:
            for each in extracted_list:
                try:
                    y = Year2Exp(each)
                except Exception as e:
                    self.log.error(e)
                    y = '?'
                finally:
                    finds_list.append((each,y))
        else:
            y = '?'
            finds_list.append((None,y))
        return finds_list 
    
    def MonthExtractor(self,sentence):
        """
        extract month info and convert to expression
        """
        def Month2Exp(text):
            month_map = {'下下下':'^3','下下':'^2','再下':'^2','下':'^1','半':'+0.5'}
            def CHN2Month(x,rela=True):
                """
                CHN2Month("二",rela=True)   --> +2
                CHN2Month("二",rela=False)   --> 2
                CHN2Month("二十",rela=False) --> +20
                """
                if x.isdigit():
                    if int(x) > 12 or rela:
                        return '+'+x
                    else:
                        return x
                # if not digit, then transform        
                else:
                    try:
                        x = str(self.CHN2NUM.transform(x))
                        if int(x) > 12 or rela:
                            x = '+'+x                
                    except Exception as e:
                        self.log.error(e)
                        x = '?'
                    finally:
                        return x
            index = text.find('月')
            m = None
            if index == -1:
                m = '?'
            else:
                # step 1. get mapping from month_map
                index_rala = text.find('个月')
                if index_rala != -1:
                    index = index_rala
                content = text[:index]
                if month_map.get(content) is not None:
                    m = month_map.get(content)

                # step 2. CHN to canlender month
                else:
                    shift = ''
                    if index_rala == -1:
                        index_rala = text.find('个半月')
                        if index_rala != -1:
                            shift = '.5'
                            content = text[:index_rala]
                        
                    if index_rala != -1:
                        ## process relative month logic
                        m = CHN2Month(content,rela=True)
                        m += shift
                    else:
                        ## process nonrelative month logic
                        m = CHN2Month(content,rela=False)
            return m
        ################## end define ############
        extracted_list = re.findall(self.month_exp,sentence)
        finds_list = []
        if len(extracted_list) > 0:
            for each in extracted_list:
                try:
                    m = Month2Exp(each)
                except Exception as e:
                    self.log.error(e)
                    m = '?'
                finally:
                    finds_list.append((each,m))
        else:
            m = '?'
            finds_list.append((None,m))
        return finds_list
    
    def DateExtractor(self,sentence,month_flag = True):
        """
        extract month info and convert to expression
        """
        def Date2Exp(text):
            date_map = {'今':'?','明':'^1','后':'^2','大后':'^3','大大后':'^4','再后':'^3',
                        '上旬':'10','中旬':'15','下旬':'28','月初':'10','月中':'15','月末':'28','月底':'28',
                        '初':'10','中':'15','底':'28','末':'28'}
            def CHN2Date(x,rela=True):
                """
                CHN2Date("二",rela=True)   --> +2
                CHN2Date("二",rela=False)   --> 2
                CHN2Date("二十",rela=False) --> +20
                """
                if x.isdigit():
                    if int(x) > 31 or rela:
                        return '+'+x
                    else:
                        return x
                # if not digit, then transform        
                else:
                    try:
                        x = str(self.CHN2NUM.transform(x))
                        if int(x) > 31 or rela:
                            x = '+'+x                
                    except Exception as e:
                        self.log.error(e)
                        x = '?'
                    finally:
                        return x
            # case 1. 号
            if text.find('号') != -1:
                index_date = text.find('号')
                d = CHN2Date(text[:index_date],rela=False)
            # case 2. 天
            elif text.find('天') != -1:
                index_date = text.find('天')
                descrip = text[:index_date]
                d = date_map.get(descrip)
                if d is None:
                    d = CHN2Date(descrip,rela=True)
            # case 3. 天
            elif text.find('日') != -1:
                index_date = text.find('日')
                descrip = text[:index_date]
                if month_flag:
                    d = CHN2Date(text[:index_date],rela=False)
                else:
                    d = CHN2Date(text[:index_date],rela=True)
            elif date_map.get(text) is not None:
                d = date_map.get(text)
            else:
                d = '?'
            return d
        ################## end define ############
        extracted_list = re.findall(self.date_exp,sentence)
        finds_list = []
        if len(extracted_list) > 0:
            for each in extracted_list:
                try:
                    d = Date2Exp(each)
                except Exception as e:
                    self.log.error(e)
                    d = '?'
                finally:
                    finds_list.append((each,d))
        else:
            d = '?'
            finds_list.append((None,d))
        return finds_list
    
    

    def HourExtractor(self,sentence,date_flag=None):
        """
        extract hour info and convert to expression
        date_flag will just be used as a placeholder
        3点15，
        3点过一刻
        can be extracted
        """
        def Minute2Exp(text):
            minute_map = {'过':'30','一刻':'15','半':'30','半过':'45'}
            reg_period = r'过|分|钟'
            def CHN2Minute(x,rela=True):
                """
                CHN2Minute("二",rela=True)   --> +2
                CHN2Minute("二",rela=False)   --> 2
                CHN2Minute("二十",rela=False) --> +20
                """
                if x.isdigit():
                    if int(x) > 59 or rela:
                        return '+'+x
                    else:
                        return x
                # if not digit, then transform        
                else:
                    try:
                        x = str(self.CHN2NUM.transform(x))
                        if int(x) > 59 or rela:
                            x = '+'+x                
                    except Exception as e:
                        self.log.error(e)
                        x = '00'
                    finally:
                        if x == '0':
                            x = '00'
                        return x
            # case 1. can get value from defined mapping
            if minute_map.get(text) is not None:
                mm = minute_map.get(text)
            # case 2. need to remove some words
            else:
                text_sub = re.sub(reg_period,'',text)
                if minute_map.get(text_sub) is not None:
                    mm = minute_map.get(text_sub)
                # cannot get value from defined mapping
                else:
                    try:
                        mm = CHN2Minute(text_sub, rela=False)
                    except Exception as e:
                        self.log.error(e)
                        mm = '00'
            return mm

        def Hour2Exp(text):
                hour_map = {'早晨':11,'凌晨':6,'早上':11,'半夜':6,'清晨':11,'上午':11,
                            '中午':14,'下午':18,'傍晚':21,'晚上':23,'午后':15,}
                reg_period = r'(?:个)?(?:小时|钟头)'
                def CHN2Hour(x,rela=True):
                    """
                    CHN2Date("二",rela=True)   --> +2
                    CHN2Date("二",rela=False)   --> 2
                    CHN2Date("二十",rela=False) --> +20
                    """
                    if x.isdigit():
                        if int(x) > 24 or rela:
                            return '+'+x
                        else:
                            return x
                    # if not digit, then transform        
                    else:
                        try:
                            x = str(self.CHN2NUM.transform(x))
                            if int(x) > 24 or rela:
                                x = '+'+x                
                        except Exception as e:
                            self.log.error(e)
                            x = '?'
                        finally:
                            return x
                def ShiftTime(x,am_pm):
                    am_pm = am_pm//12
                    if x.isdigit():
                        x = int(x) 
                        if x < 12 and am_pm == 1:
                            x += 12
                        return str(x)
                    else:
                        return x

                #1. Judge in the morning or afternoon. Then remove the description words
                des_t = re.findall(self.hour_descrip_exp,text)
                if len(des_t) > 0:
                    des_t = des_t[0]
                    hours = hour_map.get(des_t)
                    if hours is None:
                        hours = 17
                    text = re.sub(self.hour_descrip_exp,'',text)
                else:
                    hours = 17
                mm = '00'
                # case 1.  几点

                if len(re.findall(r'点',text)) > 0:
                    index_hour = text.find('点')
                    h = CHN2Hour(text[:index_hour],rela=False)
                    h = ShiftTime(h,hours)
                    mm = Minute2Exp(text[index_hour+1:])
                # case 2. 几个小时
                elif len(re.findall(reg_period,text)) > 0:
                    replace = '!H!'
                    if text.find('半') != -1:
                        mm = '+30'
                        text = re.sub(r'半','',text)
                    finds = re.sub(reg_period,replace,text)
                    index_hour = finds.find(replace)
                    h = CHN2Hour(finds[:index_hour],rela=True)
                else:
                    h = str(hours)
                return h,mm
        ################## end define ############
        extracted_list = re.findall(self.hour_exp,sentence)
        finds_list = []
        if len(extracted_list) > 0:
            for each in extracted_list:
                try:
                    h,mm = Hour2Exp(each)
                except Exception as e:
                    self.log.error(e)
                   
                    h = '?'
                    mm = '?'
                finally:
                    finds_list.append((each,h,mm))
        else:
            h = '?'
            mm = '?'
            finds_list.append((None,h,mm))
        return finds_list
    
    
    def MinuteExtractor(self,sentence,hour_flag=None):
        """
        just extract relative time. fix time will be handled by hour
        """
        def Minute2Exp(text):
            minute_map = {'一刻钟':'+15'}
            def CHN2Minute(x,rela=True):
                """
                CHN2Minute("二",rela=True)   --> +2
                CHN2Minute("二",rela=False)   --> 2
                CHN2Minute("二十",rela=False) --> +20
                """
                if x.isdigit():
                    if int(x) > 59 or rela:
                        return '+'+x
                    else:
                        return x
                # if not digit, then transform        
                else:
                    try:
                        x = str(self.CHN2NUM.transform(x))
                        if int(x) > 59 or rela:
                            x = '+'+x                
                    except Exception as e:
                        self.log.error(e)
                        x = '00'
                    finally:
                        return x
            # case 1. can get value from defined mapping
            if minute_map.get(text) is not None:
                mm = minute_map.get(text)
            # case 2. need to remove some words
            else:
                text = re.sub('过','',text)
                index_minute = text.find('分钟')
                if index_minute != -1:
                    mm = CHN2Minute(text[:index_minute],rela=True)
                else:
                    mm = '?'
            return mm
        ################## end define ############
        extracted_list = re.findall(self.minute_exp,sentence)
        finds_list = []
        if len(extracted_list) > 0:
            for each in extracted_list:
                try:
                    mm = Minute2Exp(each)
                except Exception as e:
                    self.log.error(e)
                    mm = '00'
                finally:
                    finds_list.append((each,mm))
        else:
            mm = '?'
            finds_list.append((None,mm))
        return finds_list
    
    def WeekExtractor(self,sentence):
        def Week2Exp(text):
            replace_wu = '!wu!'
            reg_wu = r'(?:{})+'.format(replace_wu)
            rela_week_map = {'这':'?','下':'^1','再下':'^2','下下':'^2','再后':'^2'}
            def CHN2Week(x,rela=True):
                """
                CHN2Minute("二",rela=True)   --> +2
                CHN2Minute("二",rela=False)   --> 2
                CHN2Minute("二十",rela=False) --> +20
                """
                if x.isdigit():
                    if rela:
                        return '+'+x
                    else:
                        return x
                # if not digit, then transform        
                else:
                    try:
                        x = str(self.CHN2NUM.transform(x))
                        if rela:
                            x = '+'+x                
                    except Exception as e:
                        self.log.error(e)
                        x = '?'
                    finally:
                        return x
            # replace key word

            text = re.sub(self.week_unit,replace_wu,text)
            text = re.sub(reg_wu,replace_wu,text)
            # no such pattern
            index_wu = text.find(replace_wu)
            if index_wu == -1:
                W = '?'
                w = '?'
            else:
                Week_info = text[:index_wu]
                Week_info = re.sub(r'个','',Week_info)
                WeekDay_info = text[index_wu+len(replace_wu):]
                if len(Week_info) > 0:
                    if rela_week_map.get(Week_info) is not None:
                        W = rela_week_map.get(Week_info)
                    else:
                        W = CHN2Week(Week_info,rela=True)
                else:
                    W = '?'
                if len(WeekDay_info) > 0:
                    w = CHN2Week(WeekDay_info,rela=False)
                else:
                    w = '?'
            return W,w
        ################## end define ############
        extracted_list = re.findall(self.exp_week,sentence)      
        finds_list = []
        if len(extracted_list) > 0:
            for each in extracted_list:
                each = re.sub(self.hour_exp,'',each)
                try:
                    W,w = Week2Exp(each)
                except Exception as e:
                    self.log.error(e)
                    W = '?'
                    w = '?'
                finally:
                    finds_list.append((each,W,w))
        else:
            W = '?'
            w = '?'
            finds_list.append((None,W,w))
        return finds_list
        
    def evl_week(self,sentence):
        exp = '?y-{}W-{}w-{}H:{}M:00S'
        finds = re.findall(self.exp_week,sentence)
        return_list = []

        for each in finds:
            #1. process week and weekday
            extract_w = self.WeekExtractor(each)
            p,W,w = extract_w[0]
            if p is None:
                continue
            #2. process hour and minute
            extract_h = self.HourExtractor(each)
            p,h,mm = extract_h[0]
            if p is None:
                h = '18'
                mm = '00'
            return_list.append((each,exp.format(W,w,h,mm)))
            
        return return_list
    
    
    def evl_ymd(self,sentence):
        exp = '{}y-{}m-{}d-{}H:{}M:00S'
        finds = re.findall(self.exp_ymd,sentence)
        return_list = []

        for each in finds:
            #1. process year
            extract_y = self.YearExtractor(each)
            p,y = extract_y[0]
            if p is None:
                p=''
            each_remain = re.sub(p,'',each)
            #2. process month
            extract_m = self.MonthExtractor(each_remain)
            p,m = extract_m[0]
            if p is None:
                p=''
                month_flag = False
            else:
                month_flag = True
            each_remain = re.sub(p,'',each_remain)
            #3. process date
            extract_d = self.DateExtractor(each_remain,month_flag)
            p,d = extract_d[0]
            if p is None:
                p=''
            each_remain = re.sub(p,'',each_remain)
            #4. process hours
            extract_h = self.HourExtractor(each_remain)
            p,h,mm = extract_h[0]
            if p is None:
                p=''
            each_remain = re.sub(p,'',each_remain)
            #5. process minutes
            extract_m = self.MinuteExtractor(each_remain)
            p,mm_rela = extract_m[0]
            if mm_rela[0] == '+':
                mm = mm_rela
            return_list.append((each,exp.format(y,m,d,h,mm)))
            
        return return_list
    
    def evl_selfDefine(self,sentence):
        finds = re.findall(self.re_ext,sentence)
        return_list = []
        for each in finds:
            return_list.append((each,self.dict_ext[each]))
        return return_list
        
    
    
    def extract_pattern(self,sentence,replace='TIMEPATTERN'):
        #1 process by self define
        selfDefine_finds = self.evl_selfDefine(sentence)
        remain = re.sub(self.re_ext,replace,sentence)
        #2 process by week exp
        week_finds = self.evl_week(remain)
        remain = re.sub(self.exp_week,replace,remain)
        #3 process by ymd exp
        ymd_finds = self.evl_ymd(remain)
        remain = re.sub(self.exp_ymd,replace,remain)
        
        finds = selfDefine_finds + week_finds + ymd_finds
        return finds,remain
        
        
    def process(self,sentence):
        if self.log is None:
            self._init_post()
        finds,_ = self.extract_pattern(sentence)
        result = []
        for p,exp in finds:
            try:
                timestamp,gapS,gapH,gapD = self.evlEngine.evl(exp)
                result.append({'pattern':p,'time':timestamp,'gapS':gapS,'gapH':gapH,'gapD':gapD,'exp':exp})
            except Exception as e:
                self.log.error('evaluating expression: {}. Got error!!!'.format(exp))
                self.log.error(e)
            
        return result
            
                
                
                    
    
class EvlTimeExpEngine:
    def __init__(self,tz=None):
        self.log = Logger(self.__class__.__name__,level=ENV.MODEL_LOG_LEVEL.value).logger
        self._set_timeZone(tz)
        
    def _set_timeZone(self,tz=None):
        if tz is None:
            tz = ENV.TIMEZONE.value
            self.log.info('Time Zone is set from ENV: {}'.format(tz))
        tz = ENV.TIMEZONE.value
        self.tz = pytz.timezone(tz)
        self.delta = self.tz.utcoffset(dt.datetime.utcnow())
        
        
    def _get_LocalNow(self):
        now = dt.datetime.utcnow()
        return self.tz.localize(now) + self.delta
        
    
    def evl(self,exp):
        """
        '?y-{}W-{}w-{}H:{}M:00S'
        '{}y-{}m-{}d-{}H:{}M:00S'
        """
        current = self._get_LocalNow()
        if exp.find('W') != -1:
            timestamp =  self.createFromWD(exp,current)
        else:
            timestamp = self.createFromYMD(exp,current)
        gapS = (timestamp - current).total_seconds()
        gapH = gapS / 3600
        gapD = gapH / 24
        return timestamp,gapS,gapH,gapD
        
    
    def createFromWD(self,exp,current):
        """
        create timestamp from weekDay expression
        https://docs.python.org/3/library/datetime.html#strftime-strptime-behavior
        y,W has '^'
        """
        posi_info = self.WD_exp_keyExtractor(exp)
        y_cur = current.year
        W_cur = int(current.strftime("%W"))
        w_cur = int(current.strftime("%w"))
        shift = 0
        ###### process year
        if posi_info['y'][0] == '^':
            y = current.year + int(posi_info['y'][1:])
        elif posi_info['y'] == '?':
            y = current.year
        elif posi_info['y'][0] == '+':
            y = current.year
            shift += float(posi_info['y'][1:]) * 365 * 24 * 60
        else:
            y = int(posi_info['y'])
            
        ###### process week
        if posi_info['W'][0] == '^':
            W = W_cur + int(posi_info['W'][1:])
        elif posi_info['W'] == '?':
            W = W_cur
        elif posi_info['W'][0] == '+':
            W = W_cur
            shift += float(posi_info['W'][1:]) * 7 * 24 * 60
        else:
            W = int(posi_info['W'])
        
        ###### process week day
        if posi_info['w'] == '?':
            w = w_cur
        elif posi_info['w'][0] == '+':
            w = w_cur
            shift += float(posi_info['w'][1:]) * 1 * 24 * 60
        else:
            w = int(posi_info['w'])
            
        ###### process hour
        if posi_info['H'] == '?':
            H = current.hour
        elif posi_info['H'][0] == '+':
            H = current.hour
            shift += float(posi_info['H'][1:]) * 60
        else:
            H = int(posi_info['H'])
        
        ###### process Minute
        if posi_info['M'] == '?':
            M = current.minute
        elif posi_info['M'][0] == '+':
            M = current.minute
            shift += float(posi_info['M'][1:])
        else:
            M = int(posi_info['M'])
        
        ###### process Second
        if posi_info['S'] == '?':
            S = current.second
        elif posi_info['S'][0] == '+':
            S = current.second
            shift += int(float(posi_info['S'][1:]) / 60)
        else:
            S = int(posi_info['S'])
            
        y = y + ((W-1)//53)
        W = W % 53
        if W==0:
            W=53
        if w >= 7:
            shift+= (w-7)*24*60
            w=0
            
        
        reconstruct = True
        while reconstruct:
            try:    
                time = '{}y-{}W-{}w-{}H:{}M:00S'.format(y,W,w,H,M,S)
                timestamp = dt.datetime.strptime(time, "%Yy-%WW-%ww-%HH:%MM:%SS")
                reconstruct = False
            except ValueError as e:
                self.log.error(e)
                W -= 1
                shift += 24 * 60 * 7
            
        delta = dt.timedelta(minutes=shift)
        timestamp += delta
        timestamp = self.tz.localize(timestamp)
        
        return timestamp
            
    
    def createFromYMD(self,exp,current):
        """
        shift is converted to minute level
        y,m,d has '^'
        
        """
        posi_info = self.YMD_exp_keyExtractor(exp)
        shift = 0
        ###### process year
        if posi_info['y'][0] == '^':
            y = current.year + int(posi_info['y'][1:])
        elif posi_info['y'] == '?':
            y = current.year
        elif posi_info['y'][0] == '+':
            y = current.year
            shift += float(posi_info['y'][1:]) * 365 * 24 * 60
        else:
            y = int(posi_info['y'])
        ###### process month
        if posi_info['m'][0] == '^':
            m = current.month + int(posi_info['m'][1:])
        elif posi_info['m'] == '?':
            m = current.month
        elif posi_info['m'][0] == '+':
            m = current.month
            shift += float(posi_info['m'][1:]) * 30 * 24 * 60
        else:
            m = int(posi_info['m'])
            
        y = y + ((m-1)//12)
        m = m % 12
        if m == 0:
            m = 12
        
        ###### process day
        if posi_info['d'][0] == '^':
            d = current.day + int(posi_info['d'][1:])
        elif posi_info['d'] == '?':
            d = current.day
        elif posi_info['d'][0] == '+':
            d = current.day
            shift += float(posi_info['d'][1:]) * 24 * 60
        else:
            d = int(posi_info['d'])
        
        ###### process hour
        if posi_info['H'] == '?':
            H = current.hour
        elif posi_info['H'][0] == '+':
            H = current.hour
            shift += float(posi_info['H'][1:]) * 60
        else:
            H = int(posi_info['H'])
        
        ###### process Minute
        if posi_info['M'] == '?':
            M = current.minute
        elif posi_info['M'][0] == '+':
            M = current.minute
            shift += float(posi_info['M'][1:])
        else:
            M = int(posi_info['M'])
        
        ###### process Second
        if posi_info['S'] == '?':
            S = current.second
        elif posi_info['S'][0] == '+':
            S = current.second
            shift += float(int(posi_info['S'][1:]) / 60)
        else:
            S = int(posi_info['S'])
            
        reconstruct = True
        while reconstruct:
            try:    
                timestamp = dt.datetime(year=y,month=m,day=d,hour=H,minute=M,second=S)
                reconstruct = False
            except ValueError as e:
                self.log.error(e)
                d -= 1
                shift += 24 * 60
            
        delta = dt.timedelta(minutes=shift)
        timestamp += delta
        timestamp = self.tz.localize(timestamp)
        
        return timestamp
    
    def YMD_exp_keyExtractor(self, exp):
        y_index = exp.find('y')
        m_index = exp.find('m')
        d_index = exp.find('d')
        H_index = exp.find('H')
        M_index = exp.find('M')
        S_index = exp.find('S')
        y = exp[:y_index]
        m = exp[y_index+2:m_index]
        d = exp[m_index+2:d_index]
        H = exp[d_index+2:H_index]
        M = exp[H_index+2:M_index]
        S = exp[M_index+2:S_index]
        return {'y':y, 'm':m, 'd':d, 'H':H, 'M':M, 'S':S}
    
    def WD_exp_keyExtractor(self, exp):
        y_index = exp.find('y')
        W_index = exp.find('W')
        w_index = exp.find('w')
        H_index = exp.find('H')
        M_index = exp.find('M')
        S_index = exp.find('S')
        y = exp[:y_index]
        W = exp[y_index+2:W_index]
        w = exp[W_index+2:w_index]
        H = exp[w_index+2:H_index]
        M = exp[H_index+2:M_index]
        S = exp[M_index+2:S_index]
        return {'y':y, 'W':W, 'w':w, 'H':H, 'M':M, 'S':S}

# %%
r = TimePattern()

# %%
r.process('明天下午5点58分')
# Out:
# 2018-09-10 18:19:48,113 - INFO - CLASS:EvlTimeExpEngine- METHOD:_set_timeZone -LINE:724 - MSG:Time Zone is set from ENV: Asia/Shanghai
# 2018-09-10 18:19:48,113 - INFO - CLASS:EvlTimeExpEngine- METHOD:_set_timeZone -LINE:724 - MSG:Time Zone is set from ENV: Asia/Shanghai
# 2018-09-10 18:19:48,113 - INFO - CLASS:EvlTimeExpEngine- METHOD:_set_timeZone -LINE:724 - MSG:Time Zone is set from ENV: Asia/Shanghai
# 2018-09-10 18:19:48,113 - INFO - CLASS:EvlTimeExpEngine- METHOD:_set_timeZone -LINE:724 - MSG:Time Zone is set from ENV: Asia/Shanghai
# 2018-09-10 18:19:48,113 - INFO - CLASS:EvlTimeExpEngine- METHOD:_set_timeZone -LINE:724 - MSG:Time Zone is set from ENV: Asia/Shanghai
# [{'pattern': '明天下午5点58分',
#   'time': datetime.datetime(2018, 9, 12, 17, 58, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>),
#   'gapS': 142691.870298,
#   'gapH': 39.63663063833333,
#   'gapD': 1.651526276597222,
#   'exp': '?y-?m-^1d-17H:58M:00S'}]

# %% [markdown]
# # Test self-define

# %%
df_mapping = pd.read_csv('../../classifier/models/time_pattern/mapping.csv')

# %% [markdown]
# # Load from py

# %%
import re
import sys,os
import pandas as pd
sys.path.append('../../classifier/models/time_extractor/')
from time_pattern import TimePattern
df_mapping = pd.read_csv('../../classifier/models/time_pattern/mapping.csv')

# %%
import time
r = TimePattern()
error_list = []
not_match = []
for pt in df_mapping.key_word.values:
    result = r.process(pt)
    print(pt)
    print(result)
    try:
        pt_extract = result[0]['pattern']
        if pt_extract != pt:
            not_match.append((pt,pt_extract))
    except Exception as e:  
        error_list.append((pt,str(e)))
# Out:
# 2018-09-10 17:50:09,491 - INFO - CLASS:EvlTimeExpEngine- METHOD:_set_timeZone -LINE:739 - MSG:Time Zone is set from ENV: Asia/Shanghai
# 明天
# [{'pattern': '明天', 'time': datetime.datetime(2018, 9, 12, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 86390.47445, 'gapH': 23.997354013888888, 'gapD': 0.9998897505787037, 'exp': '?y-?m-^1d-?H:?M:00S'}]
# 明天早上
# [{'pattern': '明天早上', 'time': datetime.datetime(2018, 9, 12, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 119390.472936, 'gapH': 33.16402026, 'gapD': 1.3818341775, 'exp': '?y-?m-^1d-11H:00M:00S'}]
# 明天下午
# [{'pattern': '明天下午', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 144590.472276, 'gapH': 40.16402007666666, 'gapD': 1.6735008365277775, 'exp': '?y-?m-^1d-18H:00M:00S'}]
# 后天下午
# [{'pattern': '后天下午', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 230990.471645, 'gapH': 64.1640199013889, 'gapD': 2.6735008292245372, 'exp': '?y-?m-^2d-18H:00M:00S'}]
# 后天
# [{'pattern': '后天', 'time': datetime.datetime(2018, 9, 13, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 172790.47095, 'gapH': 47.99735304166666, 'gapD': 1.9998897100694444, 'exp': '?y-?m-^2d-?H:?M:00S'}]
# 后天早上
# [{'pattern': '后天早上', 'time': datetime.datetime(2018, 9, 13, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 205790.470388, 'gapH': 57.16401955222222, 'gapD': 2.381834148009259, 'exp': '?y-?m-^2d-11H:00M:00S'}]
# 今天
# [{'pattern': '今天', 'time': datetime.datetime(2018, 9, 11, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -9.530196, 'gapH': -0.002647276666666667, 'gapD': -0.00011030319444444445, 'exp': '?y-?m-?d-?H:?M:00S'}]
# 今天下午
# [{'pattern': '今天下午', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 58190.469255, 'gapH': 16.1640192375, 'gapD': 0.6735008015625, 'exp': '?y-?m-?d-18H:00M:00S'}]
# 大后天
# [{'pattern': '大后天', 'time': datetime.datetime(2018, 9, 14, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 259190.468636, 'gapH': 71.99735239888889, 'gapD': 2.999889683287037, 'exp': '?y-?m-^3d-?H:?M:00S'}]
# 大后天早上
# [{'pattern': '大后天早上', 'time': datetime.datetime(2018, 9, 14, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 292190.467954, 'gapH': 81.16401887611111, 'gapD': 3.381834119837963, 'exp': '?y-?m-^3d-11H:00M:00S'}]
# 大后天下午
# [{'pattern': '大后天下午', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 317390.467409, 'gapH': 88.16401872472221, 'gapD': 3.673500780196759, 'exp': '?y-?m-^3d-18H:00M:00S'}]
# 半个月内
# [{'pattern': '半个月', 'time': datetime.datetime(2018, 9, 26, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1295990.466813, 'gapH': 359.9973518925, 'gapD': 14.999889662187499, 'exp': '?y-+0.5m-?d-?H:?M:00S'}]
# 下个月
# [{'pattern': '下个月', 'time': datetime.datetime(2018, 10, 11, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 2591990.466219, 'gapH': 719.9973517275, 'gapD': 29.9998896553125, 'exp': '?y-^1m-?d-?H:?M:00S'}]
# 下个月月底
# [{'pattern': '下个月月底', 'time': datetime.datetime(2018, 10, 28, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 4060790.465624, 'gapH': 1127.9973515622223, 'gapD': 46.99988964842593, 'exp': '?y-^1m-28d-?H:?M:00S'}]
# 下个月初
# [{'pattern': '下个月初', 'time': datetime.datetime(2018, 10, 10, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 2505590.465029, 'gapH': 695.9973513969444, 'gapD': 28.99988964153935, 'exp': '?y-^1m-10d-?H:?M:00S'}]
# 下下个月
# [{'pattern': '下下个月', 'time': datetime.datetime(2018, 11, 11, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 5270390.464434, 'gapH': 1463.9973512316667, 'gapD': 60.99988963465278, 'exp': '?y-^2m-?d-?H:?M:00S'}]
# 再下个月
# [{'pattern': '再下个月', 'time': datetime.datetime(2018, 11, 11, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 5270390.463835, 'gapH': 1463.9973510652778, 'gapD': 60.99988962771991, 'exp': '?y-^2m-?d-?H:?M:00S'}]
# 下下个月初
# [{'pattern': '下下个月初', 'time': datetime.datetime(2018, 11, 10, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 5183990.463293, 'gapH': 1439.9973509147223, 'gapD': 59.99988962144676, 'exp': '?y-^2m-10d-?H:?M:00S'}]
# 下个月中
# [{'pattern': '下个月', 'time': datetime.datetime(2018, 10, 11, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 2591990.462641, 'gapH': 719.997350733611, 'gapD': 29.99988961390046, 'exp': '?y-^1m-?d-?H:?M:00S'}]
# 下下个月中
# [{'pattern': '下下个月', 'time': datetime.datetime(2018, 11, 11, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 5270390.462033, 'gapH': 1463.9973505647222, 'gapD': 60.99988960686343, 'exp': '?y-^2m-?d-?H:?M:00S'}]
# 下个月末
# [{'pattern': '下个月末', 'time': datetime.datetime(2018, 10, 28, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 4060790.461429, 'gapH': 1127.9973503969445, 'gapD': 46.99988959987269, 'exp': '?y-^1m-28d-?H:?M:00S'}]
# 下个月底
# [{'pattern': '下个月底', 'time': datetime.datetime(2018, 10, 28, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 4060790.460838, 'gapH': 1127.9973502327778, 'gapD': 46.99988959303241, 'exp': '?y-^1m-28d-?H:?M:00S'}]
# 下下个月末
# [{'pattern': '下下个月末', 'time': datetime.datetime(2018, 11, 28, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 6739190.460296, 'gapH': 1871.9973500822223, 'gapD': 77.99988958675927, 'exp': '?y-^2m-28d-?H:?M:00S'}]
# 下下个月底
# [{'pattern': '下下个月底', 'time': datetime.datetime(2018, 11, 28, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 6739190.459581, 'gapH': 1871.9973498836112, 'gapD': 77.9998895784838, 'exp': '?y-^2m-28d-?H:?M:00S'}]
# 下下下个月
# [{'pattern': '下下下个月', 'time': datetime.datetime(2018, 12, 11, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 7862390.458959, 'gapH': 2183.9973497108335, 'gapD': 90.99988957128473, 'exp': '?y-^3m-?d-?H:?M:00S'}]
# 一个月
# [{'pattern': '一个月', 'time': datetime.datetime(2018, 10, 11, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 2591990.458358, 'gapH': 719.9973495438888, 'gapD': 29.9998895643287, 'exp': '?y-+1m-?d-?H:?M:00S'}]
# 1个月
# [{'pattern': '1个月', 'time': datetime.datetime(2018, 10, 11, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 2591990.457768, 'gapH': 719.9973493800001, 'gapD': 29.9998895575, 'exp': '?y-+1m-?d-?H:?M:00S'}]
# 半个月
# [{'pattern': '半个月', 'time': datetime.datetime(2018, 9, 26, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1295990.457241, 'gapH': 359.9973492336111, 'gapD': 14.999889551400463, 'exp': '?y-+0.5m-?d-?H:?M:00S'}]
# 两个月
# [{'pattern': '两个月', 'time': datetime.datetime(2018, 11, 10, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 5183990.456663, 'gapH': 1439.9973490730556, 'gapD': 59.99988954471065, 'exp': '?y-+2m-?d-?H:?M:00S'}]
# 2个月
# [{'pattern': '2个月', 'time': datetime.datetime(2018, 11, 10, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 5183990.456084, 'gapH': 1439.9973489122222, 'gapD': 59.999889538009256, 'exp': '?y-+2m-?d-?H:?M:00S'}]
# 一个半月
# [{'pattern': '一个半月', 'time': datetime.datetime(2018, 10, 26, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 3887990.4555, 'gapH': 1079.9973487500001, 'gapD': 44.999889531250005, 'exp': '?y-+1.5m-?d-?H:?M:00S'}]
# 1个半月
# [{'pattern': '1个半月', 'time': datetime.datetime(2018, 10, 26, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 3887990.454915, 'gapH': 1079.9973485875, 'gapD': 44.999889524479165, 'exp': '?y-+1.5m-?d-?H:?M:00S'}]
# 两个半月
# [{'pattern': '两个半月', 'time': datetime.datetime(2018, 11, 25, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 6479990.454326, 'gapH': 1799.997348423889, 'gapD': 74.99988951766204, 'exp': '?y-+2.5m-?d-?H:?M:00S'}]
# 2个半月
# [{'pattern': '2个半月', 'time': datetime.datetime(2018, 11, 25, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 6479990.453644, 'gapH': 1799.9973482344444, 'gapD': 74.99988950976852, 'exp': '?y-+2.5m-?d-?H:?M:00S'}]
# 三个月
# [{'pattern': '三个月', 'time': datetime.datetime(2018, 12, 10, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 7775990.453036, 'gapH': 2159.9973480655553, 'gapD': 89.99988950273148, 'exp': '?y-+3m-?d-?H:?M:00S'}]
# 3个月
# [{'pattern': '3个月', 'time': datetime.datetime(2018, 12, 10, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 7775990.452334, 'gapH': 2159.9973478705556, 'gapD': 89.99988949460648, 'exp': '?y-+3m-?d-?H:?M:00S'}]
# 三个半月
# [{'pattern': '三个半月', 'time': datetime.datetime(2018, 12, 25, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 9071990.450749, 'gapH': 2519.997347430278, 'gapD': 104.99988947626157, 'exp': '?y-+3.5m-?d-?H:?M:00S'}]
# 3个半月
# [{'pattern': '3个半月', 'time': datetime.datetime(2018, 12, 25, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 9071990.449883, 'gapH': 2519.9973471897224, 'gapD': 104.99988946623843, 'exp': '?y-+3.5m-?d-?H:?M:00S'}]
# 四个月
# [{'pattern': '四个月', 'time': datetime.datetime(2019, 1, 9, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 10367990.449215, 'gapH': 2879.997347004167, 'gapD': 119.99988945850696, 'exp': '?y-+4m-?d-?H:?M:00S'}]
# 4个月
# [{'pattern': '4个月', 'time': datetime.datetime(2019, 1, 9, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 10367990.448595, 'gapH': 2879.9973468319445, 'gapD': 119.99988945133101, 'exp': '?y-+4m-?d-?H:?M:00S'}]
# 四个半月
# [{'pattern': '四个半月', 'time': datetime.datetime(2019, 1, 24, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 11663990.447973, 'gapH': 3239.997346659167, 'gapD': 134.99988944413195, 'exp': '?y-+4.5m-?d-?H:?M:00S'}]
# 4个半月
# [{'pattern': '4个半月', 'time': datetime.datetime(2019, 1, 24, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 11663990.447354, 'gapH': 3239.9973464872223, 'gapD': 134.9998894369676, 'exp': '?y-+4.5m-?d-?H:?M:00S'}]
# 五个月
# [{'pattern': '五个月', 'time': datetime.datetime(2019, 2, 8, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 12959990.446772, 'gapH': 3599.9973463255556, 'gapD': 149.9998894302315, 'exp': '?y-+5m-?d-?H:?M:00S'}]
# 5个月
# [{'pattern': '5个月', 'time': datetime.datetime(2019, 2, 8, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 12959990.446208, 'gapH': 3599.9973461688887, 'gapD': 149.9998894237037, 'exp': '?y-+5m-?d-?H:?M:00S'}]
# 五个半月
# [{'pattern': '五个半月', 'time': datetime.datetime(2019, 2, 23, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 14255990.445639, 'gapH': 3959.997346010833, 'gapD': 164.99988941711806, 'exp': '?y-+5.5m-?d-?H:?M:00S'}]
# 5个半月
# [{'pattern': '5个半月', 'time': datetime.datetime(2019, 2, 23, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 14255990.445078, 'gapH': 3959.9973458550003, 'gapD': 164.999889410625, 'exp': '?y-+5.5m-?d-?H:?M:00S'}]
# 六个月
# [{'pattern': '六个月', 'time': datetime.datetime(2019, 3, 10, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 15551990.444515, 'gapH': 4319.997345698611, 'gapD': 179.99988940410879, 'exp': '?y-+6m-?d-?H:?M:00S'}]
# 6个月
# [{'pattern': '6个月', 'time': datetime.datetime(2019, 3, 10, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 15551990.443957, 'gapH': 4319.997345543611, 'gapD': 179.99988939765046, 'exp': '?y-+6m-?d-?H:?M:00S'}]
# 六个半月
# [{'pattern': '六个半月', 'time': datetime.datetime(2019, 3, 25, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 16847990.443391, 'gapH': 4679.997345386389, 'gapD': 194.99988939109952, 'exp': '?y-+6.5m-?d-?H:?M:00S'}]
# 6个半月
# [{'pattern': '6个半月', 'time': datetime.datetime(2019, 3, 25, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 16847990.442827, 'gapH': 4679.997345229723, 'gapD': 194.9998893845718, 'exp': '?y-+6.5m-?d-?H:?M:00S'}]
# 七个月
# [{'pattern': '七个月', 'time': datetime.datetime(2019, 4, 9, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 18143990.442262, 'gapH': 5039.997345072778, 'gapD': 209.99988937803244, 'exp': '?y-+7m-?d-?H:?M:00S'}]
# 7个月
# [{'pattern': '7个月', 'time': datetime.datetime(2019, 4, 9, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 18143990.441703, 'gapH': 5039.9973449174995, 'gapD': 209.9998893715625, 'exp': '?y-+7m-?d-?H:?M:00S'}]
# 七个半月
# [{'pattern': '七个半月', 'time': datetime.datetime(2019, 4, 24, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 19439990.441135, 'gapH': 5399.997344759722, 'gapD': 224.99988936498843, 'exp': '?y-+7.5m-?d-?H:?M:00S'}]
# 7个半月
# [{'pattern': '7个半月', 'time': datetime.datetime(2019, 4, 24, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 19439990.440574, 'gapH': 5399.997344603889, 'gapD': 224.99988935849538, 'exp': '?y-+7.5m-?d-?H:?M:00S'}]
# 八个月
# [{'pattern': '八个月', 'time': datetime.datetime(2019, 5, 9, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 20735990.439975, 'gapH': 5759.9973444375, 'gapD': 239.9998893515625, 'exp': '?y-+8m-?d-?H:?M:00S'}]
# 8个月
# [{'pattern': '8个月', 'time': datetime.datetime(2019, 5, 9, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 20735990.43926, 'gapH': 5759.997344238888, 'gapD': 239.999889343287, 'exp': '?y-+8m-?d-?H:?M:00S'}]
# 八个半月
# [{'pattern': '八个半月', 'time': datetime.datetime(2019, 5, 24, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 22031990.438684, 'gapH': 6119.997344078889, 'gapD': 254.99988933662038, 'exp': '?y-+8.5m-?d-?H:?M:00S'}]
# 8个半月
# [{'pattern': '8个半月', 'time': datetime.datetime(2019, 5, 24, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 22031990.438112, 'gapH': 6119.997343919999, 'gapD': 254.99988932999997, 'exp': '?y-+8.5m-?d-?H:?M:00S'}]
# 上半年
# [{'pattern': '上半年', 'time': datetime.datetime(2018, 5, 31, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -8862609.562388, 'gapH': -2461.835989552222, 'gapD': -102.57649956467593, 'exp': '?y-5m-31d-12H:00M:00S'}]
# 前半年
# [{'pattern': '半年', 'time': datetime.datetime(2019, 3, 12, 13, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 15767990.437059, 'gapH': 4379.9973436275, 'gapD': 182.49988931781252, 'exp': '+0.5y-?m-?d-?H:?M:00S'}]
# 下半年
# [{'pattern': '下半年', 'time': datetime.datetime(2018, 12, 31, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 9626990.436339, 'gapH': 2674.1640100941668, 'gapD': 111.42350042059029, 'exp': '?y-12m-31d-12H:00M:00S'}]
# 后半年
# [{'pattern': '半年', 'time': datetime.datetime(2019, 3, 12, 13, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 15767990.435783, 'gapH': 4379.997343273056, 'gapD': 182.499889303044, 'exp': '+0.5y-?m-?d-?H:?M:00S'}]
# 年初
# [{'pattern': '年初', 'time': datetime.datetime(2018, 3, 31, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -14133009.564769, 'gapH': -3925.8359902136112, 'gapD': -163.5764995922338, 'exp': '?y-3m-31d-12H:00M:00S'}]
# 年末
# [{'pattern': '末', 'time': datetime.datetime(2018, 9, 28, 1, 50, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1468790.434546, 'gapH': 407.99734292944447, 'gapD': 16.999889288726852, 'exp': '?y-?m-28d-?H:?M:00S'}]
# 年尾
# [{'pattern': '年尾', 'time': datetime.datetime(2018, 12, 31, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 9626990.434058, 'gapH': 2674.1640094605555, 'gapD': 111.42350039418982, 'exp': '?y-12m-31d-12H:00M:00S'}]
# 春天
# [{'pattern': '春天', 'time': datetime.datetime(2018, 5, 30, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -8949009.566531, 'gapH': -2485.835990703056, 'gapD': -103.57649961262733, 'exp': '?y-5m-30d-12H:00M:00S'}]
# 春季
# [{'pattern': '春季', 'time': datetime.datetime(2018, 5, 30, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -8949009.567042, 'gapH': -2485.835990845, 'gapD': -103.57649961854167, 'exp': '?y-5m-30d-12H:00M:00S'}]
# 夏天
# [{'pattern': '夏天', 'time': datetime.datetime(2018, 8, 30, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -1000209.567525, 'gapH': -277.83599097916664, 'gapD': -11.576499624131943, 'exp': '?y-8m-30d-12H:00M:00S'}]
# 夏季
# [{'pattern': '夏季', 'time': datetime.datetime(2018, 8, 30, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -1000209.567994, 'gapH': -277.8359911094445, 'gapD': -11.576499629560187, 'exp': '?y-8m-30d-12H:00M:00S'}]
# 秋天
# [{'pattern': '秋天', 'time': datetime.datetime(2018, 11, 30, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 6948590.431536, 'gapH': 1930.1640087600001, 'gapD': 80.42350036500001, 'exp': '?y-11m-30d-12H:00M:00S'}]
# 秋季
# [{'pattern': '秋季', 'time': datetime.datetime(2018, 11, 30, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 6948590.431067, 'gapH': 1930.1640086297223, 'gapD': 80.42350035957176, 'exp': '?y-11m-30d-12H:00M:00S'}]
# 冬天
# [{'pattern': '冬天', 'time': datetime.datetime(2018, 2, 28, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -16811409.569401, 'gapH': -4669.8359915002775, 'gapD': -194.5764996458449, 'exp': '?y-2m-28d-12H:00M:00S'}]
# 冬季
# [{'pattern': '冬季', 'time': datetime.datetime(2018, 2, 28, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -16811409.569995, 'gapH': -4669.835991665278, 'gapD': -194.57649965271992, 'exp': '?y-2m-28d-12H:00M:00S'}]
# 一个季度
# [{'pattern': '一个季度', 'time': datetime.datetime(2018, 12, 10, 1, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 7772990.429518, 'gapH': 2159.1640081994447, 'gapD': 89.96516700831019, 'exp': '?y-+3m-?d-?H:00M:00S'}]
# 1个季度
# [{'pattern': '1个季度', 'time': datetime.datetime(2018, 12, 10, 1, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 7772990.429036, 'gapH': 2159.1640080655557, 'gapD': 89.96516700273149, 'exp': '?y-+3m-?d-?H:00M:00S'}]
# 两个季度
# [{'pattern': '两个季度', 'time': datetime.datetime(2019, 3, 10, 1, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 15548990.428562, 'gapH': 4319.164007933889, 'gapD': 179.96516699724535, 'exp': '?y-+6m-?d-?H:00M:00S'}]
# 2个季度
# [{'pattern': '2个季度', 'time': datetime.datetime(2019, 3, 10, 1, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 15548990.42809, 'gapH': 4319.164007802778, 'gapD': 179.9651669917824, 'exp': '?y-+6m-?d-?H:00M:00S'}]
# 三个季度
# [{'pattern': '三个季度', 'time': datetime.datetime(2019, 6, 8, 1, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 23324990.42762, 'gapH': 6479.164007672222, 'gapD': 269.9651669863426, 'exp': '?y-+9m-?d-?H:00M:00S'}]
# 3个季度
# [{'pattern': '3个季度', 'time': datetime.datetime(2019, 6, 8, 1, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 23324990.427151, 'gapH': 6479.164007541944, 'gapD': 269.9651669809143, 'exp': '?y-+9m-?d-?H:00M:00S'}]
# 劳动节
# [{'pattern': '劳动节', 'time': datetime.datetime(2018, 5, 7, 1, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -10975809.573317, 'gapH': -3048.835992588056, 'gapD': -127.03483302450233, 'exp': '?y-5m-7d-?H:00M:00S'}]
# 国庆节
# [{'pattern': '国庆节', 'time': datetime.datetime(2018, 10, 7, 1, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 2243390.426116, 'gapH': 623.1640072544444, 'gapD': 25.965166968935183, 'exp': '?y-10m-7d-?H:00M:00S'}]
# 下辈子
# [{'pattern': '下辈子', 'time': datetime.datetime(2118, 8, 18, 1, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 3153596990.425639, 'gapH': 875999.1640071219, 'gapD': 36499.96516696341, 'exp': '+100y-?m-?d-?H:00M:00S'}]
# 一周后
# [{'pattern': '一周', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 662990.424672, 'gapH': 184.16400685333332, 'gapD': 7.673500285555555, 'exp': '?y-+1W-?w-18H:00M:00S'}]
# 一周内
# [{'pattern': '一周', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 662990.423059, 'gapH': 184.1640064052778, 'gapD': 7.673500266886575, 'exp': '?y-+1W-?w-18H:00M:00S'}]
# 1周后
# [{'pattern': '1周', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 662990.422437, 'gapH': 184.1640062325, 'gapD': 7.6735002596875, 'exp': '?y-+1W-?w-18H:00M:00S'}]
# 2周后
# [{'pattern': '2周', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1267790.421853, 'gapH': 352.1640060702778, 'gapD': 14.673500252928243, 'exp': '?y-+2W-?w-18H:00M:00S'}]
# 两周后
# [{'pattern': '两周', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1267790.421268, 'gapH': 352.1640059077778, 'gapD': 14.673500246157408, 'exp': '?y-+2W-?w-18H:00M:00S'}]
# 下周
# [{'pattern': '下周', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 662990.420697, 'gapH': 184.16400574916668, 'gapD': 7.673500239548612, 'exp': '?y-^1W-?w-18H:00M:00S'}]
# 周三
# [{'pattern': '周三', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 144590.420081, 'gapH': 40.16400557805555, 'gapD': 1.6735002324189814, 'exp': '?y-?W-3w-18H:00M:00S'}]
# 下周一
# [{'pattern': '下周一', 'time': datetime.datetime(2018, 9, 17, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 576590.419501, 'gapH': 160.16400541694443, 'gapD': 6.673500225706018, 'exp': '?y-^1W-1w-18H:00M:00S'}]
# 下周1
# [{'pattern': '下周1', 'time': datetime.datetime(2018, 9, 17, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 576590.418934, 'gapH': 160.16400525944442, 'gapD': 6.673500219143517, 'exp': '?y-^1W-1w-18H:00M:00S'}]
# 下周一早上
# [{'pattern': '下周一早上', 'time': datetime.datetime(2018, 9, 17, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 551390.418181, 'gapH': 153.16400505027778, 'gapD': 6.381833543761574, 'exp': '?y-^1W-1w-11H:00M:00S'}]
# 下周1早上
# [{'pattern': '下周1早上', 'time': datetime.datetime(2018, 9, 17, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 551390.417558, 'gapH': 153.1640048772222, 'gapD': 6.381833536550925, 'exp': '?y-^1W-1w-11H:00M:00S'}]
# 下周一下午
# [{'pattern': '下周一下午', 'time': datetime.datetime(2018, 9, 17, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 576590.41695, 'gapH': 160.16400470833332, 'gapD': 6.673500196180555, 'exp': '?y-^1W-1w-18H:00M:00S'}]
# 下周1下午
# [{'pattern': '下周1下午', 'time': datetime.datetime(2018, 9, 17, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 576590.41634, 'gapH': 160.1640045388889, 'gapD': 6.673500189120371, 'exp': '?y-^1W-1w-18H:00M:00S'}]
# 下下周一
# [{'pattern': '下下周一', 'time': datetime.datetime(2018, 9, 24, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1181390.415733, 'gapH': 328.1640043702778, 'gapD': 13.673500182094907, 'exp': '?y-^2W-1w-18H:00M:00S'}]
# 下下周1
# [{'pattern': '下下周1', 'time': datetime.datetime(2018, 9, 24, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1181390.415146, 'gapH': 328.1640042072222, 'gapD': 13.673500175300925, 'exp': '?y-^2W-1w-18H:00M:00S'}]
# 下周二
# [{'pattern': '下周二', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 662990.414389, 'gapH': 184.16400399694444, 'gapD': 7.673500166539352, 'exp': '?y-^1W-2w-18H:00M:00S'}]
# 下周2
# [{'pattern': '下周2', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 662990.413007, 'gapH': 184.16400361305554, 'gapD': 7.673500150543981, 'exp': '?y-^1W-2w-18H:00M:00S'}]
# 下周二下午
# [{'pattern': '下周二下午', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 662990.411564, 'gapH': 184.1640032122222, 'gapD': 7.673500133842592, 'exp': '?y-^1W-2w-18H:00M:00S'}]
# 下周2下午
# [{'pattern': '下周2下午', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 662990.409897, 'gapH': 184.16400274916666, 'gapD': 7.67350011454861, 'exp': '?y-^1W-2w-18H:00M:00S'}]
# 下周二早上
# [{'pattern': '下周二早上', 'time': datetime.datetime(2018, 9, 18, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 637790.40812, 'gapH': 177.16400225555557, 'gapD': 7.381833427314816, 'exp': '?y-^1W-2w-11H:00M:00S'}]
# 下周2早上
# [{'pattern': '下周2早上', 'time': datetime.datetime(2018, 9, 18, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 637790.406051, 'gapH': 177.16400168083334, 'gapD': 7.381833403368056, 'exp': '?y-^1W-2w-11H:00M:00S'}]
# 下下周二
# [{'pattern': '下下周二', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1267790.404674, 'gapH': 352.16400129833335, 'gapD': 14.673500054097223, 'exp': '?y-^2W-2w-18H:00M:00S'}]
# 下下周2
# [{'pattern': '下下周2', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1267790.402505, 'gapH': 352.1640006958333, 'gapD': 14.673500028993054, 'exp': '?y-^2W-2w-18H:00M:00S'}]
# 下周三
# [{'pattern': '下周三', 'time': datetime.datetime(2018, 9, 19, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 749390.392761, 'gapH': 208.16399798916666, 'gapD': 8.673499916215277, 'exp': '?y-^1W-3w-18H:00M:00S'}]
# 下周3
# [{'pattern': '下周3', 'time': datetime.datetime(2018, 9, 19, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 749390.392084, 'gapH': 208.16399780111112, 'gapD': 8.67349990837963, 'exp': '?y-^1W-3w-18H:00M:00S'}]
# 下周三早上
# [{'pattern': '下周三早上', 'time': datetime.datetime(2018, 9, 19, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 724190.391452, 'gapH': 201.16399762555557, 'gapD': 8.38183323439815, 'exp': '?y-^1W-3w-11H:00M:00S'}]
# 下周3早上
# [{'pattern': '下周3早上', 'time': datetime.datetime(2018, 9, 19, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 724190.390994, 'gapH': 201.16399749833334, 'gapD': 8.381833229097223, 'exp': '?y-^1W-3w-11H:00M:00S'}]
# 下周三下午
# [{'pattern': '下周三下午', 'time': datetime.datetime(2018, 9, 19, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 749390.390351, 'gapH': 208.16399731972223, 'gapD': 8.673499888321759, 'exp': '?y-^1W-3w-18H:00M:00S'}]
# 下周3下午
# [{'pattern': '下周3下午', 'time': datetime.datetime(2018, 9, 19, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 749390.389878, 'gapH': 208.16399718833333, 'gapD': 8.673499882847223, 'exp': '?y-^1W-3w-18H:00M:00S'}]
# 下下周三
# [{'pattern': '下下周三', 'time': datetime.datetime(2018, 9, 26, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1354190.389424, 'gapH': 376.1639970622222, 'gapD': 15.673499877592592, 'exp': '?y-^2W-3w-18H:00M:00S'}]
# 下下周3
# [{'pattern': '下下周3', 'time': datetime.datetime(2018, 9, 26, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1354190.389092, 'gapH': 376.16399696999997, 'gapD': 15.673499873749998, 'exp': '?y-^2W-3w-18H:00M:00S'}]
# 下周四
# [{'pattern': '下周四', 'time': datetime.datetime(2018, 9, 20, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 835790.388626, 'gapH': 232.16399684055557, 'gapD': 9.673499868356481, 'exp': '?y-^1W-4w-18H:00M:00S'}]
# 下周4
# [{'pattern': '下周4', 'time': datetime.datetime(2018, 9, 20, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 835790.388325, 'gapH': 232.16399675694444, 'gapD': 9.673499864872685, 'exp': '?y-^1W-4w-18H:00M:00S'}]
# 下周四早上
# [{'pattern': '下周四早上', 'time': datetime.datetime(2018, 9, 20, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 810590.388066, 'gapH': 225.163996685, 'gapD': 9.381833195208333, 'exp': '?y-^1W-4w-11H:00M:00S'}]
# 下周4早上
# [{'pattern': '下周4早上', 'time': datetime.datetime(2018, 9, 20, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 810590.387819, 'gapH': 225.1639966163889, 'gapD': 9.381833192349537, 'exp': '?y-^1W-4w-11H:00M:00S'}]
# 下周四下午
# [{'pattern': '下周四下午', 'time': datetime.datetime(2018, 9, 20, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 835790.387574, 'gapH': 232.16399654833336, 'gapD': 9.673499856180557, 'exp': '?y-^1W-4w-18H:00M:00S'}]
# 下周4下午
# [{'pattern': '下周4下午', 'time': datetime.datetime(2018, 9, 20, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 835790.387337, 'gapH': 232.1639964825, 'gapD': 9.6734998534375, 'exp': '?y-^1W-4w-18H:00M:00S'}]
# 下下周四
# [{'pattern': '下下周四', 'time': datetime.datetime(2018, 9, 27, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1440590.387107, 'gapH': 400.16399641861113, 'gapD': 16.673499850775464, 'exp': '?y-^2W-4w-18H:00M:00S'}]
# 下下周4
# [{'pattern': '下下周4', 'time': datetime.datetime(2018, 9, 27, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1440590.386881, 'gapH': 400.1639963558333, 'gapD': 16.67349984815972, 'exp': '?y-^2W-4w-18H:00M:00S'}]
# 下周五
# [{'pattern': '下周五', 'time': datetime.datetime(2018, 9, 21, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 922190.38665, 'gapH': 256.16399629166665, 'gapD': 10.673499845486111, 'exp': '?y-^1W-5w-18H:00M:00S'}]
# 下周5
# [{'pattern': '下周5', 'time': datetime.datetime(2018, 9, 21, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 922190.386428, 'gapH': 256.16399623, 'gapD': 10.673499842916668, 'exp': '?y-^1W-5w-18H:00M:00S'}]
# 下周五早上
# [{'pattern': '下周五早上', 'time': datetime.datetime(2018, 9, 21, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 896990.386191, 'gapH': 249.16399616416666, 'gapD': 10.381833173506944, 'exp': '?y-^1W-5w-11H:00M:00S'}]
# 下周5早上
# [{'pattern': '下周5早上', 'time': datetime.datetime(2018, 9, 21, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 896990.385956, 'gapH': 249.16399609888887, 'gapD': 10.381833170787036, 'exp': '?y-^1W-5w-11H:00M:00S'}]
# 下周五下午
# [{'pattern': '下周五下午', 'time': datetime.datetime(2018, 9, 21, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 922190.385721, 'gapH': 256.1639960336111, 'gapD': 10.673499834733796, 'exp': '?y-^1W-5w-18H:00M:00S'}]
# 下周5下午
# [{'pattern': '下周5下午', 'time': datetime.datetime(2018, 9, 21, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 922190.385379, 'gapH': 256.1639959386111, 'gapD': 10.673499830775462, 'exp': '?y-^1W-5w-18H:00M:00S'}]
# 下下周五
# [{'pattern': '下下周五', 'time': datetime.datetime(2018, 9, 28, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1526990.384947, 'gapH': 424.1639958186111, 'gapD': 17.673499825775462, 'exp': '?y-^2W-5w-18H:00M:00S'}]
# 下下周5
# [{'pattern': '下下周5', 'time': datetime.datetime(2018, 9, 28, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1526990.384693, 'gapH': 424.1639957480556, 'gapD': 17.673499822835648, 'exp': '?y-^2W-5w-18H:00M:00S'}]
# 这周内
# [{'pattern': '这周', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 58190.384194, 'gapH': 16.163995609444445, 'gapD': 0.6734998170601852, 'exp': '?y-?W-?w-18H:00M:00S'}]
# 这星期内
# [{'pattern': '这星期', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 58190.383821, 'gapH': 16.163995505833334, 'gapD': 0.6734998127430556, 'exp': '?y-?W-?w-18H:00M:00S'}]
# 这礼拜内内
# [{'pattern': '这礼拜', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 58190.383422, 'gapH': 16.163995395, 'gapD': 0.673499808125, 'exp': '?y-?W-?w-18H:00M:00S'}]
# 下周内
# [{'pattern': '下周', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 662990.383032, 'gapH': 184.16399528666668, 'gapD': 7.6734998036111115, 'exp': '?y-^1W-?w-18H:00M:00S'}]
# 下星期内
# [{'pattern': '下星期', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 662990.382635, 'gapH': 184.1639951763889, 'gapD': 7.673499799016205, 'exp': '?y-^1W-?w-18H:00M:00S'}]
# 下礼拜内
# [{'pattern': '下礼拜', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 662990.38231, 'gapH': 184.16399508611113, 'gapD': 7.673499795254631, 'exp': '?y-^1W-?w-18H:00M:00S'}]
# 下下周
# [{'pattern': '下下周', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1267790.381939, 'gapH': 352.16399498305555, 'gapD': 14.673499790960648, 'exp': '?y-^2W-?w-18H:00M:00S'}]
# 下下星期
# [{'pattern': '下下星期', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1267790.381122, 'gapH': 352.16399475611115, 'gapD': 14.673499781504631, 'exp': '?y-^2W-?w-18H:00M:00S'}]
# 下下礼拜
# [{'pattern': '下下礼拜', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1267790.380783, 'gapH': 352.16399466194446, 'gapD': 14.67349977758102, 'exp': '?y-^2W-?w-18H:00M:00S'}]
# 下下下周
# [{'pattern': '下下周', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1267790.380371, 'gapH': 352.16399454749995, 'gapD': 14.673499772812498, 'exp': '?y-^2W-?w-18H:00M:00S'}]
# 下下下星期
# [{'pattern': '下下星期', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1267790.379975, 'gapH': 352.1639944375, 'gapD': 14.673499768229165, 'exp': '?y-^2W-?w-18H:00M:00S'}]
# 下下下礼拜
# [{'pattern': '下下礼拜', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1267790.379563, 'gapH': 352.1639943230556, 'gapD': 14.673499763460649, 'exp': '?y-^2W-?w-18H:00M:00S'}]
# 两周内
# [{'pattern': '两周', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1267790.37915, 'gapH': 352.1639942083333, 'gapD': 14.673499758680554, 'exp': '?y-+2W-?w-18H:00M:00S'}]
# 这周二
# [{'pattern': '这周二', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 58190.378754, 'gapH': 16.163994098333333, 'gapD': 0.6734997540972222, 'exp': '?y-?W-2w-18H:00M:00S'}]
# 这周2
# [{'pattern': '这周2', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 58190.378346, 'gapH': 16.163993984999998, 'gapD': 0.6734997493749999, 'exp': '?y-?W-2w-18H:00M:00S'}]
# 这周二早上
# [{'pattern': '这周二早上', 'time': datetime.datetime(2018, 9, 11, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 32990.377919, 'gapH': 9.16399386638889, 'gapD': 0.38183307776620373, 'exp': '?y-?W-2w-11H:00M:00S'}]
# 这周2早上
# [{'pattern': '这周2早上', 'time': datetime.datetime(2018, 9, 11, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 32990.37749, 'gapH': 9.163993747222221, 'gapD': 0.3818330728009259, 'exp': '?y-?W-2w-11H:00M:00S'}]
# 这周二下午
# [{'pattern': '这周二下午', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 58190.37706, 'gapH': 16.163993627777778, 'gapD': 0.6734997344907407, 'exp': '?y-?W-2w-18H:00M:00S'}]
# 这周2下午
# [{'pattern': '这周2下午', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 58190.376725, 'gapH': 16.163993534722223, 'gapD': 0.6734997306134259, 'exp': '?y-?W-2w-18H:00M:00S'}]
# 这周三
# [{'pattern': '这周三', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 144590.376399, 'gapH': 40.163993444166664, 'gapD': 1.6734997268402776, 'exp': '?y-?W-3w-18H:00M:00S'}]
# 这周3
# [{'pattern': '这周3', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 144590.375997, 'gapH': 40.1639933325, 'gapD': 1.6734997221874999, 'exp': '?y-?W-3w-18H:00M:00S'}]
# 这周三早上
# [{'pattern': '这周三早上', 'time': datetime.datetime(2018, 9, 12, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 119390.375564, 'gapH': 33.16399321222222, 'gapD': 1.3818330505092593, 'exp': '?y-?W-3w-11H:00M:00S'}]
# 这周3早上
# [{'pattern': '这周3早上', 'time': datetime.datetime(2018, 9, 12, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 119390.375132, 'gapH': 33.16399309222222, 'gapD': 1.3818330455092591, 'exp': '?y-?W-3w-11H:00M:00S'}]
# 这周三下午
# [{'pattern': '这周三下午', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 144590.37452, 'gapH': 40.16399292222223, 'gapD': 1.6734997050925928, 'exp': '?y-?W-3w-18H:00M:00S'}]
# 这周四
# [{'pattern': '这周四', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 230990.374023, 'gapH': 64.16399278416667, 'gapD': 2.6734996993402778, 'exp': '?y-?W-4w-18H:00M:00S'}]
# 这周4
# [{'pattern': '这周4', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 230990.373618, 'gapH': 64.16399267166668, 'gapD': 2.673499694652778, 'exp': '?y-?W-4w-18H:00M:00S'}]
# 这周四早上
# [{'pattern': '这周四早上', 'time': datetime.datetime(2018, 9, 13, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 205790.373176, 'gapH': 57.163992548888885, 'gapD': 2.3818330228703704, 'exp': '?y-?W-4w-11H:00M:00S'}]
# 这周4早上
# [{'pattern': '这周4早上', 'time': datetime.datetime(2018, 9, 13, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 205790.372683, 'gapH': 57.16399241194444, 'gapD': 2.3818330171643516, 'exp': '?y-?W-4w-11H:00M:00S'}]
# 这周四下午
# [{'pattern': '这周四下午', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 230990.371744, 'gapH': 64.16399215111112, 'gapD': 2.673499672962963, 'exp': '?y-?W-4w-18H:00M:00S'}]
# 这周4下午
# [{'pattern': '这周4下午', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 230990.371244, 'gapH': 64.16399201222222, 'gapD': 2.673499667175926, 'exp': '?y-?W-4w-18H:00M:00S'}]
# 这周五
# [{'pattern': '这周五', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 317390.370035, 'gapH': 88.1639916763889, 'gapD': 3.673499653182871, 'exp': '?y-?W-5w-18H:00M:00S'}]
# 这周5
# [{'pattern': '这周5', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 317390.369628, 'gapH': 88.16399156333334, 'gapD': 3.6734996484722227, 'exp': '?y-?W-5w-18H:00M:00S'}]
# 这周五早上
# [{'pattern': '这周五早上', 'time': datetime.datetime(2018, 9, 14, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 292190.36925, 'gapH': 81.16399145833333, 'gapD': 3.3818329774305553, 'exp': '?y-?W-5w-11H:00M:00S'}]
# 这周5早上
# [{'pattern': '这周5早上', 'time': datetime.datetime(2018, 9, 14, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 292190.368827, 'gapH': 81.16399134083333, 'gapD': 3.3818329725347223, 'exp': '?y-?W-5w-11H:00M:00S'}]
# 这周五下午
# [{'pattern': '这周五下午', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 317390.368273, 'gapH': 88.16399118694444, 'gapD': 3.6734996327893517, 'exp': '?y-?W-5w-18H:00M:00S'}]
# 这周5下午
# [{'pattern': '这周5下午', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 317390.36785, 'gapH': 88.16399106944444, 'gapD': 3.673499627893518, 'exp': '?y-?W-5w-18H:00M:00S'}]
# 星期二
# [{'pattern': '星期二', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 58190.367509, 'gapH': 16.163990974722225, 'gapD': 0.6734996239467593, 'exp': '?y-?W-2w-18H:00M:00S'}]
# 星期2
# [{'pattern': '星期2', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 58190.367175, 'gapH': 16.163990881944443, 'gapD': 0.6734996200810185, 'exp': '?y-?W-2w-18H:00M:00S'}]
# 礼拜二
# [{'pattern': '礼拜二', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 58190.366625, 'gapH': 16.163990729166667, 'gapD': 0.6734996137152778, 'exp': '?y-?W-2w-18H:00M:00S'}]
# 礼拜2
# [{'pattern': '礼拜2', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 58190.366247, 'gapH': 16.163990624166665, 'gapD': 0.6734996093402777, 'exp': '?y-?W-2w-18H:00M:00S'}]
# 星期三
# [{'pattern': '星期三', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 144590.365345, 'gapH': 40.163990373611114, 'gapD': 1.673499598900463, 'exp': '?y-?W-3w-18H:00M:00S'}]
# 星期3
# [{'pattern': '星期3', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 144590.364972, 'gapH': 40.16399027, 'gapD': 1.6734995945833333, 'exp': '?y-?W-3w-18H:00M:00S'}]
# 礼拜三
# [{'pattern': '礼拜三', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 144590.364585, 'gapH': 40.1639901625, 'gapD': 1.6734995901041667, 'exp': '?y-?W-3w-18H:00M:00S'}]
# 礼拜3
# [{'pattern': '礼拜3', 'time': datetime.datetime(2018, 9, 12, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 144590.364291, 'gapH': 40.16399008083334, 'gapD': 1.673499586701389, 'exp': '?y-?W-3w-18H:00M:00S'}]
# 星期四
# [{'pattern': '星期四', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 230990.363921, 'gapH': 64.16398997805555, 'gapD': 2.6734995824189816, 'exp': '?y-?W-4w-18H:00M:00S'}]
# 星期4
# [{'pattern': '星期4', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 230990.363535, 'gapH': 64.16398987083333, 'gapD': 2.673499577951389, 'exp': '?y-?W-4w-18H:00M:00S'}]
# 礼拜4
# [{'pattern': '礼拜4', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 230990.363217, 'gapH': 64.1639897825, 'gapD': 2.673499574270833, 'exp': '?y-?W-4w-18H:00M:00S'}]
# 礼拜四
# [{'pattern': '礼拜四', 'time': datetime.datetime(2018, 9, 13, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 230990.36289, 'gapH': 64.16398969166666, 'gapD': 2.673499570486111, 'exp': '?y-?W-4w-18H:00M:00S'}]
# 星期五
# [{'pattern': '星期五', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 317390.362501, 'gapH': 88.16398958361111, 'gapD': 3.6734995659837963, 'exp': '?y-?W-5w-18H:00M:00S'}]
# 星期5
# [{'pattern': '星期5', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 317390.36218, 'gapH': 88.16398949444444, 'gapD': 3.673499562268518, 'exp': '?y-?W-5w-18H:00M:00S'}]
# 礼拜五
# [{'pattern': '礼拜五', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 317390.361831, 'gapH': 88.1639893975, 'gapD': 3.673499558229167, 'exp': '?y-?W-5w-18H:00M:00S'}]
# 礼拜5
# [{'pattern': '礼拜5', 'time': datetime.datetime(2018, 9, 14, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 317390.361514, 'gapH': 88.16398930944445, 'gapD': 3.6734995545601854, 'exp': '?y-?W-5w-18H:00M:00S'}]
# 下个星期一
# [{'pattern': '下个星期一', 'time': datetime.datetime(2018, 9, 17, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 576590.36109, 'gapH': 160.16398919166667, 'gapD': 6.673499549652778, 'exp': '?y-^1W-1w-18H:00M:00S'}]
# 下个礼拜一
# [{'pattern': '下个礼拜一', 'time': datetime.datetime(2018, 9, 17, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 576590.36047, 'gapH': 160.16398901944444, 'gapD': 6.6734995424768515, 'exp': '?y-^1W-1w-18H:00M:00S'}]
# 下个星期1
# [{'pattern': '下个星期1', 'time': datetime.datetime(2018, 9, 17, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 576590.360054, 'gapH': 160.1639889038889, 'gapD': 6.673499537662038, 'exp': '?y-^1W-1w-18H:00M:00S'}]
# 下个礼拜1
# [{'pattern': '下个礼拜1', 'time': datetime.datetime(2018, 9, 17, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 576590.35974, 'gapH': 160.16398881666666, 'gapD': 6.673499534027777, 'exp': '?y-^1W-1w-18H:00M:00S'}]
# 下个星期一早上
# [{'pattern': '下个星期一早上', 'time': datetime.datetime(2018, 9, 17, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 551390.358901, 'gapH': 153.16398858361111, 'gapD': 6.381832857650463, 'exp': '?y-^1W-1w-11H:00M:00S'}]
# 下个礼拜一早上
# [{'pattern': '下个礼拜一早上', 'time': datetime.datetime(2018, 9, 17, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 551390.35739, 'gapH': 153.1639881638889, 'gapD': 6.381832840162037, 'exp': '?y-^1W-1w-11H:00M:00S'}]
# 下个星期1早上
# [{'pattern': '下个星期1早上', 'time': datetime.datetime(2018, 9, 17, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 551390.356841, 'gapH': 153.1639880113889, 'gapD': 6.381832833807871, 'exp': '?y-^1W-1w-11H:00M:00S'}]
# 下个礼拜1早上
# [{'pattern': '下个礼拜1早上', 'time': datetime.datetime(2018, 9, 17, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 551390.356359, 'gapH': 153.16398787749998, 'gapD': 6.381832828229165, 'exp': '?y-^1W-1w-11H:00M:00S'}]
# 下下个星期一
# [{'pattern': '下下个星期一', 'time': datetime.datetime(2018, 9, 24, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1181390.356063, 'gapH': 328.16398779527776, 'gapD': 13.673499491469906, 'exp': '?y-^2W-1w-18H:00M:00S'}]
# 下下个礼拜一
# [{'pattern': '下下个礼拜一', 'time': datetime.datetime(2018, 9, 24, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1181390.3558, 'gapH': 328.1639877222222, 'gapD': 13.673499488425925, 'exp': '?y-^2W-1w-18H:00M:00S'}]
# 下下个星期1
# [{'pattern': '下下个星期1', 'time': datetime.datetime(2018, 9, 24, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1181390.355546, 'gapH': 328.1639876516667, 'gapD': 13.673499485486111, 'exp': '?y-^2W-1w-18H:00M:00S'}]
# 下下个礼拜1
# [{'pattern': '下下个礼拜1', 'time': datetime.datetime(2018, 9, 24, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1181390.355292, 'gapH': 328.16398758111114, 'gapD': 13.673499482546298, 'exp': '?y-^2W-1w-18H:00M:00S'}]
# 下个星期二
# [{'pattern': '下个星期二', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 662990.355039, 'gapH': 184.16398751083335, 'gapD': 7.673499479618056, 'exp': '?y-^1W-2w-18H:00M:00S'}]
# 下个礼拜二
# [{'pattern': '下个礼拜二', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 662990.354787, 'gapH': 184.16398744083332, 'gapD': 7.673499476701388, 'exp': '?y-^1W-2w-18H:00M:00S'}]
# 下个星期2
# [{'pattern': '下个星期2', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 662990.35454, 'gapH': 184.1639873722222, 'gapD': 7.673499473842592, 'exp': '?y-^1W-2w-18H:00M:00S'}]
# 下个礼拜2
# [{'pattern': '下个礼拜2', 'time': datetime.datetime(2018, 9, 18, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 662990.354292, 'gapH': 184.16398730333333, 'gapD': 7.673499470972222, 'exp': '?y-^1W-2w-18H:00M:00S'}]
# 下个星期二早上
# [{'pattern': '下个星期二早上', 'time': datetime.datetime(2018, 9, 18, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 637790.353837, 'gapH': 177.16398717694443, 'gapD': 7.381832799039351, 'exp': '?y-^1W-2w-11H:00M:00S'}]
# 下个礼拜二早上
# [{'pattern': '下个礼拜二早上', 'time': datetime.datetime(2018, 9, 18, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 637790.353495, 'gapH': 177.16398708194447, 'gapD': 7.38183279508102, 'exp': '?y-^1W-2w-11H:00M:00S'}]
# 下个星期2早上
# [{'pattern': '下个星期2早上', 'time': datetime.datetime(2018, 9, 18, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 637790.353186, 'gapH': 177.1639869961111, 'gapD': 7.381832791504629, 'exp': '?y-^1W-2w-11H:00M:00S'}]
# 下个礼拜2早上
# [{'pattern': '下个礼拜2早上', 'time': datetime.datetime(2018, 9, 18, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 637790.352901, 'gapH': 177.16398691694442, 'gapD': 7.381832788206018, 'exp': '?y-^1W-2w-11H:00M:00S'}]
# 下下个星期二
# [{'pattern': '下下个星期二', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1267790.352646, 'gapH': 352.16398684611113, 'gapD': 14.673499451921296, 'exp': '?y-^2W-2w-18H:00M:00S'}]
# 下下个礼拜二
# [{'pattern': '下下个礼拜二', 'time': datetime.datetime(2018, 9, 25, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 1267790.352397, 'gapH': 352.16398677694445, 'gapD': 14.673499449039353, 'exp': '?y-^2W-2w-18H:00M:00S'}]
# 下下个星期2
# ...
# 早上3点
# [{'pattern': '早上3点', 'time': datetime.datetime(2018, 9, 11, 3, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 4190.18201, 'gapH': 1.1639394472222224, 'gapD': 0.0484974769675926, 'exp': '?y-?m-?d-3H:00M:00S'}]
# 早上4点
# [{'pattern': '早上4点', 'time': datetime.datetime(2018, 9, 11, 4, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 7790.181764, 'gapH': 2.1639393788888888, 'gapD': 0.09016414078703704, 'exp': '?y-?m-?d-4H:00M:00S'}]
# 早上5点
# [{'pattern': '早上5点', 'time': datetime.datetime(2018, 9, 11, 5, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 11390.180814, 'gapH': 3.163939115, 'gapD': 0.13183079645833332, 'exp': '?y-?m-?d-5H:00M:00S'}]
# 早上6点
# [{'pattern': '早上6点', 'time': datetime.datetime(2018, 9, 11, 6, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 14990.180514, 'gapH': 4.163939031666667, 'gapD': 0.17349745965277777, 'exp': '?y-?m-?d-6H:00M:00S'}]
# 早上7点
# [{'pattern': '早上7点', 'time': datetime.datetime(2018, 9, 11, 7, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 18590.180203, 'gapH': 5.163938945277778, 'gapD': 0.2151641227199074, 'exp': '?y-?m-?d-7H:00M:00S'}]
# 早上8点
# [{'pattern': '早上8点', 'time': datetime.datetime(2018, 9, 11, 8, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 22190.179983, 'gapH': 6.163938884166667, 'gapD': 0.25683078684027777, 'exp': '?y-?m-?d-8H:00M:00S'}]
# 早上9点
# [{'pattern': '早上9点', 'time': datetime.datetime(2018, 9, 11, 9, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 25790.179764, 'gapH': 7.163938823333334, 'gapD': 0.29849745097222224, 'exp': '?y-?m-?d-9H:00M:00S'}]
# 早上10点
# [{'pattern': '早上10点', 'time': datetime.datetime(2018, 9, 11, 10, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 29390.179561, 'gapH': 8.163938766944444, 'gapD': 0.3401641152893518, 'exp': '?y-?m-?d-10H:00M:00S'}]
# 早上11点
# [{'pattern': '早上11点', 'time': datetime.datetime(2018, 9, 11, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 32990.179355, 'gapH': 9.163938709722222, 'gapD': 0.38183077957175926, 'exp': '?y-?m-?d-11H:00M:00S'}]
# 早上一点
# [{'pattern': '早上一点', 'time': datetime.datetime(2018, 9, 11, 1, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -3009.820853, 'gapH': -0.8360613480555557, 'gapD': -0.03483588950231482, 'exp': '?y-?m-?d-1H:00M:00S'}]
# 早上二点
# [{'pattern': '早上二点', 'time': datetime.datetime(2018, 9, 11, 2, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590.178941, 'gapH': 0.16393859472222222, 'gapD': 0.0068307747800925925, 'exp': '?y-?m-?d-2H:00M:00S'}]
# 早上三点
# [{'pattern': '早上三点', 'time': datetime.datetime(2018, 9, 11, 3, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 4190.178741, 'gapH': 1.1639385391666666, 'gapD': 0.04849743913194444, 'exp': '?y-?m-?d-3H:00M:00S'}]
# 早上四点
# [{'pattern': '早上四点', 'time': datetime.datetime(2018, 9, 11, 4, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 7790.17854, 'gapH': 2.1639384833333333, 'gapD': 0.09016410347222222, 'exp': '?y-?m-?d-4H:00M:00S'}]
# 早上五点
# [{'pattern': '早上五点', 'time': datetime.datetime(2018, 9, 11, 5, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 11390.178342, 'gapH': 3.163938428333333, 'gapD': 0.13183076784722222, 'exp': '?y-?m-?d-5H:00M:00S'}]
# 早上六点
# [{'pattern': '早上六点', 'time': datetime.datetime(2018, 9, 11, 6, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 14990.178138, 'gapH': 4.163938371666666, 'gapD': 0.17349743215277777, 'exp': '?y-?m-?d-6H:00M:00S'}]
# 早上七点
# [{'pattern': '早上七点', 'time': datetime.datetime(2018, 9, 11, 7, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 18590.177938, 'gapH': 5.163938316111111, 'gapD': 0.21516409650462964, 'exp': '?y-?m-?d-7H:00M:00S'}]
# 早上八点
# [{'pattern': '早上八点', 'time': datetime.datetime(2018, 9, 11, 8, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 22190.177736, 'gapH': 6.16393826, 'gapD': 0.25683076083333334, 'exp': '?y-?m-?d-8H:00M:00S'}]
# 早上九点
# [{'pattern': '早上九点', 'time': datetime.datetime(2018, 9, 11, 9, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 25790.177535, 'gapH': 7.163938204166667, 'gapD': 0.2984974251736111, 'exp': '?y-?m-?d-9H:00M:00S'}]
# 早上十点
# [{'pattern': '早上十点', 'time': datetime.datetime(2018, 9, 11, 10, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 29390.177336, 'gapH': 8.163938148888889, 'gapD': 0.34016408953703703, 'exp': '?y-?m-?d-10H:00M:00S'}]
# 早上十一点
# [{'pattern': '早上十一点', 'time': datetime.datetime(2018, 9, 11, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 32990.177138, 'gapH': 9.16393809388889, 'gapD': 0.3818307539120371, 'exp': '?y-?m-?d-11H:00M:00S'}]
# 早晨1点
# [{'pattern': '早晨1点', 'time': datetime.datetime(2018, 9, 11, 1, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -3009.82305, 'gapH': -0.8360619583333333, 'gapD': -0.03483591493055555, 'exp': '?y-?m-?d-1H:00M:00S'}]
# 早晨2点
# [{'pattern': '早晨2点', 'time': datetime.datetime(2018, 9, 11, 2, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590.176763, 'gapH': 0.16393798972222223, 'gapD': 0.006830749571759259, 'exp': '?y-?m-?d-2H:00M:00S'}]
# 早晨3点
# [{'pattern': '早晨3点', 'time': datetime.datetime(2018, 9, 11, 3, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 4190.176577, 'gapH': 1.1639379380555557, 'gapD': 0.04849741408564815, 'exp': '?y-?m-?d-3H:00M:00S'}]
# 早晨4点
# [{'pattern': '早晨4点', 'time': datetime.datetime(2018, 9, 11, 4, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 7790.176389, 'gapH': 2.1639378858333336, 'gapD': 0.0901640785763889, 'exp': '?y-?m-?d-4H:00M:00S'}]
# 早晨5点
# [{'pattern': '早晨5点', 'time': datetime.datetime(2018, 9, 11, 5, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 11390.176198, 'gapH': 3.1639378327777776, 'gapD': 0.1318307430324074, 'exp': '?y-?m-?d-5H:00M:00S'}]
# 早晨6点
# [{'pattern': '早晨6点', 'time': datetime.datetime(2018, 9, 11, 6, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 14990.176009, 'gapH': 4.163937780277778, 'gapD': 0.17349740751157408, 'exp': '?y-?m-?d-6H:00M:00S'}]
# 早晨7点
# [{'pattern': '早晨7点', 'time': datetime.datetime(2018, 9, 11, 7, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 18590.175722, 'gapH': 5.163937700555556, 'gapD': 0.21516407085648148, 'exp': '?y-?m-?d-7H:00M:00S'}]
# 早晨8点
# [{'pattern': '早晨8点', 'time': datetime.datetime(2018, 9, 11, 8, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 22190.175466, 'gapH': 6.163937629444445, 'gapD': 0.2568307345601852, 'exp': '?y-?m-?d-8H:00M:00S'}]
# 早晨9点
# [{'pattern': '早晨9点', 'time': datetime.datetime(2018, 9, 11, 9, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 25790.174809, 'gapH': 7.163937446944445, 'gapD': 0.2984973936226852, 'exp': '?y-?m-?d-9H:00M:00S'}]
# 早晨10点
# [{'pattern': '早晨10点', 'time': datetime.datetime(2018, 9, 11, 10, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 29390.174529, 'gapH': 8.163937369166666, 'gapD': 0.3401640570486111, 'exp': '?y-?m-?d-10H:00M:00S'}]
# 早晨11点
# [{'pattern': '早晨11点', 'time': datetime.datetime(2018, 9, 11, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 32990.174234, 'gapH': 9.163937287222222, 'gapD': 0.3818307203009259, 'exp': '?y-?m-?d-11H:00M:00S'}]
# 早晨一点
# [{'pattern': '早晨一点', 'time': datetime.datetime(2018, 9, 11, 1, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': -3009.82606, 'gapH': -0.8360627944444444, 'gapD': -0.03483594976851852, 'exp': '?y-?m-?d-1H:00M:00S'}]
# 早晨二点
# [{'pattern': '早晨二点', 'time': datetime.datetime(2018, 9, 11, 2, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 590.173624, 'gapH': 0.16393711777777778, 'gapD': 0.006830713240740741, 'exp': '?y-?m-?d-2H:00M:00S'}]
# 早晨三点
# [{'pattern': '早晨三点', 'time': datetime.datetime(2018, 9, 11, 3, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 4190.173432, 'gapH': 1.1639370644444442, 'gapD': 0.048497377685185174, 'exp': '?y-?m-?d-3H:00M:00S'}]
# 早晨四点
# [{'pattern': '早晨四点', 'time': datetime.datetime(2018, 9, 11, 4, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 7790.173246, 'gapH': 2.1639370127777777, 'gapD': 0.09016404219907408, 'exp': '?y-?m-?d-4H:00M:00S'}]
# 早晨五点
# [{'pattern': '早晨五点', 'time': datetime.datetime(2018, 9, 11, 5, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 11390.173062, 'gapH': 3.163936961666667, 'gapD': 0.1318307067361111, 'exp': '?y-?m-?d-5H:00M:00S'}]
# 早晨六点
# [{'pattern': '早晨六点', 'time': datetime.datetime(2018, 9, 11, 6, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 14990.172879, 'gapH': 4.163936910833333, 'gapD': 0.1734973712847222, 'exp': '?y-?m-?d-6H:00M:00S'}]
# 早晨七点
# [{'pattern': '早晨七点', 'time': datetime.datetime(2018, 9, 11, 7, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 18590.172696, 'gapH': 5.163936860000001, 'gapD': 0.21516403583333335, 'exp': '?y-?m-?d-7H:00M:00S'}]
# 早晨八点
# [{'pattern': '早晨八点', 'time': datetime.datetime(2018, 9, 11, 8, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 22190.172513, 'gapH': 6.163936809166667, 'gapD': 0.25683070038194444, 'exp': '?y-?m-?d-8H:00M:00S'}]
# 早晨九点
# [{'pattern': '早晨九点', 'time': datetime.datetime(2018, 9, 11, 9, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 25790.172332, 'gapH': 7.163936758888888, 'gapD': 0.29849736495370366, 'exp': '?y-?m-?d-9H:00M:00S'}]
# 早晨十点
# [{'pattern': '早晨十点', 'time': datetime.datetime(2018, 9, 11, 10, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 29390.172152, 'gapH': 8.163936708888889, 'gapD': 0.340164029537037, 'exp': '?y-?m-?d-10H:00M:00S'}]
# 早晨十一点
# [{'pattern': '早晨十一点', 'time': datetime.datetime(2018, 9, 11, 11, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 32990.171968, 'gapH': 9.163936657777779, 'gapD': 0.3818306940740741, 'exp': '?y-?m-?d-11H:00M:00S'}]
# 下午1点
# [{'pattern': '下午1点', 'time': datetime.datetime(2018, 9, 11, 13, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 40190.171786, 'gapH': 11.163936607222222, 'gapD': 0.46516402530092593, 'exp': '?y-?m-?d-13H:00M:00S'}]
# 下午2点
# [{'pattern': '下午2点', 'time': datetime.datetime(2018, 9, 11, 14, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 43790.171605, 'gapH': 12.163936556944446, 'gapD': 0.5068306898726852, 'exp': '?y-?m-?d-14H:00M:00S'}]
# 下午3点
# [{'pattern': '下午3点', 'time': datetime.datetime(2018, 9, 11, 15, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 47390.171424, 'gapH': 13.163936506666667, 'gapD': 0.5484973544444445, 'exp': '?y-?m-?d-15H:00M:00S'}]
# 下午4点
# [{'pattern': '下午4点', 'time': datetime.datetime(2018, 9, 11, 16, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 50990.171241, 'gapH': 14.163936455833332, 'gapD': 0.5901640189930555, 'exp': '?y-?m-?d-16H:00M:00S'}]
# 下午5点
# [{'pattern': '下午5点', 'time': datetime.datetime(2018, 9, 11, 17, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 54590.170993, 'gapH': 15.163936386944444, 'gapD': 0.6318306827893518, 'exp': '?y-?m-?d-17H:00M:00S'}]
# 下午6点
# [{'pattern': '下午6点', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 58190.170765, 'gapH': 16.16393632361111, 'gapD': 0.6734973468171296, 'exp': '?y-?m-?d-18H:00M:00S'}]
# 下午一点
# [{'pattern': '下午一点', 'time': datetime.datetime(2018, 9, 11, 13, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 40190.170573, 'gapH': 11.163936270277778, 'gapD': 0.4651640112615741, 'exp': '?y-?m-?d-13H:00M:00S'}]
# 下午二点
# [{'pattern': '下午二点', 'time': datetime.datetime(2018, 9, 11, 14, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 43790.170381, 'gapH': 12.163936216944446, 'gapD': 0.5068306757060186, 'exp': '?y-?m-?d-14H:00M:00S'}]
# 下午三点
# [{'pattern': '下午三点', 'time': datetime.datetime(2018, 9, 11, 15, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 47390.170188, 'gapH': 13.163936163333332, 'gapD': 0.5484973401388888, 'exp': '?y-?m-?d-15H:00M:00S'}]
# 下午四点
# [{'pattern': '下午四点', 'time': datetime.datetime(2018, 9, 11, 16, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 50990.169998, 'gapH': 14.163936110555555, 'gapD': 0.5901640046064814, 'exp': '?y-?m-?d-16H:00M:00S'}]
# 下午五点
# [{'pattern': '下午五点', 'time': datetime.datetime(2018, 9, 11, 17, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 54590.169808, 'gapH': 15.163936057777777, 'gapD': 0.631830669074074, 'exp': '?y-?m-?d-17H:00M:00S'}]
# 下午六点
# [{'pattern': '下午六点', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 58190.169619, 'gapH': 16.163936005277776, 'gapD': 0.6734973335532407, 'exp': '?y-?m-?d-18H:00M:00S'}]
# 晚上6点
# [{'pattern': '晚上6点', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 58190.169432, 'gapH': 16.163935953333333, 'gapD': 0.6734973313888889, 'exp': '?y-?m-?d-18H:00M:00S'}]
# 晚上7点
# [{'pattern': '晚上7点', 'time': datetime.datetime(2018, 9, 11, 19, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 61790.169245, 'gapH': 17.16393590138889, 'gapD': 0.7151639958912037, 'exp': '?y-?m-?d-19H:00M:00S'}]
# 晚上8点
# [{'pattern': '晚上8点', 'time': datetime.datetime(2018, 9, 11, 20, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 65390.169061, 'gapH': 18.163935850277777, 'gapD': 0.7568306604282408, 'exp': '?y-?m-?d-20H:00M:00S'}]
# 晚上9点
# [{'pattern': '晚上9点', 'time': datetime.datetime(2018, 9, 11, 21, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 68990.168747, 'gapH': 19.163935763055555, 'gapD': 0.7984973234606482, 'exp': '?y-?m-?d-21H:00M:00S'}]
# 晚上10点
# [{'pattern': '晚上10点', 'time': datetime.datetime(2018, 9, 11, 22, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 72590.16847, 'gapH': 20.163935686111113, 'gapD': 0.8401639869212963, 'exp': '?y-?m-?d-22H:00M:00S'}]
# 晚上11点
# [{'pattern': '晚上11点', 'time': datetime.datetime(2018, 9, 11, 23, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 76190.16826, 'gapH': 21.16393562777778, 'gapD': 0.8818306511574074, 'exp': '?y-?m-?d-23H:00M:00S'}]
# 晚上12点
# [{'pattern': '晚上12点', 'time': datetime.datetime(2018, 9, 11, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 36590.168061, 'gapH': 10.1639355725, 'gapD': 0.4234973155208333, 'exp': '?y-?m-?d-12H:00M:00S'}]
# 晚上六点
# [{'pattern': '晚上六点', 'time': datetime.datetime(2018, 9, 11, 18, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 58190.167865, 'gapH': 16.163935518055556, 'gapD': 0.6734973132523149, 'exp': '?y-?m-?d-18H:00M:00S'}]
# 晚上七点
# [{'pattern': '晚上七点', 'time': datetime.datetime(2018, 9, 11, 19, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 61790.16767, 'gapH': 17.16393546388889, 'gapD': 0.7151639776620371, 'exp': '?y-?m-?d-19H:00M:00S'}]
# 晚上八点
# [{'pattern': '晚上八点', 'time': datetime.datetime(2018, 9, 11, 20, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 65390.167478, 'gapH': 18.163935410555556, 'gapD': 0.7568306421064815, 'exp': '?y-?m-?d-20H:00M:00S'}]
# 晚上九点
# [{'pattern': '晚上九点', 'time': datetime.datetime(2018, 9, 11, 21, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 68990.167283, 'gapH': 19.16393535638889, 'gapD': 0.7984973065162038, 'exp': '?y-?m-?d-21H:00M:00S'}]
# 晚上十点
# [{'pattern': '晚上十点', 'time': datetime.datetime(2018, 9, 11, 22, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 72590.167098, 'gapH': 20.163935305000003, 'gapD': 0.8401639710416667, 'exp': '?y-?m-?d-22H:00M:00S'}]
# 晚上十一点
# [{'pattern': '晚上十一点', 'time': datetime.datetime(2018, 9, 11, 23, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 76190.166911, 'gapH': 21.163935253055552, 'gapD': 0.8818306355439813, 'exp': '?y-?m-?d-23H:00M:00S'}]
# 晚上十二点
# [{'pattern': '晚上十二点', 'time': datetime.datetime(2018, 9, 11, 12, 0, tzinfo=<DstTzInfo 'Asia/Shanghai' CST+8:00:00 STD>), 'gapS': 36590.16671, 'gapH': 10.163935197222221, 'gapD': 0.4234972998842592, 'exp': '?y-?m-?d-12H:00M:00S'}]
